# %%
# %%time
import pandas as pd
import numpy as np
import gc
import os
import random
import pickle
from sklearn.model_selection import StratifiedKFold,KFold
from scipy.sparse import hstack,vstack,csr_matrix,save_npz,load_npz
from sklearn.decomposition import TruncatedSVD
import lightgbm as lgb

############################################################################
#----- work folder -----
############################################################################
settings = json.load(open('./settings.json'))

input_path = settings['input_path']
features_path = settings['features_path']
model_path = settings['model_path']
sub_path = settings['sub_path']
# Out:
# CPU times: total: 3.25 s
# Wall time: 3.64 s
# c:\users\senki\appdata\local\programs\python\python38\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # load csr_matrix

# %%
# %%time

train_df = pd.read_feather(feature_path+'train_cite_inputs_id.feather')
test_df = pd.read_feather(feature_path+'test_cite_inputs_id.feather')

cite_inputs_sparse = load_npz(feature_path+"cite_inputs_sparse.npz")

train_cite_X = cite_inputs_sparse[:len(train_df)]
test_cite_X = cite_inputs_sparse[len(train_df):]
train_cite_y = np.load(feature_path+'train_cite_targets.npy')
# Out:
# CPU times: total: 16.2 s
# Wall time: 18.1 s

# %%
train_cite_X.shape,test_cite_X.shape,train_cite_y.shape
# Out:
# ((70988, 22050), (48663, 22050), (70988, 140))

# %% [markdown]
# # model

# %%
# %%time
# ====================================================
# lightgbm
# ====================================================
def lgb_kfold(train_df, test_df, train_cite_X, train_cite_y, test_cite_X, folds):
    params = {    
        'objective' : 'rmse', 
        'metric' : 'mse', 
         'num_leaves': 33,
         'min_data_in_leaf': 30,
         'learning_rate': 0.01,
         'max_depth': 7,
         "boosting": "gbdt",
         "feature_fraction": 0.05,
         "bagging_freq": 1,
         "bagging_fraction": 0.9,
         "bagging_seed": 42,
         "verbosity": -1,        
                 }      
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df)): 
        print ('n_fold:',n_fold)
        train_x = train_cite_X[train_idx]
        valid_x = train_cite_X[valid_idx]
        train_y = train_cite_y[train_idx]
        valid_y = train_cite_y[valid_idx]

        dtrain = lgb.Dataset(
            train_x, label=train_y,)
        dval = lgb.Dataset(
            valid_x, label=valid_y, reference=dtrain,)
        bst = lgb.train(
            params, dtrain, num_boost_round=10000,
            valid_sets=[dval],verbose_eval=1000, early_stopping_rounds=100,
        )
        
        oof_preds[valid_idx] = bst.predict(valid_x, num_iteration=bst.best_iteration)
        sub_preds += bst.predict(test_multi_X, num_iteration=bst.best_iteration) / folds.n_splits         
        
    return oof_preds,sub_preds
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
seed = 666
folds = KFold(n_splits= 5, shuffle=True, random_state=seed)  
train_preds = []
test_preds = []
for i in range(140):
    print('=====================')
    print(i)
    train_cite_y_single = train_cite_y[:,i]
    oof_preds,sub_preds = lgb_kfold(train_df, test_df, train_cite_X, train_cite_y_single, test_cite_X, folds)
    train_preds.append(oof_preds)
    test_preds.append(sub_preds)
# Out:
# =====================
# 0
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.52761
# [2000]	valid_0's l2: 1.52307
# Early stopping, best iteration is:
# [1951]	valid_0's l2: 1.52286
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.51331
# Early stopping, best iteration is:
# [1531]	valid_0's l2: 1.50659
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58769
# [2000]	valid_0's l2: 1.57645
# Early stopping, best iteration is:
# [2097]	valid_0's l2: 1.57587
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.60639
# [2000]	valid_0's l2: 1.5949
# Early stopping, best iteration is:
# [2038]	valid_0's l2: 1.59457
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.51805
# Early stopping, best iteration is:
# [1588]	valid_0's l2: 1.51167
# =====================
# 1
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [864]	valid_0's l2: 0.749524
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.744375
# Early stopping, best iteration is:
# [1221]	valid_0's l2: 0.74418
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.742402
# Early stopping, best iteration is:
# [977]	valid_0's l2: 0.742375
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.729537
# Early stopping, best iteration is:
# [946]	valid_0's l2: 0.729458
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [858]	valid_0's l2: 0.723799
# =====================
# 2
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.732505
# Early stopping, best iteration is:
# [1464]	valid_0's l2: 0.731753
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.720015
# Early stopping, best iteration is:
# [1872]	valid_0's l2: 0.718334
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.715694
# Early stopping, best iteration is:
# [1312]	valid_0's l2: 0.714725
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.719695
# Early stopping, best iteration is:
# [1521]	valid_0's l2: 0.718751
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.718956
# Early stopping, best iteration is:
# [1667]	valid_0's l2: 0.717666
# =====================
# 3
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.27118
# [2000]	valid_0's l2: 3.18599
# [3000]	valid_0's l2: 3.16548
# [4000]	valid_0's l2: 3.15905
# Early stopping, best iteration is:
# [4183]	valid_0's l2: 3.15737
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.29071
# [2000]	valid_0's l2: 3.20595
# [3000]	valid_0's l2: 3.18236
# [4000]	valid_0's l2: 3.17343
# [5000]	valid_0's l2: 3.16842
# Early stopping, best iteration is:
# [5062]	valid_0's l2: 3.16788
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.32583
# [2000]	valid_0's l2: 3.24486
# [3000]	valid_0's l2: 3.22537
# Early stopping, best iteration is:
# [3872]	valid_0's l2: 3.21805
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.31133
# [2000]	valid_0's l2: 3.23334
# [3000]	valid_0's l2: 3.21566
# [4000]	valid_0's l2: 3.20762
# Early stopping, best iteration is:
# [4128]	valid_0's l2: 3.20655
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.34661
# [2000]	valid_0's l2: 3.25381
# [3000]	valid_0's l2: 3.22885
# [4000]	valid_0's l2: 3.21926
# [5000]	valid_0's l2: 3.21431
# Early stopping, best iteration is:
# [4908]	valid_0's l2: 3.2141
# =====================
# 4
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.63207
# [2000]	valid_0's l2: 1.55102
# [3000]	valid_0's l2: 1.52458
# [4000]	valid_0's l2: 1.51305
# [5000]	valid_0's l2: 1.50732
# [6000]	valid_0's l2: 1.50379
# Early stopping, best iteration is:
# [6617]	valid_0's l2: 1.50174
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.5656
# [2000]	valid_0's l2: 1.49077
# [3000]	valid_0's l2: 1.46668
# [4000]	valid_0's l2: 1.45565
# [5000]	valid_0's l2: 1.44971
# [6000]	valid_0's l2: 1.44561
# [7000]	valid_0's l2: 1.44332
# Early stopping, best iteration is:
# [7134]	valid_0's l2: 1.44298
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.55946
# [2000]	valid_0's l2: 1.48986
# [3000]	valid_0's l2: 1.46993
# [4000]	valid_0's l2: 1.46084
# [5000]	valid_0's l2: 1.45609
# [6000]	valid_0's l2: 1.45355
# Early stopping, best iteration is:
# [5907]	valid_0's l2: 1.45353
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58413
# [2000]	valid_0's l2: 1.51832
# [3000]	valid_0's l2: 1.49845
# [4000]	valid_0's l2: 1.48924
# [5000]	valid_0's l2: 1.48421
# [6000]	valid_0's l2: 1.48113
# Early stopping, best iteration is:
# [6876]	valid_0's l2: 1.47842
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.62719
# [2000]	valid_0's l2: 1.55243
# [3000]	valid_0's l2: 1.53028
# [4000]	valid_0's l2: 1.52079
# [5000]	valid_0's l2: 1.51494
# Early stopping, best iteration is:
# [4958]	valid_0's l2: 1.51486
# =====================
# 5
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.59173
# [2000]	valid_0's l2: 6.37641
# [3000]	valid_0's l2: 6.31286
# [4000]	valid_0's l2: 6.27962
# [5000]	valid_0's l2: 6.26536
# Early stopping, best iteration is:
# [5761]	valid_0's l2: 6.2577
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.46859
# [2000]	valid_0's l2: 6.24436
# [3000]	valid_0's l2: 6.17535
# [4000]	valid_0's l2: 6.14694
# [5000]	valid_0's l2: 6.13199
# Early stopping, best iteration is:
# [5139]	valid_0's l2: 6.13017
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.55047
# [2000]	valid_0's l2: 6.34737
# [3000]	valid_0's l2: 6.28873
# [4000]	valid_0's l2: 6.26236
# Early stopping, best iteration is:
# [4442]	valid_0's l2: 6.25671
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.48977
# [2000]	valid_0's l2: 6.28396
# [3000]	valid_0's l2: 6.2195
# [4000]	valid_0's l2: 6.19255
# Early stopping, best iteration is:
# [4273]	valid_0's l2: 6.18804
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.34511
# [2000]	valid_0's l2: 6.17004
# [3000]	valid_0's l2: 6.12103
# [4000]	valid_0's l2: 6.10347
# Early stopping, best iteration is:
# [4297]	valid_0's l2: 6.0995
# =====================
# 6
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.15236
# [2000]	valid_0's l2: 7.8285
# [3000]	valid_0's l2: 7.71975
# [4000]	valid_0's l2: 7.66223
# [5000]	valid_0's l2: 7.63169
# [6000]	valid_0's l2: 7.61465
# [7000]	valid_0's l2: 7.60235
# Early stopping, best iteration is:
# [7478]	valid_0's l2: 7.59574
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.93114
# [2000]	valid_0's l2: 7.60544
# [3000]	valid_0's l2: 7.50582
# [4000]	valid_0's l2: 7.46164
# [5000]	valid_0's l2: 7.43549
# [6000]	valid_0's l2: 7.42348
# Early stopping, best iteration is:
# [6373]	valid_0's l2: 7.41972
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.1301
# [2000]	valid_0's l2: 7.76404
# [3000]	valid_0's l2: 7.66191
# [4000]	valid_0's l2: 7.61648
# [5000]	valid_0's l2: 7.59112
# Early stopping, best iteration is:
# [5334]	valid_0's l2: 7.58308
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.1745
# [2000]	valid_0's l2: 7.79775
# [3000]	valid_0's l2: 7.69329
# [4000]	valid_0's l2: 7.63727
# [5000]	valid_0's l2: 7.60028
# [6000]	valid_0's l2: 7.58039
# [7000]	valid_0's l2: 7.56074
# Early stopping, best iteration is:
# [7858]	valid_0's l2: 7.55266
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.88474
# [2000]	valid_0's l2: 7.60247
# [3000]	valid_0's l2: 7.52624
# [4000]	valid_0's l2: 7.48629
# Early stopping, best iteration is:
# [4568]	valid_0's l2: 7.47233
# =====================
# 7
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [725]	valid_0's l2: 0.935039
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.958861
# Early stopping, best iteration is:
# [1712]	valid_0's l2: 0.955096
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.94435
# [2000]	valid_0's l2: 0.940235
# Early stopping, best iteration is:
# [1921]	valid_0's l2: 0.940157
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.915465
# Early stopping, best iteration is:
# [1473]	valid_0's l2: 0.914456
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.908384
# Early stopping, best iteration is:
# [1500]	valid_0's l2: 0.906924
# =====================
# 8
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.60588
# Early stopping, best iteration is:
# [1811]	valid_0's l2: 0.604437
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.586249
# Early stopping, best iteration is:
# [1728]	valid_0's l2: 0.584475
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.598903
# [2000]	valid_0's l2: 0.596537
# Early stopping, best iteration is:
# [1946]	valid_0's l2: 0.596457
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.592697
# Early stopping, best iteration is:
# [1731]	valid_0's l2: 0.590923
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.605065
# Early stopping, best iteration is:
# [1744]	valid_0's l2: 0.603131
# =====================
# 9
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11492
# [2000]	valid_0's l2: 1.10805
# [3000]	valid_0's l2: 1.10556
# Early stopping, best iteration is:
# [3594]	valid_0's l2: 1.10434
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.12712
# [2000]	valid_0's l2: 1.11919
# Early stopping, best iteration is:
# [2201]	valid_0's l2: 1.11837
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10663
# [2000]	valid_0's l2: 1.09491
# [3000]	valid_0's l2: 1.09179
# Early stopping, best iteration is:
# [2904]	valid_0's l2: 1.09165
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10431
# [2000]	valid_0's l2: 1.09554
# Early stopping, best iteration is:
# [2153]	valid_0's l2: 1.0948
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11311
# [2000]	valid_0's l2: 1.10702
# Early stopping, best iteration is:
# [2438]	valid_0's l2: 1.10618
# =====================
# 10
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [507]	valid_0's l2: 0.691453
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [500]	valid_0's l2: 0.717847
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [597]	valid_0's l2: 0.705888
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [723]	valid_0's l2: 0.691472
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [783]	valid_0's l2: 0.708471
# =====================
# 11
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [587]	valid_0's l2: 1.33056
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [716]	valid_0's l2: 1.30319
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [741]	valid_0's l2: 1.28169
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [763]	valid_0's l2: 1.24391
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [602]	valid_0's l2: 1.305
# =====================
# 12
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.03178
# Early stopping, best iteration is:
# [1415]	valid_0's l2: 1.02982
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.04685
# Early stopping, best iteration is:
# [1256]	valid_0's l2: 1.04587
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.972642
# Early stopping, best iteration is:
# [1222]	valid_0's l2: 0.971356
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02132
# Early stopping, best iteration is:
# [1022]	valid_0's l2: 1.02117
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.00331
# Early stopping, best iteration is:
# [1425]	valid_0's l2: 1.00077
# =====================
# 13
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.16687
# Early stopping, best iteration is:
# [1708]	valid_0's l2: 1.16298
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.18731
# [2000]	valid_0's l2: 1.17862
# Early stopping, best iteration is:
# [2519]	valid_0's l2: 1.17747
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10697
# [2000]	valid_0's l2: 1.09236
# Early stopping, best iteration is:
# [2132]	valid_0's l2: 1.09153
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.09571
# Early stopping, best iteration is:
# [1696]	valid_0's l2: 1.0897
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05631
# Early stopping, best iteration is:
# [1499]	valid_0's l2: 1.05259
# =====================
# 14
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.8597
# [2000]	valid_0's l2: 13.5762
# [3000]	valid_0's l2: 13.4829
# [4000]	valid_0's l2: 13.4416
# [5000]	valid_0's l2: 13.4212
# Early stopping, best iteration is:
# [4972]	valid_0's l2: 13.4199
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.2873
# [2000]	valid_0's l2: 13.0263
# [3000]	valid_0's l2: 12.9573
# Early stopping, best iteration is:
# [3490]	valid_0's l2: 12.936
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.6584
# [2000]	valid_0's l2: 13.3804
# [3000]	valid_0's l2: 13.2961
# [4000]	valid_0's l2: 13.2669
# Early stopping, best iteration is:
# [3909]	valid_0's l2: 13.2653
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.5199
# [2000]	valid_0's l2: 13.2652
# [3000]	valid_0's l2: 13.1981
# [4000]	valid_0's l2: 13.1702
# Early stopping, best iteration is:
# [3965]	valid_0's l2: 13.1698
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.4124
# [2000]	valid_0's l2: 13.1792
# [3000]	valid_0's l2: 13.114
# Early stopping, best iteration is:
# [3705]	valid_0's l2: 13.0903
# =====================
# 15
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.01895
# [2000]	valid_0's l2: 4.95302
# Early stopping, best iteration is:
# [2378]	valid_0's l2: 4.94504
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.80489
# Early stopping, best iteration is:
# [968]	valid_0's l2: 4.80305
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [783]	valid_0's l2: 5.34814
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.87287
# [2000]	valid_0's l2: 4.82181
# Early stopping, best iteration is:
# [2726]	valid_0's l2: 4.81536
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.16483
# [2000]	valid_0's l2: 5.11272
# Early stopping, best iteration is:
# [2538]	valid_0's l2: 5.10348
# =====================
# 16
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.24282
# [2000]	valid_0's l2: 5.02636
# [3000]	valid_0's l2: 4.94421
# [4000]	valid_0's l2: 4.90791
# [5000]	valid_0's l2: 4.88237
# [6000]	valid_0's l2: 4.86647
# [7000]	valid_0's l2: 4.85693
# [8000]	valid_0's l2: 4.85162
# [9000]	valid_0's l2: 4.84442
# Early stopping, best iteration is:
# [9029]	valid_0's l2: 4.84387
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.37057
# [2000]	valid_0's l2: 5.14987
# [3000]	valid_0's l2: 5.06757
# [4000]	valid_0's l2: 5.02419
# [5000]	valid_0's l2: 5.00078
# [6000]	valid_0's l2: 4.98885
# [7000]	valid_0's l2: 4.97899
# Early stopping, best iteration is:
# [7443]	valid_0's l2: 4.97485
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.41434
# [2000]	valid_0's l2: 5.1854
# [3000]	valid_0's l2: 5.1011
# [4000]	valid_0's l2: 5.06447
# [5000]	valid_0's l2: 5.04288
# [6000]	valid_0's l2: 5.03165
# [7000]	valid_0's l2: 5.0231
# Early stopping, best iteration is:
# [7120]	valid_0's l2: 5.02212
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.37245
# [2000]	valid_0's l2: 5.14609
# [3000]	valid_0's l2: 5.0663
# [4000]	valid_0's l2: 5.02044
# [5000]	valid_0's l2: 4.99766
# [6000]	valid_0's l2: 4.98341
# [7000]	valid_0's l2: 4.97277
# Early stopping, best iteration is:
# [7835]	valid_0's l2: 4.96618
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.3181
# [2000]	valid_0's l2: 5.11706
# [3000]	valid_0's l2: 5.04233
# [4000]	valid_0's l2: 5.0096
# [5000]	valid_0's l2: 4.98996
# Early stopping, best iteration is:
# [5136]	valid_0's l2: 4.98837
# =====================
# 17
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.42182
# [2000]	valid_0's l2: 2.31937
# [3000]	valid_0's l2: 2.28609
# [4000]	valid_0's l2: 2.26802
# [5000]	valid_0's l2: 2.25641
# [6000]	valid_0's l2: 2.24889
# [7000]	valid_0's l2: 2.24462
# [8000]	valid_0's l2: 2.24102
# Early stopping, best iteration is:
# [8120]	valid_0's l2: 2.24068
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.47204
# [2000]	valid_0's l2: 2.36061
# [3000]	valid_0's l2: 2.32403
# [4000]	valid_0's l2: 2.30515
# [5000]	valid_0's l2: 2.29586
# [6000]	valid_0's l2: 2.28898
# Early stopping, best iteration is:
# [6318]	valid_0's l2: 2.28752
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.49962
# [2000]	valid_0's l2: 2.40031
# [3000]	valid_0's l2: 2.37175
# [4000]	valid_0's l2: 2.35655
# [5000]	valid_0's l2: 2.34709
# [6000]	valid_0's l2: 2.34105
# [7000]	valid_0's l2: 2.33712
# Early stopping, best iteration is:
# [7143]	valid_0's l2: 2.33663
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.46822
# [2000]	valid_0's l2: 2.37174
# [3000]	valid_0's l2: 2.33554
# [4000]	valid_0's l2: 2.31842
# [5000]	valid_0's l2: 2.30944
# [6000]	valid_0's l2: 2.30255
# [7000]	valid_0's l2: 2.29841
# [8000]	valid_0's l2: 2.29427
# Early stopping, best iteration is:
# [8306]	valid_0's l2: 2.29287
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.53145
# [2000]	valid_0's l2: 2.42536
# [3000]	valid_0's l2: 2.38873
# [4000]	valid_0's l2: 2.37205
# [5000]	valid_0's l2: 2.3614
# [6000]	valid_0's l2: 2.35431
# [7000]	valid_0's l2: 2.35045
# Early stopping, best iteration is:
# [7207]	valid_0's l2: 2.34962
# =====================
# 18
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.06881
# [2000]	valid_0's l2: 4.00023
# [3000]	valid_0's l2: 3.97386
# [4000]	valid_0's l2: 3.96086
# Early stopping, best iteration is:
# [4257]	valid_0's l2: 3.9585
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.93877
# [2000]	valid_0's l2: 3.86557
# [3000]	valid_0's l2: 3.84326
# [4000]	valid_0's l2: 3.83639
# Early stopping, best iteration is:
# [4505]	valid_0's l2: 3.83288
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.04474
# [2000]	valid_0's l2: 3.95623
# [3000]	valid_0's l2: 3.93189
# [4000]	valid_0's l2: 3.92449
# [5000]	valid_0's l2: 3.91695
# Early stopping, best iteration is:
# [4986]	valid_0's l2: 3.91673
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.08346
# [2000]	valid_0's l2: 4.00835
# [3000]	valid_0's l2: 3.98537
# Early stopping, best iteration is:
# [3333]	valid_0's l2: 3.98174
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.06999
# [2000]	valid_0's l2: 3.99898
# [3000]	valid_0's l2: 3.97292
# [4000]	valid_0's l2: 3.96352
# Early stopping, best iteration is:
# [4306]	valid_0's l2: 3.95984
# =====================
# 19
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.78921
# [2000]	valid_0's l2: 3.75854
# Early stopping, best iteration is:
# [2063]	valid_0's l2: 3.75664
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.02581
# [2000]	valid_0's l2: 3.98023
# Early stopping, best iteration is:
# [2153]	valid_0's l2: 3.9777
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.8137
# [2000]	valid_0's l2: 3.78487
# Early stopping, best iteration is:
# [2676]	valid_0's l2: 3.776
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [523]	valid_0's l2: 3.82507
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.21834
# [2000]	valid_0's l2: 4.1797
# Early stopping, best iteration is:
# [2299]	valid_0's l2: 4.17631
# =====================
# 20
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.712037
# Early stopping, best iteration is:
# [1802]	valid_0's l2: 0.708282
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.700686
# Early stopping, best iteration is:
# [1835]	valid_0's l2: 0.697655
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.710236
# [2000]	valid_0's l2: 0.70618
# Early stopping, best iteration is:
# [2451]	valid_0's l2: 0.705566
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.708645
# [2000]	valid_0's l2: 0.705742
# Early stopping, best iteration is:
# [1989]	valid_0's l2: 0.705739
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.686996
# Early stopping, best iteration is:
# [1874]	valid_0's l2: 0.683496
# =====================
# 21
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.90821
# [2000]	valid_0's l2: 1.84777
# [3000]	valid_0's l2: 1.83091
# [4000]	valid_0's l2: 1.82421
# [5000]	valid_0's l2: 1.82104
# Early stopping, best iteration is:
# [5485]	valid_0's l2: 1.81921
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.95286
# [2000]	valid_0's l2: 1.88652
# [3000]	valid_0's l2: 1.86706
# [4000]	valid_0's l2: 1.85764
# [5000]	valid_0's l2: 1.85318
# Early stopping, best iteration is:
# [5673]	valid_0's l2: 1.8506
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.92745
# [2000]	valid_0's l2: 1.86335
# [3000]	valid_0's l2: 1.84801
# [4000]	valid_0's l2: 1.84015
# [5000]	valid_0's l2: 1.83459
# Early stopping, best iteration is:
# [5755]	valid_0's l2: 1.83218
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.88683
# [2000]	valid_0's l2: 1.82056
# [3000]	valid_0's l2: 1.80286
# [4000]	valid_0's l2: 1.79522
# [5000]	valid_0's l2: 1.79153
# Early stopping, best iteration is:
# [5776]	valid_0's l2: 1.78931
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.92374
# [2000]	valid_0's l2: 1.86437
# [3000]	valid_0's l2: 1.84864
# [4000]	valid_0's l2: 1.83959
# [5000]	valid_0's l2: 1.83593
# Early stopping, best iteration is:
# [4954]	valid_0's l2: 1.83591
# =====================
# 22
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [654]	valid_0's l2: 1.09946
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [674]	valid_0's l2: 1.08706
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [473]	valid_0's l2: 1.03693
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [522]	valid_0's l2: 0.996461
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [612]	valid_0's l2: 1.03001
# =====================
# 23
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.27265
# [2000]	valid_0's l2: 1.26383
# Early stopping, best iteration is:
# [2046]	valid_0's l2: 1.26356
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.31797
# [2000]	valid_0's l2: 1.30968
# Early stopping, best iteration is:
# [2468]	valid_0's l2: 1.30715
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.31388
# [2000]	valid_0's l2: 1.30442
# Early stopping, best iteration is:
# [2704]	valid_0's l2: 1.30151
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.32374
# [2000]	valid_0's l2: 1.31674
# Early stopping, best iteration is:
# [2440]	valid_0's l2: 1.31568
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.27724
# [2000]	valid_0's l2: 1.26842
# Early stopping, best iteration is:
# [1929]	valid_0's l2: 1.26802
# =====================
# 24
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.95225
# [2000]	valid_0's l2: 9.70319
# [3000]	valid_0's l2: 9.61221
# [4000]	valid_0's l2: 9.57097
# Early stopping, best iteration is:
# [4893]	valid_0's l2: 9.54788
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.84621
# [2000]	valid_0's l2: 9.58378
# [3000]	valid_0's l2: 9.49172
# [4000]	valid_0's l2: 9.45141
# [5000]	valid_0's l2: 9.4248
# Early stopping, best iteration is:
# [5265]	valid_0's l2: 9.42137
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 10.0777
# [2000]	valid_0's l2: 9.8003
# [3000]	valid_0's l2: 9.71666
# [4000]	valid_0's l2: 9.67705
# [5000]	valid_0's l2: 9.65966
# Early stopping, best iteration is:
# [5153]	valid_0's l2: 9.65862
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.91084
# [2000]	valid_0's l2: 9.68238
# [3000]	valid_0's l2: 9.6123
# [4000]	valid_0's l2: 9.57307
# Early stopping, best iteration is:
# [4628]	valid_0's l2: 9.55488
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.8684
# [2000]	valid_0's l2: 9.62176
# [3000]	valid_0's l2: 9.53053
# [4000]	valid_0's l2: 9.4947
# [5000]	valid_0's l2: 9.47543
# Early stopping, best iteration is:
# [4952]	valid_0's l2: 9.47463
# =====================
# 25
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [546]	valid_0's l2: 0.901306
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [800]	valid_0's l2: 0.887559
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [823]	valid_0's l2: 0.878498
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.87871
# Early stopping, best iteration is:
# [981]	valid_0's l2: 0.878574
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.901172
# Early stopping, best iteration is:
# [1139]	valid_0's l2: 0.900703
# =====================
# 26
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [424]	valid_0's l2: 0.800089
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [512]	valid_0's l2: 0.799198
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [429]	valid_0's l2: 0.817824
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [654]	valid_0's l2: 0.787515
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [499]	valid_0's l2: 0.834061
# =====================
# 27
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [696]	valid_0's l2: 0.766221
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [780]	valid_0's l2: 0.771446
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.788094
# Early stopping, best iteration is:
# [1085]	valid_0's l2: 0.787788
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [717]	valid_0's l2: 0.740775
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.760001
# Early stopping, best iteration is:
# [1002]	valid_0's l2: 0.759994
# =====================
# 28
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.606655
# Early stopping, best iteration is:
# [1729]	valid_0's l2: 0.605155
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.60263
# Early stopping, best iteration is:
# [1867]	valid_0's l2: 0.600352
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.599844
# Early stopping, best iteration is:
# [1734]	valid_0's l2: 0.597966
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.601627
# Early stopping, best iteration is:
# [1514]	valid_0's l2: 0.600413
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.596362
# [2000]	valid_0's l2: 0.593407
# Early stopping, best iteration is:
# [2133]	valid_0's l2: 0.593143
# =====================
# 29
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.564726
# Early stopping, best iteration is:
# [1390]	valid_0's l2: 0.564079
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.571582
# Early stopping, best iteration is:
# [1507]	valid_0's l2: 0.570465
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.559772
# Early stopping, best iteration is:
# [1555]	valid_0's l2: 0.558216
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.567072
# Early stopping, best iteration is:
# [1089]	valid_0's l2: 0.566886
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.558139
# Early stopping, best iteration is:
# [1775]	valid_0's l2: 0.556715
# =====================
# 30
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.6574
# Early stopping, best iteration is:
# [1037]	valid_0's l2: 0.657265
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.630136
# Early stopping, best iteration is:
# [1041]	valid_0's l2: 0.630032
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.642832
# Early stopping, best iteration is:
# [1094]	valid_0's l2: 0.642689
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.630369
# Early stopping, best iteration is:
# [1102]	valid_0's l2: 0.630216
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.635833
# Early stopping, best iteration is:
# [1135]	valid_0's l2: 0.635789
# =====================
# 31
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.690545
# Early stopping, best iteration is:
# [904]	valid_0's l2: 0.690486
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.673229
# Early stopping, best iteration is:
# [946]	valid_0's l2: 0.673166
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.687067
# Early stopping, best iteration is:
# [997]	valid_0's l2: 0.68704
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.669421
# Early stopping, best iteration is:
# [1176]	valid_0's l2: 0.669098
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [797]	valid_0's l2: 0.666448
# =====================
# 32
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [778]	valid_0's l2: 0.587365
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.58197
# Early stopping, best iteration is:
# [955]	valid_0's l2: 0.581937
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [849]	valid_0's l2: 0.578028
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [635]	valid_0's l2: 0.583592
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [856]	valid_0's l2: 0.571046
# =====================
# 33
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [669]	valid_0's l2: 0.584941
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [865]	valid_0's l2: 0.608425
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.593546
# Early stopping, best iteration is:
# [952]	valid_0's l2: 0.593442
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [655]	valid_0's l2: 0.594048
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [564]	valid_0's l2: 0.584996
# =====================
# 34
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [570]	valid_0's l2: 0.848855
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.864466
# Early stopping, best iteration is:
# [1043]	valid_0's l2: 0.864413
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [855]	valid_0's l2: 0.856278
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.856452
# Early stopping, best iteration is:
# [958]	valid_0's l2: 0.856366
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.838885
# Early stopping, best iteration is:
# [987]	valid_0's l2: 0.838803
# =====================
# 35
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [718]	valid_0's l2: 0.742659
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.773754
# Early stopping, best iteration is:
# [1223]	valid_0's l2: 0.772913
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.746729
# [2000]	valid_0's l2: 0.74369
# Early stopping, best iteration is:
# [2248]	valid_0's l2: 0.743536
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.696014
# Early stopping, best iteration is:
# [1173]	valid_0's l2: 0.695949
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [764]	valid_0's l2: 0.707024
# =====================
# 36
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.891334
# Early stopping, best iteration is:
# [1456]	valid_0's l2: 0.890285
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.875837
# Early stopping, best iteration is:
# [1254]	valid_0's l2: 0.875183
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.912158
# Early stopping, best iteration is:
# [1078]	valid_0's l2: 0.911928
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.876573
# Early stopping, best iteration is:
# [1481]	valid_0's l2: 0.875617
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.871984
# Early stopping, best iteration is:
# [1343]	valid_0's l2: 0.871269
# =====================
# 37
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 18.0258
# [2000]	valid_0's l2: 17.5684
# [3000]	valid_0's l2: 17.406
# [4000]	valid_0's l2: 17.3458
# Early stopping, best iteration is:
# [3945]	valid_0's l2: 17.3437
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.6763
# [2000]	valid_0's l2: 17.1955
# [3000]	valid_0's l2: 17.0481
# [4000]	valid_0's l2: 16.9809
# Early stopping, best iteration is:
# [4638]	valid_0's l2: 16.9542
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.6959
# [2000]	valid_0's l2: 17.2426
# [3000]	valid_0's l2: 17.1319
# [4000]	valid_0's l2: 17.0867
# Early stopping, best iteration is:
# [4681]	valid_0's l2: 17.0599
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.5398
# [2000]	valid_0's l2: 17.1436
# [3000]	valid_0's l2: 17.0279
# Early stopping, best iteration is:
# [3852]	valid_0's l2: 16.9907
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.7255
# [2000]	valid_0's l2: 17.3246
# [3000]	valid_0's l2: 17.2118
# [4000]	valid_0's l2: 17.1574
# [5000]	valid_0's l2: 17.1383
# Early stopping, best iteration is:
# [4962]	valid_0's l2: 17.1374
# =====================
# 38
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.741724
# Early stopping, best iteration is:
# [954]	valid_0's l2: 0.741638
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.74636
# Early stopping, best iteration is:
# [1211]	valid_0's l2: 0.745583
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.757744
# Early stopping, best iteration is:
# [1540]	valid_0's l2: 0.756483
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.732064
# Early stopping, best iteration is:
# [1565]	valid_0's l2: 0.730906
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.760552
# Early stopping, best iteration is:
# [1373]	valid_0's l2: 0.759641
# =====================
# 39
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.43686
# Early stopping, best iteration is:
# [905]	valid_0's l2: 1.43681
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [629]	valid_0's l2: 1.41325
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.40803
# Early stopping, best iteration is:
# [919]	valid_0's l2: 1.40782
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [680]	valid_0's l2: 1.46923
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [846]	valid_0's l2: 1.49567
# =====================
# 40
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [714]	valid_0's l2: 0.824567
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.801968
# Early stopping, best iteration is:
# [1277]	valid_0's l2: 0.801534
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.938107
# Early stopping, best iteration is:
# [1162]	valid_0's l2: 0.937892
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.824986
# Early stopping, best iteration is:
# [1289]	valid_0's l2: 0.824353
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.894736
# Early stopping, best iteration is:
# [1088]	valid_0's l2: 0.894392
# =====================
# 41
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [736]	valid_0's l2: 0.962917
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [876]	valid_0's l2: 1.00261
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [855]	valid_0's l2: 0.942553
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.9758
# Early stopping, best iteration is:
# [1057]	valid_0's l2: 0.975485
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.990501
# Early stopping, best iteration is:
# [1352]	valid_0's l2: 0.989494
# =====================
# 42
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.842785
# Early stopping, best iteration is:
# [923]	valid_0's l2: 0.842735
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [860]	valid_0's l2: 0.82655
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.847934
# Early stopping, best iteration is:
# [1144]	valid_0's l2: 0.847875
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.81929
# Early stopping, best iteration is:
# [1276]	valid_0's l2: 0.818779
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.831044
# Early stopping, best iteration is:
# [1534]	valid_0's l2: 0.829479
# =====================
# 43
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.93583
# [2000]	valid_0's l2: 5.64686
# [3000]	valid_0's l2: 5.55939
# [4000]	valid_0's l2: 5.51824
# [5000]	valid_0's l2: 5.49583
# [6000]	valid_0's l2: 5.48366
# Early stopping, best iteration is:
# [6161]	valid_0's l2: 5.48255
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.14067
# [2000]	valid_0's l2: 5.83016
# [3000]	valid_0's l2: 5.72394
# [4000]	valid_0's l2: 5.67825
# [5000]	valid_0's l2: 5.6504
# [6000]	valid_0's l2: 5.6339
# [7000]	valid_0's l2: 5.62264
# Early stopping, best iteration is:
# [6972]	valid_0's l2: 5.62214
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.04166
# [2000]	valid_0's l2: 5.73422
# [3000]	valid_0's l2: 5.64896
# [4000]	valid_0's l2: 5.61116
# [5000]	valid_0's l2: 5.59222
# [6000]	valid_0's l2: 5.581
# Early stopping, best iteration is:
# [6240]	valid_0's l2: 5.57864
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.13883
# [2000]	valid_0's l2: 5.83648
# [3000]	valid_0's l2: 5.75637
# [4000]	valid_0's l2: 5.71944
# [5000]	valid_0's l2: 5.69839
# [6000]	valid_0's l2: 5.68594
# Early stopping, best iteration is:
# [6256]	valid_0's l2: 5.68311
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.1008
# [2000]	valid_0's l2: 5.76702
# [3000]	valid_0's l2: 5.66453
# [4000]	valid_0's l2: 5.61791
# [5000]	valid_0's l2: 5.59639
# Early stopping, best iteration is:
# [5845]	valid_0's l2: 5.58739
# =====================
# 44
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.741201
# Early stopping, best iteration is:
# [1019]	valid_0's l2: 0.741183
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.737853
# Early stopping, best iteration is:
# [1262]	valid_0's l2: 0.737519
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.727098
# Early stopping, best iteration is:
# [1210]	valid_0's l2: 0.72675
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.737964
# Early stopping, best iteration is:
# [1316]	valid_0's l2: 0.737207
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.712913
# Early stopping, best iteration is:
# [1145]	valid_0's l2: 0.712388
# =====================
# 45
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.68227
# Early stopping, best iteration is:
# [1243]	valid_0's l2: 0.681999
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.681081
# Early stopping, best iteration is:
# [1004]	valid_0's l2: 0.681069
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.671318
# Early stopping, best iteration is:
# [1110]	valid_0's l2: 0.671158
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.673173
# Early stopping, best iteration is:
# [937]	valid_0's l2: 0.672983
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [785]	valid_0's l2: 0.656
# =====================
# 46
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.59117
# Early stopping, best iteration is:
# [1427]	valid_0's l2: 1.58792
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.60068
# Early stopping, best iteration is:
# [1594]	valid_0's l2: 1.5973
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.60934
# Early stopping, best iteration is:
# [1278]	valid_0's l2: 1.60751
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.64964
# Early stopping, best iteration is:
# [1794]	valid_0's l2: 1.64232
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.64554
# Early stopping, best iteration is:
# [1841]	valid_0's l2: 1.64057
# =====================
# 47
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.06959
# Early stopping, best iteration is:
# [1493]	valid_0's l2: 1.06847
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.12201
# Early stopping, best iteration is:
# [1765]	valid_0's l2: 1.11696
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07973
# Early stopping, best iteration is:
# [1782]	valid_0's l2: 1.07569
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11332
# Early stopping, best iteration is:
# [1664]	valid_0's l2: 1.10856
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11533
# [2000]	valid_0's l2: 1.10778
# Early stopping, best iteration is:
# [2774]	valid_0's l2: 1.106
# =====================
# 48
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.32912
# [2000]	valid_0's l2: 8.01473
# [3000]	valid_0's l2: 7.91668
# [4000]	valid_0's l2: 7.86636
# [5000]	valid_0's l2: 7.84503
# [6000]	valid_0's l2: 7.82677
# Early stopping, best iteration is:
# [6731]	valid_0's l2: 7.81842
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.30877
# [2000]	valid_0's l2: 7.94253
# [3000]	valid_0's l2: 7.80813
# ...
# [636]	valid_0's l2: 1.11872
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [559]	valid_0's l2: 1.13952
# =====================
# 124
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.888377
# Early stopping, best iteration is:
# [1013]	valid_0's l2: 0.888351
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.904226
# Early stopping, best iteration is:
# [1146]	valid_0's l2: 0.904
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.899475
# Early stopping, best iteration is:
# [948]	valid_0's l2: 0.899334
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.874904
# Early stopping, best iteration is:
# [1242]	valid_0's l2: 0.87415
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.904765
# Early stopping, best iteration is:
# [1047]	valid_0's l2: 0.904719
# =====================
# 125
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.894393
# Early stopping, best iteration is:
# [985]	valid_0's l2: 0.894337
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.877323
# Early stopping, best iteration is:
# [924]	valid_0's l2: 0.877145
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.882757
# Early stopping, best iteration is:
# [1131]	valid_0's l2: 0.882536
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.851303
# Early stopping, best iteration is:
# [1440]	valid_0's l2: 0.85064
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.87632
# Early stopping, best iteration is:
# [1113]	valid_0's l2: 0.876088
# =====================
# 126
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [783]	valid_0's l2: 0.789427
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [645]	valid_0's l2: 0.78651
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [806]	valid_0's l2: 0.764155
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [649]	valid_0's l2: 0.785553
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [634]	valid_0's l2: 0.783164
# =====================
# 127
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.0121
# Early stopping, best iteration is:
# [1863]	valid_0's l2: 1.00698
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05753
# [2000]	valid_0's l2: 1.05118
# Early stopping, best iteration is:
# [2034]	valid_0's l2: 1.05116
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.04278
# [2000]	valid_0's l2: 1.03579
# Early stopping, best iteration is:
# [1937]	valid_0's l2: 1.03566
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.01695
# [2000]	valid_0's l2: 1.0094
# [3000]	valid_0's l2: 1.00729
# Early stopping, best iteration is:
# [3062]	valid_0's l2: 1.00707
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.04048
# [2000]	valid_0's l2: 1.03439
# Early stopping, best iteration is:
# [1936]	valid_0's l2: 1.03428
# =====================
# 128
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [844]	valid_0's l2: 0.761984
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.75746
# Early stopping, best iteration is:
# [1016]	valid_0's l2: 0.757343
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.771009
# Early stopping, best iteration is:
# [1240]	valid_0's l2: 0.770629
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [649]	valid_0's l2: 0.737085
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.744598
# Early stopping, best iteration is:
# [1014]	valid_0's l2: 0.74449
# =====================
# 129
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [896]	valid_0's l2: 0.847298
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.828702
# Early stopping, best iteration is:
# [1831]	valid_0's l2: 0.825334
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.808065
# Early stopping, best iteration is:
# [1418]	valid_0's l2: 0.805393
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.819652
# Early stopping, best iteration is:
# [1356]	valid_0's l2: 0.817756
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.801324
# Early stopping, best iteration is:
# [1272]	valid_0's l2: 0.800449
# =====================
# 130
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.659017
# Early stopping, best iteration is:
# [1163]	valid_0's l2: 0.65879
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.663876
# Early stopping, best iteration is:
# [1146]	valid_0's l2: 0.663679
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.666492
# Early stopping, best iteration is:
# [1179]	valid_0's l2: 0.666248
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.65973
# Early stopping, best iteration is:
# [1175]	valid_0's l2: 0.659506
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.661164
# Early stopping, best iteration is:
# [1163]	valid_0's l2: 0.660796
# =====================
# 131
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.96222
# [2000]	valid_0's l2: 5.80827
# [3000]	valid_0's l2: 5.76141
# [4000]	valid_0's l2: 5.74098
# Early stopping, best iteration is:
# [4336]	valid_0's l2: 5.73744
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.96506
# [2000]	valid_0's l2: 5.81039
# [3000]	valid_0's l2: 5.76771
# [4000]	valid_0's l2: 5.74112
# [5000]	valid_0's l2: 5.73132
# Early stopping, best iteration is:
# [4941]	valid_0's l2: 5.7309
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.06528
# [2000]	valid_0's l2: 5.89517
# [3000]	valid_0's l2: 5.85218
# [4000]	valid_0's l2: 5.82949
# [5000]	valid_0's l2: 5.81686
# Early stopping, best iteration is:
# [5446]	valid_0's l2: 5.81312
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.94193
# [2000]	valid_0's l2: 5.78764
# [3000]	valid_0's l2: 5.7422
# [4000]	valid_0's l2: 5.72419
# Early stopping, best iteration is:
# [4855]	valid_0's l2: 5.71069
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.94091
# [2000]	valid_0's l2: 5.77707
# [3000]	valid_0's l2: 5.72703
# [4000]	valid_0's l2: 5.70273
# [5000]	valid_0's l2: 5.68812
# [6000]	valid_0's l2: 5.68112
# Early stopping, best iteration is:
# [6412]	valid_0's l2: 5.6778
# =====================
# 132
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02667
# Early stopping, best iteration is:
# [1447]	valid_0's l2: 1.02432
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02988
# [2000]	valid_0's l2: 1.02615
# Early stopping, best iteration is:
# [2141]	valid_0's l2: 1.02588
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.0076
# [2000]	valid_0's l2: 1.00492
# Early stopping, best iteration is:
# [1926]	valid_0's l2: 1.00476
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.01295
# Early stopping, best iteration is:
# [1556]	valid_0's l2: 1.01076
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02775
# Early stopping, best iteration is:
# [1680]	valid_0's l2: 1.02504
# =====================
# 133
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.502247
# [2000]	valid_0's l2: 0.501211
# Early stopping, best iteration is:
# [2046]	valid_0's l2: 0.501127
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.487079
# Early stopping, best iteration is:
# [1595]	valid_0's l2: 0.485809
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.484045
# Early stopping, best iteration is:
# [1697]	valid_0's l2: 0.482702
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.481897
# [2000]	valid_0's l2: 0.480374
# Early stopping, best iteration is:
# [1922]	valid_0's l2: 0.480334
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.487608
# Early stopping, best iteration is:
# [1832]	valid_0's l2: 0.486247
# =====================
# 134
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [731]	valid_0's l2: 2.39384
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [329]	valid_0's l2: 2.15243
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.18647
# Early stopping, best iteration is:
# [1191]	valid_0's l2: 2.18343
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.90939
# Early stopping, best iteration is:
# [1492]	valid_0's l2: 1.9043
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.81914
# Early stopping, best iteration is:
# [998]	valid_0's l2: 1.81913
# =====================
# 135
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.761418
# Early stopping, best iteration is:
# [1524]	valid_0's l2: 0.760228
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.778718
# Early stopping, best iteration is:
# [1482]	valid_0's l2: 0.777597
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.772537
# Early stopping, best iteration is:
# [1303]	valid_0's l2: 0.771452
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.760558
# Early stopping, best iteration is:
# [1045]	valid_0's l2: 0.76044
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.774007
# Early stopping, best iteration is:
# [1588]	valid_0's l2: 0.772372
# =====================
# 136
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.52627
# [2000]	valid_0's l2: 3.34651
# [3000]	valid_0's l2: 3.27884
# [4000]	valid_0's l2: 3.24455
# [5000]	valid_0's l2: 3.22701
# [6000]	valid_0's l2: 3.21295
# [7000]	valid_0's l2: 3.20496
# [8000]	valid_0's l2: 3.19788
# [9000]	valid_0's l2: 3.1927
# Early stopping, best iteration is:
# [8934]	valid_0's l2: 3.19244
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.54672
# [2000]	valid_0's l2: 3.35449
# [3000]	valid_0's l2: 3.28201
# [4000]	valid_0's l2: 3.24751
# [5000]	valid_0's l2: 3.22995
# [6000]	valid_0's l2: 3.21802
# [7000]	valid_0's l2: 3.20973
# Early stopping, best iteration is:
# [7461]	valid_0's l2: 3.20697
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.62087
# [2000]	valid_0's l2: 3.42598
# [3000]	valid_0's l2: 3.35946
# [4000]	valid_0's l2: 3.32542
# [5000]	valid_0's l2: 3.30766
# [6000]	valid_0's l2: 3.29611
# Early stopping, best iteration is:
# [6409]	valid_0's l2: 3.2927
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.50163
# [2000]	valid_0's l2: 3.32942
# [3000]	valid_0's l2: 3.26543
# [4000]	valid_0's l2: 3.23103
# [5000]	valid_0's l2: 3.21257
# [6000]	valid_0's l2: 3.19835
# [7000]	valid_0's l2: 3.19154
# [8000]	valid_0's l2: 3.18679
# Early stopping, best iteration is:
# [8014]	valid_0's l2: 3.18662
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.51328
# [2000]	valid_0's l2: 3.34737
# [3000]	valid_0's l2: 3.2849
# [4000]	valid_0's l2: 3.25359
# [5000]	valid_0's l2: 3.23387
# [6000]	valid_0's l2: 3.22252
# [7000]	valid_0's l2: 3.21462
# Early stopping, best iteration is:
# [7852]	valid_0's l2: 3.21073
# =====================
# 137
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05867
# Early stopping, best iteration is:
# [1692]	valid_0's l2: 1.05636
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.06306
# Early stopping, best iteration is:
# [1415]	valid_0's l2: 1.06171
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07426
# Early stopping, best iteration is:
# [1409]	valid_0's l2: 1.07204
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07159
# Early stopping, best iteration is:
# [1607]	valid_0's l2: 1.06932
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10783
# Early stopping, best iteration is:
# [1886]	valid_0's l2: 1.10319
# =====================
# 138
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.34651
# [2000]	valid_0's l2: 2.29881
# [3000]	valid_0's l2: 2.28712
# Early stopping, best iteration is:
# [3428]	valid_0's l2: 2.28542
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.19013
# [2000]	valid_0's l2: 2.14069
# [3000]	valid_0's l2: 2.12644
# Early stopping, best iteration is:
# [3696]	valid_0's l2: 2.12125
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.47626
# [2000]	valid_0's l2: 2.42469
# [3000]	valid_0's l2: 2.41288
# [4000]	valid_0's l2: 2.40756
# [5000]	valid_0's l2: 2.40437
# Early stopping, best iteration is:
# [5492]	valid_0's l2: 2.40287
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.11062
# [2000]	valid_0's l2: 2.06048
# [3000]	valid_0's l2: 2.04991
# [4000]	valid_0's l2: 2.04482
# Early stopping, best iteration is:
# [4521]	valid_0's l2: 2.04267
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.46277
# [2000]	valid_0's l2: 2.4099
# [3000]	valid_0's l2: 2.39596
# [4000]	valid_0's l2: 2.38974
# Early stopping, best iteration is:
# [4168]	valid_0's l2: 2.3887
# =====================
# 139
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.92097
# [2000]	valid_0's l2: 3.85531
# [3000]	valid_0's l2: 3.83886
# Early stopping, best iteration is:
# [3606]	valid_0's l2: 3.83323
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.92794
# [2000]	valid_0's l2: 3.86554
# [3000]	valid_0's l2: 3.84414
# Early stopping, best iteration is:
# [3799]	valid_0's l2: 3.8342
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.91748
# [2000]	valid_0's l2: 3.86628
# Early stopping, best iteration is:
# [2818]	valid_0's l2: 3.85543
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.87922
# [2000]	valid_0's l2: 3.82729
# [3000]	valid_0's l2: 3.81619
# Early stopping, best iteration is:
# [3186]	valid_0's l2: 3.81535
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.96421
# [2000]	valid_0's l2: 3.90873
# [3000]	valid_0's l2: 3.8944
# Early stopping, best iteration is:
# [3564]	valid_0's l2: 3.88869
# CPU times: total: 95d 15min 3s
# Wall time: 2d 8h 32min 54s

# %%
def correlation_score(y_true, y_pred):
    """Scores the predictions according to the competition rules. 
    
    It is assumed that the predictions are not constant.
    
    Returns the average of each sample's Pearson correlation coefficient"""
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

oof_preds = np.zeros((len(train_df), 140))
for n in range(len(train_preds)):
    oof_preds[:,n] =  train_preds[n]
    
cv = correlation_score(train_cite_y, oof_preds)
print (cv)

sub_preds = np.zeros((len(test_df), 140))
for n in range(len(test_preds)):
    sub_preds[:,n] =  test_preds[n]  

lgb1 = np.concatenate([oof_preds,sub_preds],axis=0)

tsvd = TruncatedSVD(n_components=100, algorithm='arpack')
lgb1_svd = tsvd.fit_transform(lgb1)
np.save(feature_path+'cite_lgb1_svd_100.npy', lgb1_svd)
# Out:
# 0.9023621111047389

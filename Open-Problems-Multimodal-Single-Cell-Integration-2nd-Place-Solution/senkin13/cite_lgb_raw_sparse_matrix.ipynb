# %%
# %%time
import pandas as pd
import numpy as np
import gc
import os
import random
import pickle
from sklearn.model_selection import StratifiedKFold,KFold
from scipy.sparse import hstack,vstack,csr_matrix,save_npz,load_npz
from sklearn.decomposition import TruncatedSVD
import lightgbm as lgb

############################################################################
#----- work folder -----
############################################################################
settings = json.load(open('./settings.json'))

input_path = settings['input_path']
features_path = settings['features_path']
model_path = settings['model_path']
sub_path = settings['sub_path']
# Out:
# c:\users\senki\appdata\local\programs\python\python38\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# CPU times: total: 2.34 s
# Wall time: 10.1 s

# %% [markdown]
# # load raw count csr_matrix

# %%
# %%time 

train_df = pd.read_feather(feature_path+'train_cite_inputs_id.feather')
test_df = pd.read_feather(feature_path+'test_cite_inputs_id.feather')

cite_inputs_sparse = load_npz(feature_path+"cite_inputs_raw_sparse.npz")

train_cite_X = cite_inputs_sparse[:len(train_df)]
test_cite_X = cite_inputs_sparse[len(train_df):]
train_cite_y = np.load(feature_path+'train_cite_targets.npy')
# Out:
# CPU times: total: 15.4 s
# Wall time: 15.9 s

# %%
train_cite_X.shape,test_cite_X.shape,train_cite_y.shape,cite_inputs_sparse.shape
# Out:
# ((70988, 22085), (48203, 22085), (70988, 140), (119191, 22085))

# %% [markdown]
# # model

# %%
# %%time

# ====================================================
# lightgbm
# ====================================================
def lgb_kfold(train_df, test_df, train_cite_X, train_cite_y, test_cite_X, folds):
    params = {    
        'objective' : 'rmse',
        'metric' : 'mse', 
         'num_leaves': 33,
         'min_data_in_leaf': 30,
         'learning_rate': 0.01,
         'max_depth': 7,
         "boosting": "gbdt",
         "feature_fraction": 0.08,
         "bagging_freq": 1,
         "bagging_fraction": 0.9,
         "bagging_seed": 42,
         "verbosity": -1,        
                 }      
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(48203)
    cv_corr = []
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df)): 
        print ('n_fold:',n_fold)
        train_x = train_cite_X[train_idx]
        valid_x = train_cite_X[valid_idx]
        train_y = train_cite_y[train_idx]
        valid_y = train_cite_y[valid_idx]

        dtrain = lgb.Dataset(
            train_x, label=train_y,)
        dval = lgb.Dataset(
            valid_x, label=valid_y, reference=dtrain,)
        bst = lgb.train(
            params, dtrain, num_boost_round=10000,
            valid_sets=[dval],verbose_eval=1000, early_stopping_rounds=100,
        )

        oof_preds[valid_idx] = bst.predict(valid_x, num_iteration=bst.best_iteration)
        sub_preds += bst.predict(test_cite_X, num_iteration=bst.best_iteration) / folds.n_splits         
        
    return oof_preds,sub_preds
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
seed = 666
folds = KFold(n_splits= 5, shuffle=True, random_state=seed)  
train_preds = []
test_preds = []
for i in range(140):
    print('=====================')
    print(i)
    train_cite_y_single = train_cite_y[:,i]
    oof_preds,sub_preds = lgb_kfold(train_df, test_df, train_cite_X, train_cite_y_single, test_cite_X, folds)
    train_preds.append(oof_preds)
    test_preds.append(sub_preds)
# Out:
# =====================
# 0
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.50297
# Early stopping, best iteration is:
# [1579]	valid_0's l2: 1.49647
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.51522
# Early stopping, best iteration is:
# [1866]	valid_0's l2: 1.50743
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58961
# Early stopping, best iteration is:
# [1709]	valid_0's l2: 1.5834
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58538
# [2000]	valid_0's l2: 1.57246
# Early stopping, best iteration is:
# [2740]	valid_0's l2: 1.57002
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.50283
# Early stopping, best iteration is:
# [1796]	valid_0's l2: 1.4968
# =====================
# 1
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [767]	valid_0's l2: 0.748087
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [763]	valid_0's l2: 0.743112
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [846]	valid_0's l2: 0.740357
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [802]	valid_0's l2: 0.726478
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [889]	valid_0's l2: 0.72218
# =====================
# 2
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.731258
# Early stopping, best iteration is:
# [1247]	valid_0's l2: 0.730975
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.717547
# Early stopping, best iteration is:
# [1007]	valid_0's l2: 0.717493
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.715691
# Early stopping, best iteration is:
# [1123]	valid_0's l2: 0.715422
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.717386
# Early stopping, best iteration is:
# [1482]	valid_0's l2: 0.716822
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.714876
# Early stopping, best iteration is:
# [1032]	valid_0's l2: 0.714768
# =====================
# 3
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.23372
# [2000]	valid_0's l2: 3.17212
# [3000]	valid_0's l2: 3.15379
# Early stopping, best iteration is:
# [3753]	valid_0's l2: 3.14641
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.22359
# [2000]	valid_0's l2: 3.16894
# [3000]	valid_0's l2: 3.15361
# Early stopping, best iteration is:
# [3795]	valid_0's l2: 3.14644
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.28565
# [2000]	valid_0's l2: 3.23507
# [3000]	valid_0's l2: 3.21823
# [4000]	valid_0's l2: 3.21072
# Early stopping, best iteration is:
# [4204]	valid_0's l2: 3.20973
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.26314
# [2000]	valid_0's l2: 3.2096
# [3000]	valid_0's l2: 3.19304
# [4000]	valid_0's l2: 3.18638
# Early stopping, best iteration is:
# [4883]	valid_0's l2: 3.18272
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.28037
# [2000]	valid_0's l2: 3.22532
# [3000]	valid_0's l2: 3.20885
# [4000]	valid_0's l2: 3.19884
# Early stopping, best iteration is:
# [4588]	valid_0's l2: 3.19562
# =====================
# 4
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58692
# [2000]	valid_0's l2: 1.52718
# [3000]	valid_0's l2: 1.50671
# [4000]	valid_0's l2: 1.49625
# [5000]	valid_0's l2: 1.49066
# [6000]	valid_0's l2: 1.48625
# Early stopping, best iteration is:
# [6181]	valid_0's l2: 1.48549
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.52001
# [2000]	valid_0's l2: 1.46272
# [3000]	valid_0's l2: 1.44178
# [4000]	valid_0's l2: 1.43089
# [5000]	valid_0's l2: 1.42457
# [6000]	valid_0's l2: 1.42197
# Early stopping, best iteration is:
# [6226]	valid_0's l2: 1.42112
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.52888
# [2000]	valid_0's l2: 1.47681
# [3000]	valid_0's l2: 1.45742
# [4000]	valid_0's l2: 1.44825
# [5000]	valid_0's l2: 1.44352
# [6000]	valid_0's l2: 1.44087
# Early stopping, best iteration is:
# [6620]	valid_0's l2: 1.4396
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.55914
# [2000]	valid_0's l2: 1.50546
# [3000]	valid_0's l2: 1.48669
# [4000]	valid_0's l2: 1.47809
# [5000]	valid_0's l2: 1.47244
# Early stopping, best iteration is:
# [5877]	valid_0's l2: 1.46947
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.57133
# [2000]	valid_0's l2: 1.51375
# [3000]	valid_0's l2: 1.49373
# [4000]	valid_0's l2: 1.48447
# [5000]	valid_0's l2: 1.47989
# Early stopping, best iteration is:
# [5300]	valid_0's l2: 1.47889
# =====================
# 5
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.4621
# [2000]	valid_0's l2: 6.29779
# [3000]	valid_0's l2: 6.24195
# [4000]	valid_0's l2: 6.21683
# [5000]	valid_0's l2: 6.20181
# [6000]	valid_0's l2: 6.19336
# Early stopping, best iteration is:
# [6041]	valid_0's l2: 6.19251
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.30142
# [2000]	valid_0's l2: 6.14385
# [3000]	valid_0's l2: 6.09048
# [4000]	valid_0's l2: 6.06468
# Early stopping, best iteration is:
# [4756]	valid_0's l2: 6.05208
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.46745
# [2000]	valid_0's l2: 6.31592
# [3000]	valid_0's l2: 6.26753
# [4000]	valid_0's l2: 6.24171
# [5000]	valid_0's l2: 6.22613
# [6000]	valid_0's l2: 6.21974
# Early stopping, best iteration is:
# [6435]	valid_0's l2: 6.21727
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.37755
# [2000]	valid_0's l2: 6.22831
# [3000]	valid_0's l2: 6.17987
# [4000]	valid_0's l2: 6.15419
# [5000]	valid_0's l2: 6.13891
# Early stopping, best iteration is:
# [5869]	valid_0's l2: 6.13015
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.19791
# [2000]	valid_0's l2: 6.07039
# [3000]	valid_0's l2: 6.03315
# [4000]	valid_0's l2: 6.02197
# Early stopping, best iteration is:
# [4383]	valid_0's l2: 6.01788
# =====================
# 6
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.8923
# [2000]	valid_0's l2: 7.6278
# [3000]	valid_0's l2: 7.54979
# [4000]	valid_0's l2: 7.51282
# [5000]	valid_0's l2: 7.49253
# Early stopping, best iteration is:
# [5760]	valid_0's l2: 7.47783
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.6618
# [2000]	valid_0's l2: 7.41659
# [3000]	valid_0's l2: 7.35162
# [4000]	valid_0's l2: 7.31865
# [5000]	valid_0's l2: 7.29644
# Early stopping, best iteration is:
# [5078]	valid_0's l2: 7.29561
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.05687
# [2000]	valid_0's l2: 7.73044
# [3000]	valid_0's l2: 7.61867
# [4000]	valid_0's l2: 7.56487
# [5000]	valid_0's l2: 7.53836
# [6000]	valid_0's l2: 7.51554
# Early stopping, best iteration is:
# [6870]	valid_0's l2: 7.50093
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.84423
# [2000]	valid_0's l2: 7.5675
# [3000]	valid_0's l2: 7.48942
# [4000]	valid_0's l2: 7.44536
# [5000]	valid_0's l2: 7.42398
# Early stopping, best iteration is:
# [5608]	valid_0's l2: 7.41552
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.71459
# [2000]	valid_0's l2: 7.51106
# [3000]	valid_0's l2: 7.44948
# Early stopping, best iteration is:
# [3828]	valid_0's l2: 7.42546
# =====================
# 7
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [660]	valid_0's l2: 0.926946
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.94579
# Early stopping, best iteration is:
# [1788]	valid_0's l2: 0.942717
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.944759
# [2000]	valid_0's l2: 0.939755
# Early stopping, best iteration is:
# [2639]	valid_0's l2: 0.938725
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.910047
# Early stopping, best iteration is:
# [1589]	valid_0's l2: 0.909042
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.903194
# Early stopping, best iteration is:
# [1091]	valid_0's l2: 0.902775
# =====================
# 8
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.603157
# Early stopping, best iteration is:
# [1793]	valid_0's l2: 0.601747
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.583156
# Early stopping, best iteration is:
# [1571]	valid_0's l2: 0.58228
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.596705
# Early stopping, best iteration is:
# [1088]	valid_0's l2: 0.596529
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.588696
# Early stopping, best iteration is:
# [1499]	valid_0's l2: 0.587452
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.600258
# [2000]	valid_0's l2: 0.598966
# Early stopping, best iteration is:
# [2487]	valid_0's l2: 0.598559
# =====================
# 9
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10681
# [2000]	valid_0's l2: 1.10047
# Early stopping, best iteration is:
# [2095]	valid_0's l2: 1.10018
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11843
# [2000]	valid_0's l2: 1.11164
# Early stopping, best iteration is:
# [2631]	valid_0's l2: 1.11005
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.09966
# [2000]	valid_0's l2: 1.09064
# [3000]	valid_0's l2: 1.08821
# Early stopping, best iteration is:
# [3247]	valid_0's l2: 1.08786
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.10002
# [2000]	valid_0's l2: 1.09329
# [3000]	valid_0's l2: 1.09128
# Early stopping, best iteration is:
# [2911]	valid_0's l2: 1.09111
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.1028
# [2000]	valid_0's l2: 1.09779
# Early stopping, best iteration is:
# [2414]	valid_0's l2: 1.09673
# =====================
# 10
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [656]	valid_0's l2: 0.690768
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [498]	valid_0's l2: 0.717734
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [402]	valid_0's l2: 0.706137
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [631]	valid_0's l2: 0.692265
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [756]	valid_0's l2: 0.708003
# =====================
# 11
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [667]	valid_0's l2: 1.32911
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [470]	valid_0's l2: 1.30318
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [672]	valid_0's l2: 1.28112
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [789]	valid_0's l2: 1.24019
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [565]	valid_0's l2: 1.304
# =====================
# 12
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.03335
# Early stopping, best iteration is:
# [1265]	valid_0's l2: 1.03181
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.04082
# Early stopping, best iteration is:
# [1383]	valid_0's l2: 1.03921
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.973205
# Early stopping, best iteration is:
# [1488]	valid_0's l2: 0.971461
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.01766
# Early stopping, best iteration is:
# [1023]	valid_0's l2: 1.01764
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.99679
# Early stopping, best iteration is:
# [1219]	valid_0's l2: 0.995617
# =====================
# 13
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.15495
# Early stopping, best iteration is:
# [1289]	valid_0's l2: 1.15354
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.16759
# Early stopping, best iteration is:
# [1557]	valid_0's l2: 1.16383
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.12334
# [2000]	valid_0's l2: 1.10897
# Early stopping, best iteration is:
# [2278]	valid_0's l2: 1.10664
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07747
# Early stopping, best iteration is:
# [1738]	valid_0's l2: 1.07077
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05814
# Early stopping, best iteration is:
# [1726]	valid_0's l2: 1.05446
# =====================
# 14
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.6915
# [2000]	valid_0's l2: 13.4613
# [3000]	valid_0's l2: 13.374
# [4000]	valid_0's l2: 13.3245
# [5000]	valid_0's l2: 13.2847
# [6000]	valid_0's l2: 13.2587
# Early stopping, best iteration is:
# [6102]	valid_0's l2: 13.2554
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.1076
# [2000]	valid_0's l2: 12.9162
# [3000]	valid_0's l2: 12.8482
# Early stopping, best iteration is:
# [3161]	valid_0's l2: 12.8412
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.5771
# [2000]	valid_0's l2: 13.3599
# [3000]	valid_0's l2: 13.2914
# [4000]	valid_0's l2: 13.2509
# [5000]	valid_0's l2: 13.2202
# Early stopping, best iteration is:
# [5129]	valid_0's l2: 13.2177
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.3827
# [2000]	valid_0's l2: 13.1825
# [3000]	valid_0's l2: 13.1317
# [4000]	valid_0's l2: 13.1143
# Early stopping, best iteration is:
# [3942]	valid_0's l2: 13.1123
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 13.2562
# [2000]	valid_0's l2: 13.0959
# [3000]	valid_0's l2: 13.0503
# Early stopping, best iteration is:
# [3626]	valid_0's l2: 13.0283
# =====================
# 15
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.94906
# Early stopping, best iteration is:
# [1374]	valid_0's l2: 4.91881
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.56833
# Early stopping, best iteration is:
# [1145]	valid_0's l2: 4.55962
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.31263
# Early stopping, best iteration is:
# [908]	valid_0's l2: 5.30874
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [807]	valid_0's l2: 4.79191
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.8996
# Early stopping, best iteration is:
# [1619]	valid_0's l2: 4.86574
# =====================
# 16
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.09913
# [2000]	valid_0's l2: 4.93507
# [3000]	valid_0's l2: 4.87685
# [4000]	valid_0's l2: 4.84917
# [5000]	valid_0's l2: 4.83191
# Early stopping, best iteration is:
# [5520]	valid_0's l2: 4.82717
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.20311
# [2000]	valid_0's l2: 5.02215
# [3000]	valid_0's l2: 4.96068
# [4000]	valid_0's l2: 4.92956
# [5000]	valid_0's l2: 4.91302
# [6000]	valid_0's l2: 4.90246
# Early stopping, best iteration is:
# [6231]	valid_0's l2: 4.89913
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.31398
# [2000]	valid_0's l2: 5.1326
# [3000]	valid_0's l2: 5.06235
# [4000]	valid_0's l2: 5.03104
# [5000]	valid_0's l2: 5.01251
# [6000]	valid_0's l2: 5.00305
# Early stopping, best iteration is:
# [6781]	valid_0's l2: 4.99539
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.24383
# [2000]	valid_0's l2: 5.0664
# [3000]	valid_0's l2: 5.00182
# [4000]	valid_0's l2: 4.97261
# [5000]	valid_0's l2: 4.95297
# Early stopping, best iteration is:
# [5555]	valid_0's l2: 4.9449
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.1723
# [2000]	valid_0's l2: 5.00185
# [3000]	valid_0's l2: 4.94679
# [4000]	valid_0's l2: 4.92052
# [5000]	valid_0's l2: 4.9052
# Early stopping, best iteration is:
# [5535]	valid_0's l2: 4.89972
# =====================
# 17
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.37428
# [2000]	valid_0's l2: 2.28722
# [3000]	valid_0's l2: 2.25805
# [4000]	valid_0's l2: 2.24283
# [5000]	valid_0's l2: 2.23332
# [6000]	valid_0's l2: 2.22741
# [7000]	valid_0's l2: 2.22262
# Early stopping, best iteration is:
# [7103]	valid_0's l2: 2.22209
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.40361
# [2000]	valid_0's l2: 2.31645
# [3000]	valid_0's l2: 2.28475
# [4000]	valid_0's l2: 2.26995
# [5000]	valid_0's l2: 2.26097
# [6000]	valid_0's l2: 2.25453
# [7000]	valid_0's l2: 2.24966
# [8000]	valid_0's l2: 2.24587
# Early stopping, best iteration is:
# [8568]	valid_0's l2: 2.24446
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.50044
# [2000]	valid_0's l2: 2.40692
# [3000]	valid_0's l2: 2.37413
# [4000]	valid_0's l2: 2.35844
# [5000]	valid_0's l2: 2.34864
# [6000]	valid_0's l2: 2.34176
# [7000]	valid_0's l2: 2.3375
# Early stopping, best iteration is:
# [7491]	valid_0's l2: 2.33593
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.45596
# [2000]	valid_0's l2: 2.36602
# [3000]	valid_0's l2: 2.33134
# [4000]	valid_0's l2: 2.3165
# [5000]	valid_0's l2: 2.30542
# [6000]	valid_0's l2: 2.2975
# [7000]	valid_0's l2: 2.29206
# [8000]	valid_0's l2: 2.28821
# Early stopping, best iteration is:
# [8321]	valid_0's l2: 2.2869
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.46442
# [2000]	valid_0's l2: 2.38199
# [3000]	valid_0's l2: 2.3504
# [4000]	valid_0's l2: 2.33446
# [5000]	valid_0's l2: 2.32475
# [6000]	valid_0's l2: 2.31806
# [7000]	valid_0's l2: 2.31438
# [8000]	valid_0's l2: 2.31129
# Early stopping, best iteration is:
# [7904]	valid_0's l2: 2.31113
# =====================
# 18
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.01835
# [2000]	valid_0's l2: 3.96036
# [3000]	valid_0's l2: 3.94189
# Early stopping, best iteration is:
# [3703]	valid_0's l2: 3.93376
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.90607
# [2000]	valid_0's l2: 3.84864
# [3000]	valid_0's l2: 3.83019
# Early stopping, best iteration is:
# [3817]	valid_0's l2: 3.82251
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.0016
# [2000]	valid_0's l2: 3.93164
# [3000]	valid_0's l2: 3.90717
# [4000]	valid_0's l2: 3.89482
# [5000]	valid_0's l2: 3.88874
# Early stopping, best iteration is:
# [5241]	valid_0's l2: 3.887
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.05348
# [2000]	valid_0's l2: 3.98413
# [3000]	valid_0's l2: 3.96317
# [4000]	valid_0's l2: 3.94992
# [5000]	valid_0's l2: 3.94136
# Early stopping, best iteration is:
# [5132]	valid_0's l2: 3.94041
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.01369
# [2000]	valid_0's l2: 3.94202
# [3000]	valid_0's l2: 3.91997
# [4000]	valid_0's l2: 3.91254
# Early stopping, best iteration is:
# [3958]	valid_0's l2: 3.91209
# =====================
# 19
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.76753
# Early stopping, best iteration is:
# [1708]	valid_0's l2: 3.73836
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.98564
# [2000]	valid_0's l2: 3.93314
# Early stopping, best iteration is:
# [2264]	valid_0's l2: 3.92859
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.7988
# Early stopping, best iteration is:
# [1101]	valid_0's l2: 3.79244
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.7665
# [2000]	valid_0's l2: 3.71901
# Early stopping, best iteration is:
# [2405]	valid_0's l2: 3.70223
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 4.16798
# [2000]	valid_0's l2: 4.13565
# Early stopping, best iteration is:
# [2636]	valid_0's l2: 4.13137
# =====================
# 20
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.710909
# [2000]	valid_0's l2: 0.708842
# Early stopping, best iteration is:
# [2098]	valid_0's l2: 0.708768
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.693437
# Early stopping, best iteration is:
# [1801]	valid_0's l2: 0.690874
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.706059
# Early stopping, best iteration is:
# [1796]	valid_0's l2: 0.704001
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.703072
# Early stopping, best iteration is:
# [1507]	valid_0's l2: 0.701333
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.681659
# [2000]	valid_0's l2: 0.679304
# Early stopping, best iteration is:
# [2766]	valid_0's l2: 0.678566
# =====================
# 21
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.87033
# [2000]	valid_0's l2: 1.83151
# [3000]	valid_0's l2: 1.81861
# [4000]	valid_0's l2: 1.81271
# Early stopping, best iteration is:
# [4599]	valid_0's l2: 1.81095
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.88487
# [2000]	valid_0's l2: 1.84153
# [3000]	valid_0's l2: 1.82837
# [4000]	valid_0's l2: 1.82334
# Early stopping, best iteration is:
# [4253]	valid_0's l2: 1.82264
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.89695
# [2000]	valid_0's l2: 1.85418
# [3000]	valid_0's l2: 1.84052
# [4000]	valid_0's l2: 1.83228
# [5000]	valid_0's l2: 1.82833
# Early stopping, best iteration is:
# [5610]	valid_0's l2: 1.82627
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.84102
# [2000]	valid_0's l2: 1.79822
# [3000]	valid_0's l2: 1.78479
# [4000]	valid_0's l2: 1.77744
# [5000]	valid_0's l2: 1.77392
# Early stopping, best iteration is:
# [5003]	valid_0's l2: 1.77388
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.87747
# [2000]	valid_0's l2: 1.84101
# [3000]	valid_0's l2: 1.82841
# [4000]	valid_0's l2: 1.82271
# [5000]	valid_0's l2: 1.81861
# Early stopping, best iteration is:
# [5522]	valid_0's l2: 1.8168
# =====================
# 22
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's l2: 1.09915
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [846]	valid_0's l2: 1.08569
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [681]	valid_0's l2: 1.03611
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [390]	valid_0's l2: 0.998767
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [713]	valid_0's l2: 1.0286
# =====================
# 23
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.25796
# Early stopping, best iteration is:
# [1588]	valid_0's l2: 1.25481
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.30328
# [2000]	valid_0's l2: 1.29742
# Early stopping, best iteration is:
# [1940]	valid_0's l2: 1.29721
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.30453
# [2000]	valid_0's l2: 1.30023
# Early stopping, best iteration is:
# [1919]	valid_0's l2: 1.30008
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.3117
# Early stopping, best iteration is:
# [1829]	valid_0's l2: 1.3068
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.26067
# [2000]	valid_0's l2: 1.25324
# Early stopping, best iteration is:
# [2465]	valid_0's l2: 1.25247
# =====================
# 24
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.71598
# [2000]	valid_0's l2: 9.56436
# [3000]	valid_0's l2: 9.50614
# [4000]	valid_0's l2: 9.48183
# [5000]	valid_0's l2: 9.46546
# Early stopping, best iteration is:
# [5620]	valid_0's l2: 9.45614
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.61273
# [2000]	valid_0's l2: 9.46048
# [3000]	valid_0's l2: 9.40216
# [4000]	valid_0's l2: 9.37681
# Early stopping, best iteration is:
# [3907]	valid_0's l2: 9.37649
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.78418
# [2000]	valid_0's l2: 9.63648
# [3000]	valid_0's l2: 9.5879
# [4000]	valid_0's l2: 9.56126
# Early stopping, best iteration is:
# [4656]	valid_0's l2: 9.54521
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.74964
# [2000]	valid_0's l2: 9.6191
# [3000]	valid_0's l2: 9.5708
# Early stopping, best iteration is:
# [3604]	valid_0's l2: 9.55579
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 9.60703
# [2000]	valid_0's l2: 9.46991
# [3000]	valid_0's l2: 9.42261
# Early stopping, best iteration is:
# [3374]	valid_0's l2: 9.41476
# =====================
# 25
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [613]	valid_0's l2: 0.897447
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [838]	valid_0's l2: 0.888617
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [771]	valid_0's l2: 0.881068
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [433]	valid_0's l2: 0.879225
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.898897
# Early stopping, best iteration is:
# [988]	valid_0's l2: 0.898739
# =====================
# 26
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [410]	valid_0's l2: 0.800006
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [356]	valid_0's l2: 0.799284
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [406]	valid_0's l2: 0.817643
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [599]	valid_0's l2: 0.787091
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [415]	valid_0's l2: 0.834123
# =====================
# 27
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [592]	valid_0's l2: 0.76564
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.770943
# Early stopping, best iteration is:
# [1088]	valid_0's l2: 0.770725
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.789677
# Early stopping, best iteration is:
# [1269]	valid_0's l2: 0.788939
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.740098
# Early stopping, best iteration is:
# [1047]	valid_0's l2: 0.73987
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [709]	valid_0's l2: 0.760536
# =====================
# 28
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.60331
# Early stopping, best iteration is:
# [1666]	valid_0's l2: 0.60225
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.59985
# Early stopping, best iteration is:
# [1840]	valid_0's l2: 0.598889
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.597685
# Early stopping, best iteration is:
# [1878]	valid_0's l2: 0.596676
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.600203
# Early stopping, best iteration is:
# [1468]	valid_0's l2: 0.599521
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.593033
# Early stopping, best iteration is:
# [1522]	valid_0's l2: 0.591835
# =====================
# 29
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.564577
# Early stopping, best iteration is:
# [1243]	valid_0's l2: 0.564278
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.568466
# Early stopping, best iteration is:
# [1405]	valid_0's l2: 0.567876
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.559463
# Early stopping, best iteration is:
# [1882]	valid_0's l2: 0.558137
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.565625
# Early stopping, best iteration is:
# [1056]	valid_0's l2: 0.565404
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.555739
# Early stopping, best iteration is:
# [1635]	valid_0's l2: 0.554953
# =====================
# 30
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [881]	valid_0's l2: 0.655623
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.628027
# Early stopping, best iteration is:
# [1092]	valid_0's l2: 0.627921
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [814]	valid_0's l2: 0.642316
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.630335
# Early stopping, best iteration is:
# [1175]	valid_0's l2: 0.630057
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.634232
# Early stopping, best iteration is:
# [1262]	valid_0's l2: 0.633839
# =====================
# 31
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [822]	valid_0's l2: 0.689888
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [773]	valid_0's l2: 0.672504
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [698]	valid_0's l2: 0.685743
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [895]	valid_0's l2: 0.668661
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [838]	valid_0's l2: 0.665361
# =====================
# 32
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.586784
# Early stopping, best iteration is:
# [1034]	valid_0's l2: 0.58675
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [567]	valid_0's l2: 0.582492
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [755]	valid_0's l2: 0.577825
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [802]	valid_0's l2: 0.58437
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [857]	valid_0's l2: 0.570375
# =====================
# 33
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [811]	valid_0's l2: 0.584875
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [539]	valid_0's l2: 0.607588
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [791]	valid_0's l2: 0.592982
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [637]	valid_0's l2: 0.594165
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [576]	valid_0's l2: 0.583632
# =====================
# 34
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.848016
# Early stopping, best iteration is:
# [966]	valid_0's l2: 0.847956
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [658]	valid_0's l2: 0.863852
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [441]	valid_0's l2: 0.857228
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [851]	valid_0's l2: 0.855904
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [730]	valid_0's l2: 0.838223
# =====================
# 35
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [714]	valid_0's l2: 0.740296
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.771148
# Early stopping, best iteration is:
# [1523]	valid_0's l2: 0.769548
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.752604
# [2000]	valid_0's l2: 0.7499
# Early stopping, best iteration is:
# [2049]	valid_0's l2: 0.749835
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.693283
# Early stopping, best iteration is:
# [1003]	valid_0's l2: 0.693265
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [746]	valid_0's l2: 0.70385
# =====================
# 36
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.891765
# Early stopping, best iteration is:
# [1379]	valid_0's l2: 0.890533
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.870463
# Early stopping, best iteration is:
# [1336]	valid_0's l2: 0.869948
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.911666
# Early stopping, best iteration is:
# [971]	valid_0's l2: 0.911556
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.875783
# Early stopping, best iteration is:
# [1011]	valid_0's l2: 0.875711
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.868969
# Early stopping, best iteration is:
# [1126]	valid_0's l2: 0.868622
# =====================
# 37
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.5933
# [2000]	valid_0's l2: 17.2904
# [3000]	valid_0's l2: 17.1999
# [4000]	valid_0's l2: 17.1624
# Early stopping, best iteration is:
# [4747]	valid_0's l2: 17.1285
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.1831
# [2000]	valid_0's l2: 16.8661
# [3000]	valid_0's l2: 16.7716
# [4000]	valid_0's l2: 16.7271
# Early stopping, best iteration is:
# [3900]	valid_0's l2: 16.725
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.3837
# [2000]	valid_0's l2: 17.1005
# [3000]	valid_0's l2: 17.0149
# [4000]	valid_0's l2: 16.9794
# Early stopping, best iteration is:
# [4287]	valid_0's l2: 16.9706
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.29
# [2000]	valid_0's l2: 17.0526
# [3000]	valid_0's l2: 16.9912
# Early stopping, best iteration is:
# [3741]	valid_0's l2: 16.9667
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 17.2778
# [2000]	valid_0's l2: 17.0571
# Early stopping, best iteration is:
# [2504]	valid_0's l2: 17.0174
# =====================
# 38
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.741255
# Early stopping, best iteration is:
# [1258]	valid_0's l2: 0.74104
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.743608
# Early stopping, best iteration is:
# [1247]	valid_0's l2: 0.74311
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.756535
# Early stopping, best iteration is:
# [1673]	valid_0's l2: 0.755286
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.731092
# Early stopping, best iteration is:
# [1172]	valid_0's l2: 0.730493
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.759132
# Early stopping, best iteration is:
# [1453]	valid_0's l2: 0.758608
# =====================
# 39
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's l2: 1.43732
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [513]	valid_0's l2: 1.4109
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [745]	valid_0's l2: 1.41
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's l2: 1.4693
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [496]	valid_0's l2: 1.49567
# =====================
# 40
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [826]	valid_0's l2: 0.820332
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.797859
# Early stopping, best iteration is:
# [1255]	valid_0's l2: 0.797559
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.937255
# Early stopping, best iteration is:
# [1186]	valid_0's l2: 0.936993
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.820781
# Early stopping, best iteration is:
# [1372]	valid_0's l2: 0.820129
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [735]	valid_0's l2: 0.896522
# =====================
# 41
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.961672
# Early stopping, best iteration is:
# [903]	valid_0's l2: 0.961567
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [640]	valid_0's l2: 1.00377
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [657]	valid_0's l2: 0.943173
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [746]	valid_0's l2: 0.977469
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.990356
# Early stopping, best iteration is:
# [1157]	valid_0's l2: 0.990141
# =====================
# 42
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.842359
# Early stopping, best iteration is:
# [1125]	valid_0's l2: 0.842114
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [674]	valid_0's l2: 0.823622
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [826]	valid_0's l2: 0.849304
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [837]	valid_0's l2: 0.816912
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.825813
# Early stopping, best iteration is:
# [1089]	valid_0's l2: 0.82558
# =====================
# 43
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.64803
# [2000]	valid_0's l2: 5.42735
# [3000]	valid_0's l2: 5.36178
# [4000]	valid_0's l2: 5.33523
# [5000]	valid_0's l2: 5.31675
# [6000]	valid_0's l2: 5.30813
# Early stopping, best iteration is:
# [5958]	valid_0's l2: 5.30739
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.92082
# [2000]	valid_0's l2: 5.67963
# [3000]	valid_0's l2: 5.6009
# [4000]	valid_0's l2: 5.55983
# [5000]	valid_0's l2: 5.53738
# Early stopping, best iteration is:
# [4944]	valid_0's l2: 5.53698
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.88998
# [2000]	valid_0's l2: 5.6917
# [3000]	valid_0's l2: 5.62342
# [4000]	valid_0's l2: 5.5914
# [5000]	valid_0's l2: 5.56889
# Early stopping, best iteration is:
# [5610]	valid_0's l2: 5.56027
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 6.00781
# [2000]	valid_0's l2: 5.73641
# [3000]	valid_0's l2: 5.64586
# [4000]	valid_0's l2: 5.60257
# [5000]	valid_0's l2: 5.57831
# [6000]	valid_0's l2: 5.56464
# [7000]	valid_0's l2: 5.55482
# Early stopping, best iteration is:
# [7267]	valid_0's l2: 5.55233
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.76606
# [2000]	valid_0's l2: 5.55856
# [3000]	valid_0's l2: 5.48782
# [4000]	valid_0's l2: 5.4575
# [5000]	valid_0's l2: 5.44006
# Early stopping, best iteration is:
# [5213]	valid_0's l2: 5.43854
# =====================
# 44
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [888]	valid_0's l2: 0.739968
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.737072
# Early stopping, best iteration is:
# [1101]	valid_0's l2: 0.736778
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [819]	valid_0's l2: 0.72591
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.732316
# Early stopping, best iteration is:
# [1346]	valid_0's l2: 0.731596
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.708808
# Early stopping, best iteration is:
# [1696]	valid_0's l2: 0.707663
# =====================
# 45
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [856]	valid_0's l2: 0.680683
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.680282
# Early stopping, best iteration is:
# [1361]	valid_0's l2: 0.679974
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.671007
# Early stopping, best iteration is:
# [1370]	valid_0's l2: 0.670643
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.671355
# Early stopping, best iteration is:
# [1126]	valid_0's l2: 0.671267
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [737]	valid_0's l2: 0.653683
# =====================
# 46
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.58604
# Early stopping, best iteration is:
# [1556]	valid_0's l2: 1.58358
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.59396
# Early stopping, best iteration is:
# [1288]	valid_0's l2: 1.59244
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.6156
# Early stopping, best iteration is:
# [1212]	valid_0's l2: 1.61466
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.64096
# [2000]	valid_0's l2: 1.63564
# Early stopping, best iteration is:
# [2013]	valid_0's l2: 1.63555
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.63622
# [2000]	valid_0's l2: 1.62886
# Early stopping, best iteration is:
# [2292]	valid_0's l2: 1.62785
# =====================
# 47
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.06489
# Early stopping, best iteration is:
# [1169]	valid_0's l2: 1.06452
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11743
# [2000]	valid_0's l2: 1.11315
# Early stopping, best iteration is:
# [2078]	valid_0's l2: 1.11276
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07218
# [2000]	valid_0's l2: 1.06771
# Early stopping, best iteration is:
# [1987]	valid_0's l2: 1.06765
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11341
# Early stopping, best iteration is:
# [1599]	valid_0's l2: 1.10967
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.11243
# [2000]	valid_0's l2: 1.10787
# Early stopping, best iteration is:
# [2420]	valid_0's l2: 1.10704
# =====================
# 48
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.17366
# [2000]	valid_0's l2: 7.90335
# [3000]	valid_0's l2: 7.81661
# [4000]	valid_0's l2: 7.77384
# [5000]	valid_0's l2: 7.75197
# Early stopping, best iteration is:
# [5664]	valid_0's l2: 7.74069
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 7.98458
# [2000]	valid_0's l2: 7.73003
# [3000]	valid_0's l2: 7.64947
# [4000]	valid_0's l2: 7.60784
# [5000]	valid_0's l2: 7.58578
# [6000]	valid_0's l2: 7.5715
# Early stopping, best iteration is:
# [6137]	valid_0's l2: 7.57043
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.16294
# [2000]	valid_0's l2: 7.91794
# [3000]	valid_0's l2: 7.8314
# [4000]	valid_0's l2: 7.79159
# [5000]	valid_0's l2: 7.76933
# Early stopping, best iteration is:
# [5718]	valid_0's l2: 7.75772
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.30867
# [2000]	valid_0's l2: 8.00753
# [3000]	valid_0's l2: 7.90642
# [4000]	valid_0's l2: 7.85407
# Early stopping, best iteration is:
# [4739]	valid_0's l2: 7.83554
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 8.30338
# [2000]	valid_0's l2: 8.04113
# [3000]	valid_0's l2: 7.95052
# [4000]	valid_0's l2: 7.91097
# [5000]	valid_0's l2: 7.88809
# [6000]	valid_0's l2: 7.87524
# [7000]	valid_0's l2: 7.86537
# Early stopping, best iteration is:
# [7839]	valid_0's l2: 7.85808
# =====================
# 49
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [888]	valid_0's l2: 0.703531
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [501]	valid_0's l2: 0.704308
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# ...
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [426]	valid_0's l2: 1.14056
# =====================
# 124
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.88728
# Early stopping, best iteration is:
# [935]	valid_0's l2: 0.887131
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.904057
# Early stopping, best iteration is:
# [1183]	valid_0's l2: 0.903628
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.898253
# Early stopping, best iteration is:
# [1217]	valid_0's l2: 0.897776
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.872369
# Early stopping, best iteration is:
# [1331]	valid_0's l2: 0.871806
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [827]	valid_0's l2: 0.903041
# =====================
# 125
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.892854
# Early stopping, best iteration is:
# [1011]	valid_0's l2: 0.892812
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [682]	valid_0's l2: 0.876003
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [747]	valid_0's l2: 0.883914
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.851008
# Early stopping, best iteration is:
# [1619]	valid_0's l2: 0.85045
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [765]	valid_0's l2: 0.873223
# =====================
# 126
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [557]	valid_0's l2: 0.790457
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.786465
# Early stopping, best iteration is:
# [921]	valid_0's l2: 0.786381
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [729]	valid_0's l2: 0.764959
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [486]	valid_0's l2: 0.785593
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [809]	valid_0's l2: 0.782355
# =====================
# 127
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.00382
# [2000]	valid_0's l2: 0.998686
# Early stopping, best iteration is:
# [2570]	valid_0's l2: 0.997552
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.04518
# [2000]	valid_0's l2: 1.04106
# Early stopping, best iteration is:
# [1957]	valid_0's l2: 1.04095
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.0461
# Early stopping, best iteration is:
# [1890]	valid_0's l2: 1.03952
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.0097
# [2000]	valid_0's l2: 1.00373
# Early stopping, best iteration is:
# [2042]	valid_0's l2: 1.00358
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.03369
# [2000]	valid_0's l2: 1.0282
# Early stopping, best iteration is:
# [2134]	valid_0's l2: 1.0279
# =====================
# 128
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.761501
# Early stopping, best iteration is:
# [969]	valid_0's l2: 0.761439
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.75645
# Early stopping, best iteration is:
# [998]	valid_0's l2: 0.756409
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.770229
# Early stopping, best iteration is:
# [1434]	valid_0's l2: 0.769907
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [720]	valid_0's l2: 0.735457
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.741186
# Early stopping, best iteration is:
# [1137]	valid_0's l2: 0.74111
# =====================
# 129
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.838572
# Early stopping, best iteration is:
# [1875]	valid_0's l2: 0.836857
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.821234
# [2000]	valid_0's l2: 0.818476
# Early stopping, best iteration is:
# [2042]	valid_0's l2: 0.818404
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.805691
# Early stopping, best iteration is:
# [1692]	valid_0's l2: 0.802273
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.815005
# Early stopping, best iteration is:
# [1774]	valid_0's l2: 0.81208
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.801129
# Early stopping, best iteration is:
# [1141]	valid_0's l2: 0.801025
# =====================
# 130
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.657387
# Early stopping, best iteration is:
# [996]	valid_0's l2: 0.657335
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.662905
# Early stopping, best iteration is:
# [1034]	valid_0's l2: 0.662802
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [701]	valid_0's l2: 0.665416
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.659262
# Early stopping, best iteration is:
# [1057]	valid_0's l2: 0.659155
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.658133
# Early stopping, best iteration is:
# [1161]	valid_0's l2: 0.657836
# =====================
# 131
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.88413
# [2000]	valid_0's l2: 5.7672
# [3000]	valid_0's l2: 5.72413
# [4000]	valid_0's l2: 5.70604
# Early stopping, best iteration is:
# [3956]	valid_0's l2: 5.70532
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.88639
# [2000]	valid_0's l2: 5.76863
# [3000]	valid_0's l2: 5.72628
# [4000]	valid_0's l2: 5.70318
# [5000]	valid_0's l2: 5.69115
# Early stopping, best iteration is:
# [5319]	valid_0's l2: 5.68784
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.96757
# [2000]	valid_0's l2: 5.85908
# [3000]	valid_0's l2: 5.81216
# [4000]	valid_0's l2: 5.78788
# Early stopping, best iteration is:
# [4601]	valid_0's l2: 5.77816
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.89823
# [2000]	valid_0's l2: 5.78003
# [3000]	valid_0's l2: 5.73739
# [4000]	valid_0's l2: 5.71045
# [5000]	valid_0's l2: 5.69362
# [6000]	valid_0's l2: 5.68532
# [7000]	valid_0's l2: 5.67855
# Early stopping, best iteration is:
# [7261]	valid_0's l2: 5.67723
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 5.83745
# [2000]	valid_0's l2: 5.7193
# [3000]	valid_0's l2: 5.67559
# [4000]	valid_0's l2: 5.65633
# [5000]	valid_0's l2: 5.64344
# Early stopping, best iteration is:
# [5828]	valid_0's l2: 5.63763
# =====================
# 132
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02469
# [2000]	valid_0's l2: 1.02194
# Early stopping, best iteration is:
# [1977]	valid_0's l2: 1.02185
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02476
# Early stopping, best iteration is:
# [1673]	valid_0's l2: 1.02201
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.01006
# Early stopping, best iteration is:
# [1724]	valid_0's l2: 1.00808
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.01257
# Early stopping, best iteration is:
# [1715]	valid_0's l2: 1.01028
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.02437
# [2000]	valid_0's l2: 1.02216
# Early stopping, best iteration is:
# [1938]	valid_0's l2: 1.02207
# =====================
# 133
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.501172
# Early stopping, best iteration is:
# [1884]	valid_0's l2: 0.500076
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.486887
# Early stopping, best iteration is:
# [1701]	valid_0's l2: 0.485804
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.482197
# Early stopping, best iteration is:
# [1596]	valid_0's l2: 0.481494
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.480799
# Early stopping, best iteration is:
# [1848]	valid_0's l2: 0.480011
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.485896
# Early stopping, best iteration is:
# [1120]	valid_0's l2: 0.485711
# =====================
# 134
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [829]	valid_0's l2: 2.34987
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [561]	valid_0's l2: 2.03331
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [547]	valid_0's l2: 2.20288
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [468]	valid_0's l2: 1.92299
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l2: 1.78765
# =====================
# 135
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.760297
# Early stopping, best iteration is:
# [1355]	valid_0's l2: 0.759571
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.773444
# Early stopping, best iteration is:
# [1766]	valid_0's l2: 0.772224
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.769972
# Early stopping, best iteration is:
# [1133]	valid_0's l2: 0.769479
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.759246
# Early stopping, best iteration is:
# [1360]	valid_0's l2: 0.758809
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 0.76888
# Early stopping, best iteration is:
# [1141]	valid_0's l2: 0.768655
# =====================
# 136
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.43763
# [2000]	valid_0's l2: 3.28876
# [3000]	valid_0's l2: 3.23514
# [4000]	valid_0's l2: 3.20596
# [5000]	valid_0's l2: 3.18791
# [6000]	valid_0's l2: 3.17561
# [7000]	valid_0's l2: 3.16874
# [8000]	valid_0's l2: 3.16294
# [9000]	valid_0's l2: 3.1564
# [10000]	valid_0's l2: 3.15137
# Did not meet early stopping. Best iteration is:
# [9980]	valid_0's l2: 3.15122
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.45641
# [2000]	valid_0's l2: 3.30475
# [3000]	valid_0's l2: 3.24764
# [4000]	valid_0's l2: 3.21833
# [5000]	valid_0's l2: 3.20172
# [6000]	valid_0's l2: 3.18832
# [7000]	valid_0's l2: 3.18055
# [8000]	valid_0's l2: 3.17468
# Early stopping, best iteration is:
# [8721]	valid_0's l2: 3.17101
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.57156
# [2000]	valid_0's l2: 3.42046
# [3000]	valid_0's l2: 3.36299
# [4000]	valid_0's l2: 3.32974
# [5000]	valid_0's l2: 3.30945
# [6000]	valid_0's l2: 3.29748
# [7000]	valid_0's l2: 3.28875
# [8000]	valid_0's l2: 3.28229
# Early stopping, best iteration is:
# [8590]	valid_0's l2: 3.27955
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.45225
# [2000]	valid_0's l2: 3.30978
# [3000]	valid_0's l2: 3.25295
# [4000]	valid_0's l2: 3.22221
# [5000]	valid_0's l2: 3.2045
# [6000]	valid_0's l2: 3.19259
# [7000]	valid_0's l2: 3.18623
# [8000]	valid_0's l2: 3.17964
# Early stopping, best iteration is:
# [8262]	valid_0's l2: 3.17838
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.41735
# [2000]	valid_0's l2: 3.28421
# [3000]	valid_0's l2: 3.23668
# [4000]	valid_0's l2: 3.21306
# [5000]	valid_0's l2: 3.19999
# [6000]	valid_0's l2: 3.18899
# [7000]	valid_0's l2: 3.18225
# [8000]	valid_0's l2: 3.17657
# Early stopping, best iteration is:
# [8425]	valid_0's l2: 3.17385
# =====================
# 137
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05105
# Early stopping, best iteration is:
# [1564]	valid_0's l2: 1.04912
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.0569
# Early stopping, best iteration is:
# [1047]	valid_0's l2: 1.05651
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.07703
# Early stopping, best iteration is:
# [1369]	valid_0's l2: 1.07578
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.05499
# Early stopping, best iteration is:
# [1523]	valid_0's l2: 1.05335
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 1.09217
# Early stopping, best iteration is:
# [1697]	valid_0's l2: 1.08878
# =====================
# 138
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.31897
# [2000]	valid_0's l2: 2.28438
# [3000]	valid_0's l2: 2.27498
# Early stopping, best iteration is:
# [3521]	valid_0's l2: 2.27192
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.14967
# [2000]	valid_0's l2: 2.11104
# [3000]	valid_0's l2: 2.0991
# [4000]	valid_0's l2: 2.0942
# Early stopping, best iteration is:
# [4141]	valid_0's l2: 2.09333
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.46225
# [2000]	valid_0's l2: 2.4209
# [3000]	valid_0's l2: 2.40865
# [4000]	valid_0's l2: 2.40175
# Early stopping, best iteration is:
# [4544]	valid_0's l2: 2.39932
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.08805
# [2000]	valid_0's l2: 2.04862
# [3000]	valid_0's l2: 2.03771
# [4000]	valid_0's l2: 2.03244
# Early stopping, best iteration is:
# [4066]	valid_0's l2: 2.03191
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 2.42688
# [2000]	valid_0's l2: 2.3885
# [3000]	valid_0's l2: 2.37655
# [4000]	valid_0's l2: 2.37138
# [5000]	valid_0's l2: 2.36756
# Early stopping, best iteration is:
# [5483]	valid_0's l2: 2.36556
# =====================
# 139
# n_fold: 0
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.89199
# [2000]	valid_0's l2: 3.84943
# [3000]	valid_0's l2: 3.83552
# Early stopping, best iteration is:
# [3216]	valid_0's l2: 3.83408
# n_fold: 1
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.86436
# [2000]	valid_0's l2: 3.82369
# [3000]	valid_0's l2: 3.81132
# Early stopping, best iteration is:
# [3158]	valid_0's l2: 3.80996
# n_fold: 2
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.89534
# [2000]	valid_0's l2: 3.86549
# [3000]	valid_0's l2: 3.85317
# [4000]	valid_0's l2: 3.84635
# Early stopping, best iteration is:
# [3978]	valid_0's l2: 3.84588
# n_fold: 3
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.84424
# [2000]	valid_0's l2: 3.80825
# [3000]	valid_0's l2: 3.7978
# Early stopping, best iteration is:
# [2990]	valid_0's l2: 3.7975
# n_fold: 4
# Training until validation scores don't improve for 100 rounds
# [1000]	valid_0's l2: 3.90313
# [2000]	valid_0's l2: 3.86827
# Early stopping, best iteration is:
# [2526]	valid_0's l2: 3.86075
# CPU times: total: 34d 23h 47min 8s
# Wall time: 1d 5h 28min 8s

# %%
def correlation_score(y_true, y_pred):
    """Scores the predictions according to the competition rules. 
    
    It is assumed that the predictions are not constant.
    
    Returns the average of each sample's Pearson correlation coefficient"""
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

oof_preds = np.zeros((len(train_df), 140))
for n in range(len(train_preds)):
    oof_preds[:,n] =  train_preds[n]

cv = correlation_score(train_cite_y, oof_preds)
print (cv)

sub_preds = np.zeros((48203, 140))
for n in range(len(test_preds)):
    sub_preds[:,n] =  test_preds[n]  

lgb3 = np.concatenate([oof_preds,sub_preds],axis=0)

tsvd = TruncatedSVD(n_components=100, algorithm='arpack')
lgb3_svd = tsvd.fit_transform(lgb3)
np.save(feature_path+'cite_lgb3_svd_100.npy', lgb3_svd)
# Out:
# 0.903047622301149

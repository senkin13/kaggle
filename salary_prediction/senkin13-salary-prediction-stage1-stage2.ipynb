# %%
import pandas as pd
import numpy as np
from tqdm import tqdm 
from sklearn.preprocessing import LabelEncoder

train = pd.read_csv('train_data.csv')
train['salary_round'] = np.round(train['salary'])
test = pd.read_csv('test_data.csv')
df = pd.concat([train,test],axis=0)
lbl = LabelEncoder()
df['area'] = lbl.fit_transform(df['area'])
df['age_bin'] = pd.cut(df['age'], [0, 23, 30,40,50,60,100], labels=[1, 2, 3,4,5,6])
df['age_bin'] = df['age_bin'].astype('int')

    
## aggregation features
def agg(df,agg_cols):
    for c in tqdm(agg_cols):
        print (c)
        print (c['agg'])
        new_feature = '{}_{}_{}'.format('_'.join(c['groupby']), c['agg'], c['target'])
        
        if c['agg'] == 'mode':
            df[new_feature] = df.groupby(c['groupby'])[c['target']].apply(pd.Series.mode).reset_index(drop=True)           
        elif c['agg'] == 'diff':
            df[new_feature] = df.groupby(c['groupby'])[c['target']].transform(lambda x: x.diff())
        elif c['agg'] == 'cumcount':
            df[new_feature] = df.groupby(c['groupby']).cumcount()
        elif c['agg'] == 'shift':
            df[new_feature] = df.groupby(c['groupby'])[c['target']].shift()            
        else:    
            df[new_feature] = df.groupby(c['groupby'])[c['target']].transform(c['agg'])

    return df

agg_cols = [    
    
# ---------------
#     position
# ---------------    
    
    {'groupby': ['position'], 'target':'education', 'agg':'mean'},       
    
    {'groupby': ['position'], 'target':'age', 'agg':'max'}, 
    {'groupby': ['position'], 'target':'age', 'agg':'min'},     
    {'groupby': ['position'], 'target':'age', 'agg':'mean'}, 
    {'groupby': ['position'], 'target':'age', 'agg':'std'}, 
    {'groupby': ['position'], 'target':'age', 'agg':'nunique'},     
    
    {'groupby': ['position'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['position'], 'target':'commute', 'agg':'std'},  
        
# ---------------
#     age
# ---------------      
    
    {'groupby': ['age'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['age'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['age'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['age'], 'target':'commute', 'agg':'std'},  
              
    
# ---------------
#     area
# ---------------      
    {'groupby': ['area'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['area'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['area'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['area'], 'target':'commute', 'agg':'std'},  
  
# ---------------
#     education
# ---------------      
    {'groupby': ['education'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['education'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['education'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['education'], 'target':'commute', 'agg':'std'},  
   
# ---------------
#     sex
# ---------------      
#    {'groupby': ['sex'], 'target':'education', 'agg':'mean'},  
    
    {'groupby': ['sex'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['sex'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['sex'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['sex'], 'target':'commute', 'agg':'std'},  
    
# ---------------
#     service_length
# ---------------      
#    {'groupby': ['service_length'], 'target':'education', 'agg':'mean'},  
    
    {'groupby': ['service_length'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['service_length'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['service_length'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['service_length'], 'target':'commute', 'agg':'std'},      
   
# ---------------
#     num_child
# ---------------      
#    {'groupby': ['num_child'], 'target':'education', 'agg':'mean'},  
    
    {'groupby': ['num_child'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['num_child'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['num_child'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['num_child'], 'target':'commute', 'agg':'std'},  
 
# ---------------
#     partner
# ---------------      
#    {'groupby': ['partner'], 'target':'education', 'agg':'mean'},  
    
    {'groupby': ['partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['partner'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['partner'], 'target':'commute', 'agg':'min'}, 
    {'groupby': ['partner'], 'target':'commute', 'agg':'std'},      
    
# ---------------
#     position sex
# --------------- 
    {'groupby': ['position','sex'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','sex'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','sex'], 'target':'commute', 'agg':'min'}, 
# ---------------
#     position age
# ---------------     
    {'groupby': ['position','age'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','age'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','age'], 'target':'commute', 'agg':'min'},     
# ---------------
#     position area
# ---------------     
    {'groupby': ['position','area'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','area'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','area'], 'target':'commute', 'agg':'min'},
# ---------------
#     position education
# --------------- 
    {'groupby': ['position','education'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','education'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','education'], 'target':'commute', 'agg':'min'},    
# ---------------
#     position num_child
# ---------------     
    {'groupby': ['position','num_child'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','num_child'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','num_child'], 'target':'commute', 'agg':'min'},      
    
    {'groupby': ['position','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','partner'], 'target':'commute', 'agg':'max'}, 
    {'groupby': ['position','partner'], 'target':'commute', 'agg':'min'},  
    
    {'groupby': ['position','num_child','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','num_child','partner'], 'target':'commute', 'agg':'max'},      
    {'groupby': ['position','num_child','partner'], 'target':'commute', 'agg':'min'},   
    
    {'groupby': ['position','age','num_child','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','age','num_child','partner'], 'target':'commute', 'agg':'max'},      
    {'groupby': ['position','age','num_child','partner'], 'target':'commute', 'agg':'min'},   
    
    {'groupby': ['position','area','num_child','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','area','num_child','partner'], 'target':'commute', 'agg':'max'},      
    {'groupby': ['position','area','num_child','partner'], 'target':'commute', 'agg':'min'}, 
    
    {'groupby': ['position','education','num_child','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','education','num_child','partner'], 'target':'commute', 'agg':'max'},      
    {'groupby': ['position','education','num_child','partner'], 'target':'commute', 'agg':'min'},    
    
    {'groupby': ['position','sex','num_child','partner'], 'target':'commute', 'agg':'mean'}, 
    {'groupby': ['position','sex','num_child','partner'], 'target':'commute', 'agg':'max'},      
    {'groupby': ['position','sex','num_child','partner'], 'target':'commute', 'agg':'min'},       
]

df = agg(df,agg_cols)

df['diff_position_mean_commute'] = df['position_mean_commute'] - df['commute']
df['diff_age_mean_commute'] = df['age_mean_commute'] - df['commute']
df['diff_area_mean_commute'] = df['area_mean_commute'] - df['commute']
df['diff_education_mean_commute'] = df['education_mean_commute'] - df['commute']
df['diff_sex_mean_commute'] = df['sex_mean_commute'] - df['commute']
df['diff_service_length_mean_commute'] = df['service_length_mean_commute'] - df['commute']
df['diff_num_child_mean_commute'] = df['num_child_mean_commute'] - df['commute']
df['diff_partner_mean_commute'] = df['partner_mean_commute'] - df['commute']

df['ratio_position_mean_commute'] = df['position_mean_commute'] / df['commute']
df['ratio_age_mean_commute'] = df['age_mean_commute'] / df['commute']
df['ratio_area_mean_commute'] = df['area_mean_commute'] / df['commute']
df['ratio_education_mean_commute'] = df['education_mean_commute'] / df['commute']
df['ratio_sex_mean_commute'] = df['sex_mean_commute'] / df['commute']
df['ratio_service_length_mean_commute'] = df['service_length_mean_commute'] / df['commute']
df['ratio_num_child_mean_commute'] = df['num_child_mean_commute'] / df['commute']
df['ratio_partner_mean_commute'] = df['partner_mean_commute'] / df['commute']


df['diff_position_max_commute'] = df['position_max_commute'] - df['commute']
df['diff_age_max_commute'] = df['age_max_commute'] - df['commute']
df['diff_area_max_commute'] = df['area_max_commute'] - df['commute']
df['diff_education_max_commute'] = df['education_max_commute'] - df['commute']
df['diff_sex_max_commute'] = df['sex_max_commute'] - df['commute']
df['diff_service_length_max_commute'] = df['service_length_max_commute'] - df['commute']
df['diff_num_child_max_commute'] = df['num_child_max_commute'] - df['commute']
df['diff_partner_max_commute'] = df['partner_max_commute'] - df['commute']

df['ratio_position_max_commute'] = df['position_max_commute'] / df['commute']
df['ratio_age_max_commute'] = df['age_max_commute'] / df['commute']
df['ratio_area_max_commute'] = df['area_max_commute'] / df['commute']
df['ratio_education_max_commute'] = df['education_max_commute'] / df['commute']
df['ratio_sex_max_commute'] = df['sex_max_commute'] / df['commute']
df['ratio_service_length_max_commute'] = df['service_length_max_commute'] / df['commute']
df['ratio_num_child_max_commute'] = df['num_child_max_commute'] / df['commute']
df['ratio_partner_max_commute'] = df['partner_max_commute'] / df['commute']


df['diff_position_min_commute'] = df['position_min_commute'] - df['commute']
df['diff_age_min_commute'] = df['age_min_commute'] - df['commute']
df['diff_area_min_commute'] = df['area_min_commute'] - df['commute']
df['diff_education_min_commute'] = df['education_min_commute'] - df['commute']
df['diff_sex_min_commute'] = df['sex_min_commute'] - df['commute']
df['diff_service_length_min_commute'] = df['service_length_min_commute'] - df['commute']
df['diff_num_child_min_commute'] = df['num_child_min_commute'] - df['commute']
df['diff_partner_min_commute'] = df['partner_min_commute'] - df['commute']

df['ratio_position_min_commute'] = df['position_min_commute'] / df['commute']
df['ratio_age_min_commute'] = df['age_min_commute'] / df['commute']
df['ratio_area_min_commute'] = df['area_min_commute'] / df['commute']
df['ratio_education_min_commute'] = df['education_min_commute'] / df['commute']
df['ratio_sex_min_commute'] = df['sex_min_commute'] / df['commute']
df['ratio_service_length_min_commute'] = df['service_length_min_commute'] / df['commute']
df['ratio_num_child_min_commute'] = df['num_child_min_commute'] / df['commute']
df['ratio_partner_min_commute'] = df['partner_min_commute'] / df['commute']

df['diff_position_mean_age'] = df['position_mean_age'] - df['age']
df['diff_position_max_age'] = df['position_max_age'] - df['age']
df['diff_position_min_age'] = df['position_min_age'] - df['age']

df['ratio_position_mean_age'] = df['position_mean_age'] / df['age']
df['ratio_position_max_age'] = df['position_max_age'] / df['age']
df['ratio_position_min_age'] = df['position_min_age'] / df['age']

df['diff_position_mean_education'] = df['position_mean_education'] - df['education']
df['ratio_position_mean_education'] = df['position_mean_education'] / df['education']


df['diff_position_sex_max_commute'] = df['position_sex_max_commute'] - df['commute']
df['diff_position_sex_min_commute'] = df['position_sex_min_commute'] - df['commute']
df['diff_position_sex_mean_commute'] = df['position_sex_mean_commute'] - df['commute']

df['diff_position_age_max_commute'] = df['position_age_max_commute'] - df['commute']
df['diff_position_age_min_commute'] = df['position_age_min_commute'] - df['commute']
df['diff_position_age_mean_commute'] = df['position_age_mean_commute'] - df['commute']

df['diff_position_area_max_commute'] = df['position_area_max_commute'] - df['commute']
df['diff_position_area_min_commute'] = df['position_area_min_commute'] - df['commute']
df['diff_position_area_mean_commute'] = df['position_area_mean_commute'] - df['commute']

df['diff_position_education_max_commute'] = df['position_education_max_commute'] - df['commute']
df['diff_position_education_min_commute'] = df['position_education_min_commute'] - df['commute']
df['diff_position_education_mean_commute'] = df['position_education_mean_commute'] - df['commute']

df['diff_position_num_child_max_commute'] = df['position_num_child_max_commute'] - df['commute']
df['diff_position_num_child_min_commute'] = df['position_num_child_min_commute'] - df['commute']
df['diff_position_num_child_mean_commute'] = df['position_num_child_mean_commute'] - df['commute']

df['diff_position_partner_max_commute'] = df['position_partner_max_commute'] - df['commute']
df['diff_position_partner_min_commute'] = df['position_partner_min_commute'] - df['commute']
df['diff_position_partner_mean_commute'] = df['position_partner_mean_commute'] - df['commute']

df['ratio_position_sex_max_commute'] = df['position_sex_max_commute'] / df['commute']
df['ratio_position_sex_min_commute'] = df['position_sex_min_commute'] / df['commute']
df['ratio_position_sex_mean_commute'] = df['position_sex_mean_commute'] / df['commute']

df['ratio_position_age_max_commute'] = df['position_age_max_commute'] / df['commute']
df['ratio_position_age_min_commute'] = df['position_age_min_commute'] / df['commute']
df['ratio_position_age_mean_commute'] = df['position_age_mean_commute'] / df['commute']

df['ratio_position_area_max_commute'] = df['position_area_max_commute'] / df['commute']
df['ratio_position_area_min_commute'] = df['position_area_min_commute'] / df['commute']
df['ratio_position_area_mean_commute'] = df['position_area_mean_commute'] / df['commute']

df['ratio_position_education_max_commute'] = df['position_education_max_commute'] / df['commute']
df['ratio_position_education_min_commute'] = df['position_education_min_commute'] / df['commute']
df['ratio_position_education_mean_commute'] = df['position_education_mean_commute'] / df['commute']

df['ratio_position_num_child_max_commute'] = df['position_num_child_max_commute'] / df['commute']
df['ratio_position_num_child_min_commute'] = df['position_num_child_min_commute'] / df['commute']
df['ratio_position_num_child_mean_commute'] = df['position_num_child_mean_commute'] / df['commute']

df['ratio_position_partner_max_commute'] = df['position_partner_max_commute'] / df['commute']
df['ratio_position_partner_min_commute'] = df['position_partner_min_commute'] / df['commute']
df['ratio_position_partner_mean_commute'] = df['position_partner_mean_commute'] / df['commute']

df['diff_position_num_child_partner_max_commute'] = df['position_num_child_partner_max_commute'] - df['commute']
df['diff_position_num_child_partner_min_commute'] = df['position_num_child_partner_min_commute'] - df['commute']
df['diff_position_num_child_partner_mean_commute'] = df['position_num_child_partner_mean_commute'] - df['commute']

df['ratio_position_num_child_partner_max_commute'] = df['position_num_child_partner_max_commute'] / df['commute']
df['ratio_position_num_child_partner_min_commute'] = df['position_num_child_partner_min_commute'] / df['commute']
df['ratio_position_num_child_partner_mean_commute'] = df['position_num_child_partner_mean_commute'] / df['commute']

df['diff_position_age_num_child_partner_max_commute'] = df['position_age_num_child_partner_max_commute'] - df['commute']
df['diff_position_age_num_child_partner_min_commute'] = df['position_age_num_child_partner_min_commute'] - df['commute']
df['diff_position_age_num_child_partner_mean_commute'] = df['position_age_num_child_partner_mean_commute'] - df['commute']

df['ratio_position_age_num_child_partner_max_commute'] = df['position_age_num_child_partner_max_commute'] / df['commute']
df['ratio_position_age_num_child_partner_min_commute'] = df['position_age_num_child_partner_min_commute'] / df['commute']
df['ratio_position_age_num_child_partner_mean_commute'] = df['position_age_num_child_partner_mean_commute'] / df['commute']

df['diff_position_area_num_child_partner_max_commute'] = df['position_area_num_child_partner_max_commute'] - df['commute']
df['diff_position_area_num_child_partner_min_commute'] = df['position_area_num_child_partner_min_commute'] - df['commute']
df['diff_position_area_num_child_partner_mean_commute'] = df['position_area_num_child_partner_mean_commute'] - df['commute']

df['diff_position_education_num_child_partner_max_commute'] = df['position_education_num_child_partner_max_commute'] - df['commute']
df['diff_position_education_num_child_partner_min_commute'] = df['position_education_num_child_partner_min_commute'] - df['commute']
df['diff_position_education_num_child_partner_mean_commute'] = df['position_education_num_child_partner_mean_commute'] - df['commute']

df['diff_position_sex_num_child_partner_max_commute'] = df['position_sex_num_child_partner_max_commute'] - df['commute']
df['diff_position_sex_num_child_partner_min_commute'] = df['position_sex_num_child_partner_min_commute'] - df['commute']
df['diff_position_sex_num_child_partner_mean_commute'] = df['position_sex_num_child_partner_mean_commute'] - df['commute']

df['ratio_position_sex_num_child_partner_max_commute'] = df['position_sex_num_child_partner_max_commute'] / df['commute']
df['ratio_position_sex_num_child_partner_min_commute'] = df['position_sex_num_child_partner_min_commute'] / df['commute']
df['ratio_position_sex_num_child_partner_mean_commute'] = df['position_sex_num_child_partner_mean_commute'] / df['commute']

df['overtime_commute_month_ratio'] =   df['overtime'] / (df['commute']*30  + 1)
df['commute_overtime_day_ratio'] = df['commute'] / (df['overtime']/30 + 1)

df['sum_diff_partner_num_child_mean_commute'] = df['diff_partner_mean_commute'] + df['diff_num_child_mean_commute']

df['point1'] = df['position']*10 + df['age'] +  df['education']*10 
df['point2'] = df['position']*5 +  df['education']*3
df['point3'] = df['age']  + df['education']*3 

print (df.columns.values)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#  34%|███▍      | 24/71 [00:00<00:00, 230.15it/s]
# {'groupby': ['position'], 'target': 'education', 'agg': 'mean'}
# mean
# {'groupby': ['position'], 'target': 'age', 'agg': 'max'}
# max
# {'groupby': ['position'], 'target': 'age', 'agg': 'min'}
# min
# {'groupby': ['position'], 'target': 'age', 'agg': 'mean'}
# mean
# {'groupby': ['position'], 'target': 'age', 'agg': 'std'}
# std
# {'groupby': ['position'], 'target': 'age', 'agg': 'nunique'}
# nunique
# {'groupby': ['position'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['age'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['age'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['age'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['age'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['area'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['area'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['area'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['area'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['education'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['education'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['education'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['education'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['sex'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['sex'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['sex'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['sex'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['service_length'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['service_length'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['service_length'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['service_length'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['num_child'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['num_child'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['num_child'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['num_child'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['partner'], 'target': 'commute', 'agg': 'std'}
# std
# {'groupby': ['position', 'sex'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'sex'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'sex'], 'target': 'commute', 'agg': 'min'}
# min
#  75%|███████▍  | 53/71 [00:00<00:00, 170.95it/s]
# {'groupby': ['position', 'age'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'age'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'age'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'area'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'area'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'area'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'education'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'education'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'education'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'num_child'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'num_child'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'num_child'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'num_child', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'num_child', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'num_child', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'age', 'num_child', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'age', 'num_child', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'age', 'num_child', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'area', 'num_child', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# 100%|██████████| 71/71 [00:00<00:00, 136.47it/s]
# {'groupby': ['position', 'area', 'num_child', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'area', 'num_child', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'education', 'num_child', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'education', 'num_child', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'education', 'num_child', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# {'groupby': ['position', 'sex', 'num_child', 'partner'], 'target': 'commute', 'agg': 'mean'}
# mean
# {'groupby': ['position', 'sex', 'num_child', 'partner'], 'target': 'commute', 'agg': 'max'}
# max
# {'groupby': ['position', 'sex', 'num_child', 'partner'], 'target': 'commute', 'agg': 'min'}
# min
# ['age' 'area' 'commute' 'education' 'id' 'num_child' 'overtime' 'partner'
#  'position' 'salary' 'salary_round' 'service_length' 'sex' 'study_time'
#  'age_bin' 'position_mean_education' 'position_max_age' 'position_min_age'
#  'position_mean_age' 'position_std_age' 'position_nunique_age'
#  'position_mean_commute' 'position_max_commute' 'position_min_commute'
#  'position_std_commute' 'age_mean_commute' 'age_max_commute'
#  'age_min_commute' 'age_std_commute' 'area_mean_commute'
#  'area_max_commute' 'area_min_commute' 'area_std_commute'
#  'education_mean_commute' 'education_max_commute' 'education_min_commute'
#  'education_std_commute' 'sex_mean_commute' 'sex_max_commute'
#  'sex_min_commute' 'sex_std_commute' 'service_length_mean_commute'
#  'service_length_max_commute' 'service_length_min_commute'
#  'service_length_std_commute' 'num_child_mean_commute'
#  'num_child_max_commute' 'num_child_min_commute' 'num_child_std_commute'
#  'partner_mean_commute' 'partner_max_commute' 'partner_min_commute'
#  'partner_std_commute' 'position_sex_mean_commute'
#  'position_sex_max_commute' 'position_sex_min_commute'
#  'position_age_mean_commute' 'position_age_max_commute'
#  'position_age_min_commute' 'position_area_mean_commute'
#  'position_area_max_commute' 'position_area_min_commute'
#  'position_education_mean_commute' 'position_education_max_commute'
#  'position_education_min_commute' 'position_num_child_mean_commute'
#  'position_num_child_max_commute' 'position_num_child_min_commute'
#  'position_partner_mean_commute' 'position_partner_max_commute'
#  'position_partner_min_commute' 'position_num_child_partner_mean_commute'
#  'position_num_child_partner_max_commute'
#  'position_num_child_partner_min_commute'
#  'position_age_num_child_partner_mean_commute'
#  'position_age_num_child_partner_max_commute'
#  'position_age_num_child_partner_min_commute'
#  'position_area_num_child_partner_mean_commute'
#  'position_area_num_child_partner_max_commute'
#  'position_area_num_child_partner_min_commute'
#  'position_education_num_child_partner_mean_commute'
#  'position_education_num_child_partner_max_commute'
#  'position_education_num_child_partner_min_commute'
#  'position_sex_num_child_partner_mean_commute'
#  'position_sex_num_child_partner_max_commute'
#  'position_sex_num_child_partner_min_commute' 'diff_position_mean_commute'
#  'diff_age_mean_commute' 'diff_area_mean_commute'
#  'diff_education_mean_commute' 'diff_sex_mean_commute'
#  'diff_service_length_mean_commute' 'diff_num_child_mean_commute'
#  'diff_partner_mean_commute' 'ratio_position_mean_commute'
#  'ratio_age_mean_commute' 'ratio_area_mean_commute'
#  'ratio_education_mean_commute' 'ratio_sex_mean_commute'
#  'ratio_service_length_mean_commute' 'ratio_num_child_mean_commute'
#  'ratio_partner_mean_commute' 'diff_position_max_commute'
#  'diff_age_max_commute' 'diff_area_max_commute'
#  'diff_education_max_commute' 'diff_sex_max_commute'
#  'diff_service_length_max_commute' 'diff_num_child_max_commute'
#  'diff_partner_max_commute' 'ratio_position_max_commute'
#  'ratio_age_max_commute' 'ratio_area_max_commute'
#  'ratio_education_max_commute' 'ratio_sex_max_commute'
#  'ratio_service_length_max_commute' 'ratio_num_child_max_commute'
#  'ratio_partner_max_commute' 'diff_position_min_commute'
#  'diff_age_min_commute' 'diff_area_min_commute'
#  'diff_education_min_commute' 'diff_sex_min_commute'
#  'diff_service_length_min_commute' 'diff_num_child_min_commute'
#  'diff_partner_min_commute' 'ratio_position_min_commute'
#  'ratio_age_min_commute' 'ratio_area_min_commute'
#  'ratio_education_min_commute' 'ratio_sex_min_commute'
#  'ratio_service_length_min_commute' 'ratio_num_child_min_commute'
#  'ratio_partner_min_commute' 'diff_position_mean_age'
#  'diff_position_max_age' 'diff_position_min_age' 'ratio_position_mean_age'
#  'ratio_position_max_age' 'ratio_position_min_age'
#  'diff_position_mean_education' 'ratio_position_mean_education'
#  'diff_position_sex_max_commute' 'diff_position_sex_min_commute'
#  'diff_position_sex_mean_commute' 'diff_position_age_max_commute'
#  'diff_position_age_min_commute' 'diff_position_age_mean_commute'
#  'diff_position_area_max_commute' 'diff_position_area_min_commute'
#  'diff_position_area_mean_commute' 'diff_position_education_max_commute'
#  'diff_position_education_min_commute'
#  'diff_position_education_mean_commute'
#  'diff_position_num_child_max_commute'
#  'diff_position_num_child_min_commute'
#  'diff_position_num_child_mean_commute'
#  'diff_position_partner_max_commute' 'diff_position_partner_min_commute'
#  'diff_position_partner_mean_commute' 'ratio_position_sex_max_commute'
#  'ratio_position_sex_min_commute' 'ratio_position_sex_mean_commute'
#  'ratio_position_age_max_commute' 'ratio_position_age_min_commute'
#  'ratio_position_age_mean_commute' 'ratio_position_area_max_commute'
#  'ratio_position_area_min_commute' 'ratio_position_area_mean_commute'
#  'ratio_position_education_max_commute'
#  'ratio_position_education_min_commute'
#  'ratio_position_education_mean_commute'
#  'ratio_position_num_child_max_commute'
#  'ratio_position_num_child_min_commute'
#  'ratio_position_num_child_mean_commute'
#  'ratio_position_partner_max_commute' 'ratio_position_partner_min_commute'
#  'ratio_position_partner_mean_commute'
#  'diff_position_num_child_partner_max_commute'
#  'diff_position_num_child_partner_min_commute'
#  'diff_position_num_child_partner_mean_commute'
#  'ratio_position_num_child_partner_max_commute'
#  'ratio_position_num_child_partner_min_commute'
#  'ratio_position_num_child_partner_mean_commute'
#  'diff_position_age_num_child_partner_max_commute'
#  'diff_position_age_num_child_partner_min_commute'
#  'diff_position_age_num_child_partner_mean_commute'
#  'ratio_position_age_num_child_partner_max_commute'
#  'ratio_position_age_num_child_partner_min_commute'
#  'ratio_position_age_num_child_partner_mean_commute'
#  'diff_position_area_num_child_partner_max_commute'
#  'diff_position_area_num_child_partner_min_commute'
#  'diff_position_area_num_child_partner_mean_commute'
#  'diff_position_education_num_child_partner_max_commute'
#  'diff_position_education_num_child_partner_min_commute'
#  'diff_position_education_num_child_partner_mean_commute'
#  'diff_position_sex_num_child_partner_max_commute'
#  'diff_position_sex_num_child_partner_min_commute'
#  'diff_position_sex_num_child_partner_mean_commute'
#  'ratio_position_sex_num_child_partner_max_commute'
#  'ratio_position_sex_num_child_partner_min_commute'
#  'ratio_position_sex_num_child_partner_mean_commute'
#  'overtime_commute_month_ratio' 'commute_overtime_day_ratio'
#  'sum_diff_partner_num_child_mean_commute' 'point1' 'point2' 'point3']

# %%
# %%time
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold
from sklearn.metrics import mean_absolute_error

def preprocess(train_df,test_df,feats):
    train_df = train_df.replace([np.inf, -np.inf], np.nan)
    train_df = train_df.fillna(0) 

    test_df = test_df.replace([np.inf, -np.inf], np.nan)
    test_df = test_df.fillna(0)
    
    scaler = StandardScaler()
    train_df[feats] = scaler.fit_transform(train_df[feats])
    test_df[feats] = scaler.transform(test_df[feats])
    
    return train_df[feats], test_df[feats]

def lgb_kfold(train_df,test_df,features,target,cat_features,folds,params):
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])

    cv_list = []
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[features], train_df['salary_round'])):
        print ('FOLD:' + str(n_fold))
        
        train_x, train_y = train_df[features].iloc[train_idx], train_df[target].iloc[train_idx]
        valid_x, valid_y = train_df[features].iloc[valid_idx], train_df[target].iloc[valid_idx]
        
        print ('train_x shape:',train_x.shape)
        print ('valid_x shape:',valid_x.shape)
        
        dtrain = lgb.Dataset(train_x, label=train_y,categorical_feature=cat_features)
        dval = lgb.Dataset(valid_x, label=valid_y, reference=dtrain,categorical_feature=cat_features) 
        bst = lgb.train(params, dtrain, num_boost_round=50000,
            valid_sets=[dval,dtrain], verbose_eval=500,early_stopping_rounds=500, ) 
        new_list = sorted(zip(features, bst.feature_importance('gain')),key=lambda x: x[1], reverse=True)[:]
        for item in new_list:
            print (item) 
         
        oof_preds[valid_idx] = bst.predict(valid_x, num_iteration=bst.best_iteration)
        oof_cv = mean_absolute_error(valid_y,  oof_preds[valid_idx])
        cv_list.append(oof_cv)
        print (cv_list)
        sub_preds += bst.predict(test_df[features], num_iteration=bst.best_iteration) / folds.n_splits
 
    cv = mean_absolute_error(train_df[target],  oof_preds)
    print('Full OOF MAE %.6f' % cv)  

    train_df['lgb_y'] = oof_preds
    test_df['lgb_y'] = sub_preds
    
    return train_df,test_df

params = {
               "objective" : "regression", 
               "boosting" : "gbdt", 
               "metric" : "mae",  
               "max_depth": -1,
               "min_data_in_leaf": 10, 
               "min_gain_to_split": 0.05,
                "min_child_weight": 0.001,
                "reg_alpha": 0.1, 
                "reg_lambda": 10, 
               "num_leaves" : 21, 
               "max_bin" : 300, 
              "learning_rate" :0.01,
               "bagging_fraction" : 0.9,
               "bagging_freq" : 1,
               "bagging_seed" : 4590,
               "feature_fraction" : 0.15,
               "verbosity": -1,
               "boost_from_average": False,
}

train_df = df[df['salary'].notnull()] 
test_df = df[df['salary'].isnull()] 

drop_features=['id', 'salary', 'y',    
"sex_mean_commute",
"sex_max_commute",
"sex_min_commute",
"sex_std_commute",
"service_length_mean_commute",
"service_length_max_commute",
"service_length_min_commute",
"service_length_std_commute",
"partner_mean_commute",
"partner_max_commute",
"partner_min_commute",
"partner_std_commute",
"diff_age_mean_commute",
"area",
"diff_service_length_mean_commute",
"ratio_service_length_mean_commute",
"diff_age_max_commute",
"diff_education_max_commute",
'num_child_std_commute', 
"diff_sex_max_commute",
"diff_service_length_max_commute",
"ratio_position_min_age",
'study_time',  
'position_nunique_area',      
'position_sex_max_commute', 
'position_sex_std_commute',
 'diff_position_sex_mean_commute',
'position_age_mean_commute', 'position_age_max_commute','position_age_min_commute', 
'diff_position_age_max_commute',              
'position_area_mean_commute', 'position_area_max_commute', 'position_area_min_commute',               
'position_education_mean_commute', 'position_education_max_commute', 'position_education_min_commute',                            
 'position_num_child_mean_commute', 'position_num_child_max_commute', 'position_num_child_min_commute',            
'position_partner_mean_commute', 'position_partner_max_commute', 'position_partner_min_commute',
'position_num_child_partner_mean_commute', 'position_num_child_partner_max_commute', 'position_num_child_partner_min_commute',
'position_age_num_child_partner_mean_commute', 'position_age_num_child_partner_max_commute', 'position_age_num_child_partner_min_commute',
'position_area_num_child_partner_mean_commute', 'position_area_num_child_partner_max_commute', 'position_area_num_child_partner_min_commute',
'age_sex_mean_commute', 'age_sex_max_commute', 'age_sex_min_commute',
'age_area_mean_commute', 'age_area_max_commute', 'age_area_min_commute', 
'age_education_mean_commute', 'age_education_max_commute', 'age_education_min_commute',
'age_num_child_mean_commute', 'age_num_child_max_commute', 'age_num_child_min_commute',
'age_partner_mean_commute', 'age_partner_max_commute', 'age_partner_min_commute',     
"ratio_sex_max_commute",
"area_min_commute",
"diff_sex_min_commute",   
"salary_round"
]


features = [f for f in train_df.columns if f not in drop_features]
target = 'salary'
cat_features = [
'partner',    
'sex',  

]

print ('features:', len(features), features)
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=223)
train_lgb,test_lgb = lgb_kfold(train_df,test_df,features,target,cat_features,folds,params)
# Out:
# features: 152 ['age', 'commute', 'education', 'num_child', 'overtime', 'partner', 'position', 'service_length', 'sex', 'age_bin', 'position_mean_education', 'position_max_age', 'position_min_age', 'position_mean_age', 'position_std_age', 'position_nunique_age', 'position_mean_commute', 'position_max_commute', 'position_min_commute', 'position_std_commute', 'age_mean_commute', 'age_max_commute', 'age_min_commute', 'age_std_commute', 'area_mean_commute', 'area_max_commute', 'area_std_commute', 'education_mean_commute', 'education_max_commute', 'education_min_commute', 'education_std_commute', 'num_child_mean_commute', 'num_child_max_commute', 'num_child_min_commute', 'position_sex_mean_commute', 'position_sex_min_commute', 'position_education_num_child_partner_mean_commute', 'position_education_num_child_partner_max_commute', 'position_education_num_child_partner_min_commute', 'position_sex_num_child_partner_mean_commute', 'position_sex_num_child_partner_max_commute', 'position_sex_num_child_partner_min_commute', 'diff_position_mean_commute', 'diff_area_mean_commute', 'diff_education_mean_commute', 'diff_sex_mean_commute', 'diff_num_child_mean_commute', 'diff_partner_mean_commute', 'ratio_position_mean_commute', 'ratio_age_mean_commute', 'ratio_area_mean_commute', 'ratio_education_mean_commute', 'ratio_sex_mean_commute', 'ratio_num_child_mean_commute', 'ratio_partner_mean_commute', 'diff_position_max_commute', 'diff_area_max_commute', 'diff_num_child_max_commute', 'diff_partner_max_commute', 'ratio_position_max_commute', 'ratio_age_max_commute', 'ratio_area_max_commute', 'ratio_education_max_commute', 'ratio_service_length_max_commute', 'ratio_num_child_max_commute', 'ratio_partner_max_commute', 'diff_position_min_commute', 'diff_age_min_commute', 'diff_area_min_commute', 'diff_education_min_commute', 'diff_service_length_min_commute', 'diff_num_child_min_commute', 'diff_partner_min_commute', 'ratio_position_min_commute', 'ratio_age_min_commute', 'ratio_area_min_commute', 'ratio_education_min_commute', 'ratio_sex_min_commute', 'ratio_service_length_min_commute', 'ratio_num_child_min_commute', 'ratio_partner_min_commute', 'diff_position_mean_age', 'diff_position_max_age', 'diff_position_min_age', 'ratio_position_mean_age', 'ratio_position_max_age', 'diff_position_mean_education', 'ratio_position_mean_education', 'diff_position_sex_max_commute', 'diff_position_sex_min_commute', 'diff_position_age_min_commute', 'diff_position_age_mean_commute', 'diff_position_area_max_commute', 'diff_position_area_min_commute', 'diff_position_area_mean_commute', 'diff_position_education_max_commute', 'diff_position_education_min_commute', 'diff_position_education_mean_commute', 'diff_position_num_child_max_commute', 'diff_position_num_child_min_commute', 'diff_position_num_child_mean_commute', 'diff_position_partner_max_commute', 'diff_position_partner_min_commute', 'diff_position_partner_mean_commute', 'ratio_position_sex_max_commute', 'ratio_position_sex_min_commute', 'ratio_position_sex_mean_commute', 'ratio_position_age_max_commute', 'ratio_position_age_min_commute', 'ratio_position_age_mean_commute', 'ratio_position_area_max_commute', 'ratio_position_area_min_commute', 'ratio_position_area_mean_commute', 'ratio_position_education_max_commute', 'ratio_position_education_min_commute', 'ratio_position_education_mean_commute', 'ratio_position_num_child_max_commute', 'ratio_position_num_child_min_commute', 'ratio_position_num_child_mean_commute', 'ratio_position_partner_max_commute', 'ratio_position_partner_min_commute', 'ratio_position_partner_mean_commute', 'diff_position_num_child_partner_max_commute', 'diff_position_num_child_partner_min_commute', 'diff_position_num_child_partner_mean_commute', 'ratio_position_num_child_partner_max_commute', 'ratio_position_num_child_partner_min_commute', 'ratio_position_num_child_partner_mean_commute', 'diff_position_age_num_child_partner_max_commute', 'diff_position_age_num_child_partner_min_commute', 'diff_p ...
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# FOLD:0
# train_x shape: (16614, 152)
# valid_x shape: (4386, 152)
# /usr/local/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# Training until validation scores don't improve for 500 rounds.
# [500]	training's l1: 22.5052	valid_0's l1: 23.5762
# [1000]	training's l1: 19.8303	valid_0's l1: 21.53
# [1500]	training's l1: 18.7121	valid_0's l1: 20.8931
# [2000]	training's l1: 17.9802	valid_0's l1: 20.6733
# [2500]	training's l1: 17.3926	valid_0's l1: 20.5523
# [3000]	training's l1: 16.8869	valid_0's l1: 20.4869
# [3500]	training's l1: 16.4406	valid_0's l1: 20.4523
# [4000]	training's l1: 16.0388	valid_0's l1: 20.4341
# [4500]	training's l1: 15.6606	valid_0's l1: 20.4294
# [5000]	training's l1: 15.3067	valid_0's l1: 20.43
# Early stopping, best iteration is:
# [4788]	training's l1: 15.4532	valid_0's l1: 20.4238
# ('sum_diff_partner_num_child_mean_commute', 2513107228.778412)
# ('diff_partner_mean_commute', 1424414635.361145)
# ('point1', 1337132463.1055298)
# ('diff_num_child_mean_commute', 1263500112.661316)
# ('ratio_partner_max_commute', 1234086200.49292)
# ('point2', 958231887.1917725)
# ('ratio_partner_mean_commute', 760083234.8322754)
# ('position', 741862541.1239624)
# ('diff_num_child_max_commute', 725537183.895752)
# ('point3', 657185727.1557312)
# ('diff_num_child_min_commute', 601724512.914856)
# ('age', 566480974.8879395)
# ('position_max_age', 381707743.9111328)
# ('ratio_position_partner_max_commute', 359538042.51452637)
# ('diff_position_num_child_partner_mean_commute', 355903503.0913696)
# ('age_mean_commute', 346325970.17803955)
# ('position_mean_commute', 314851992.1660156)
# ('age_min_commute', 282393210.4869385)
# ('education_mean_commute', 248550955.16760254)
# ('diff_position_area_num_child_partner_mean_commute', 239102253.72528076)
# ('ratio_position_num_child_partner_max_commute', 233526916.85858154)
# ('diff_position_partner_mean_commute', 216877593.82965088)
# ('diff_position_sex_num_child_partner_mean_commute', 215165640.14266968)
# ('position_mean_education', 213663105.44293213)
# ('diff_position_area_num_child_partner_min_commute', 211847570.31591797)
# ('position_mean_age', 176169946.07720947)
# ('position_max_commute', 171101081.8862915)
# ('age_std_commute', 164219610.23184204)
# ('ratio_partner_min_commute', 158342499.84313965)
# ('education_std_commute', 144052986.05950928)
# ('diff_position_area_num_child_partner_max_commute', 143658268.6881714)
# ('ratio_num_child_mean_commute', 135940658.39190674)
# ('diff_position_mean_education', 133916890.69314575)
# ('diff_position_sex_num_child_partner_min_commute', 129250668.57513428)
# ('ratio_position_num_child_partner_mean_commute', 122418138.05230713)
# ('age_bin', 118196722.1876831)
# ('diff_position_num_child_partner_min_commute', 115947964.38311768)
# ('education', 112798323.13763428)
# ('position_sex_min_commute', 108037206.1027832)
# ('diff_partner_min_commute', 106761960.51171875)
# ('diff_position_age_num_child_partner_min_commute', 98898176.50332642)
# ('position_sex_mean_commute', 85508100.34143066)
# ('overtime', 81776481.17669678)
# ('position_min_commute', 80562342.48370361)
# ('ratio_position_education_min_commute', 79646157.74310303)
# ('ratio_position_mean_education', 78728374.41833496)
# ('position_std_commute', 77617339.58947754)
# ('diff_area_max_commute', 73128847.82098389)
# ('position_min_age', 71734921.27508545)
# ('diff_partner_max_commute', 70681004.60760498)
# ('diff_position_age_num_child_partner_mean_commute', 70418960.84701538)
# ('ratio_area_max_commute', 64451372.30899048)
# ('ratio_position_sex_num_child_partner_max_commute', 62572748.857910156)
# ('diff_sex_mean_commute', 61010241.7618103)
# ('service_length', 60361355.56744385)
# ('position_sex_num_child_partner_mean_commute', 58345645.644348145)
# ('diff_area_mean_commute', 53162991.29193115)
# ('position_std_age', 51670303.371032715)
# ('ratio_position_age_min_commute', 49564072.64581299)
# ('num_child', 45381470.57141113)
# ('ratio_position_num_child_mean_commute', 40354811.98327637)
# ('education_max_commute', 39269062.88391113)
# ('position_education_num_child_partner_mean_commute', 39237611.89819336)
# ('diff_position_min_age', 34573775.889038086)
# ('position_nunique_age', 34384638.7210083)
# ('diff_position_num_child_mean_commute', 34338701.411102295)
# ('overtime_commute_month_ratio', 33688382.58782959)
# ('ratio_position_sex_num_child_partner_mean_commute', 31803127.860229492)
# ('ratio_area_mean_commute', 30989674.619018555)
# ('position_education_num_child_partner_min_commute', 30584056.58770752)
# ('position_sex_num_child_partner_max_commute', 28796827.932250977)
# ('ratio_position_area_max_commute', 28086572.37475586)
# ('ratio_position_area_mean_commute', 28030178.255493164)
# ('ratio_sex_min_commute', 27991521.44088745)
# ('diff_position_max_age', 27806319.25140381)
# ('ratio_position_age_num_child_partner_mean_commute', 27718190.167175293)
# ('position_sex_num_child_partner_min_commute', 26667712.421569824)
# ('diff_position_area_max_commute', 24899548.679992676)
# ('ratio_position_age_num_child_partner_max_commute', 24290590.239959717)
# ('education_min_commute', 23094156.259155273)
# ('ratio_position_sex_max_commute', 21645325.283996582)
# ('ratio_position_education_max_commute', 21599265.765075684)
# ('ratio_position_partner_mean_commute', 21598040.122680664)
# ('ratio_position_max_commute', 21142901.92376709)
# ('diff_education_mean_commute', 20880736.128936768)
# ('num_child_mean_commute', 20168778.892333984)
# ('num_child_min_commute', 19224224.898986816)
# ('ratio_num_child_max_commute', 19160587.49871826)
# ('diff_position_education_num_child_partner_min_commute', 19018295.052734375)
# ('diff_position_education_num_child_partner_mean_commute', 18421933.294189453)
# ('diff_position_num_child_max_commute', 18235955.408447266)
# ('diff_position_area_mean_commute', 17748879.070770264)
# ('ratio_position_max_age', 16893018.30630493)
# ('ratio_area_min_commute', 16547215.635925293)
# ('area_std_commute', 16399533.084350586)
# ('ratio_position_partner_min_commute', 16200372.113952637)
# ('ratio_sex_mean_commute', 15326793.880310059)
# ('ratio_position_education_mean_commute', 14859425.555053711)
# ('diff_position_age_mean_commute', 14705546.927093506)
# ('diff_position_partner_min_commute', 14578987.222045898)
# ('area_mean_commute', 14207823.277557373)
# ('ratio_position_sex_min_commute', 14018996.697753906)
# ('commute_overtime_day_ratio', 13980773.037658691)
# ('ratio_age_min_commute', 13917946.38494873)
# ('ratio_education_mean_commute', 13904272.433227539)
# ('ratio_position_age_num_child_partner_min_commute', 13280351.382873535)
# ('ratio_position_num_child_min_commute', 13181902.420288086)
# ('ratio_position_num_child_partner_min_commute', 12885718.86315918)
# ('ratio_education_max_commute', 12135340.347229004)
# ('diff_position_partner_max_commute', 11261893.770019531)
# ('diff_position_area_min_commute', 10621966.275939941)
# ('ratio_position_age_mean_commute', 10366482.92352295)
# ('ratio_position_mean_commute', 9353423.350463867)
# ('diff_position_mean_age', 8626731.854064941)
# ('diff_position_num_child_min_commute', 7857608.6447143555)
# ('diff_position_max_commute', 7833163.879150391)
# ('ratio_service_length_max_commute', 7768434.403869629)
# ('ratio_age_mean_commute', 7722519.828674316)
# ('diff_position_education_mean_commute', 7707930.043518066)
# ('ratio_position_age_max_commute', 7638592.488647461)
# ('commute', 7476101.184875488)
# ('ratio_position_mean_age', 7427389.188110352)
# ('ratio_position_num_child_max_commute', 7356232.958374023)
# ('ratio_education_min_commute', 7212410.480102539)
# ('diff_position_num_child_partner_max_commute', 7093581.960388184)
# ('ratio_position_min_commute', 6880609.91217041)
# ('diff_position_mean_commute', 6782920.0113220215)
# ('ratio_position_sex_num_child_partner_min_commute', 6740203.496582031)
# ('diff_position_sex_num_child_partner_max_commute', 6493834.410705566)
# ('diff_position_education_num_child_partner_max_commute', 6253680.470825195)
# ('diff_position_education_max_commute', 5875476.629638672)
# ('sex', 5708560.30456543)
# ('area_max_commute', 5535824.722808838)
# ('diff_age_min_commute', 5520493.043029785)
# ('ratio_position_area_min_commute', 5458788.0900268555)
# ('diff_position_age_num_child_partner_max_commute', 5030601.808654785)
# ('diff_position_sex_min_commute', 4949112.450927734)
# ('diff_education_min_commute', 4832092.552246094)
# ('diff_position_age_min_commute', 4693519.683959961)
# ('diff_position_sex_max_commute', 4674620.3298950195)
# ('diff_position_education_min_commute', 4359291.397827148)
# ('num_child_max_commute', 4111379.807800293)
# ('ratio_service_length_min_commute', 4069505.062927246)
# ('ratio_num_child_min_commute', 3956852.397644043)
# ('ratio_age_max_commute', 3944208.0143432617)
# ('ratio_position_sex_mean_commute', 3943667.1237182617)
# ('position_education_num_child_partner_max_commute', 3919911.863586426)
# ('diff_service_length_min_commute', 3245978.0107421875)
# ('age_max_commute', 2724205.9697875977)
# ('diff_area_min_commute', 1814497.0232543945)
# ('diff_position_min_commute', 1410795.4858398438)
# ('partner', 245389.98583984375)
# [20.42383684524302]
# FOLD:1
# train_x shape: (16552, 152)
# valid_x shape: (4448, 152)
# Training until validation scores don't improve for 500 rounds.
# [500]	training's l1: 22.4198	valid_0's l1: 25.1681
# [1000]	training's l1: 19.7734	valid_0's l1: 22.351
# [1500]	training's l1: 18.6654	valid_0's l1: 21.6676
# [2000]	training's l1: 17.9477	valid_0's l1: 21.4107
# [2500]	training's l1: 17.3647	valid_0's l1: 21.2818
# [3000]	training's l1: 16.8662	valid_0's l1: 21.203
# [3500]	training's l1: 16.4257	valid_0's l1: 21.1597
# [4000]	training's l1: 16.0176	valid_0's l1: 21.1205
# [4500]	training's l1: 15.6338	valid_0's l1: 21.0994
# [5000]	training's l1: 15.2792	valid_0's l1: 21.097
# Early stopping, best iteration is:
# [4812]	training's l1: 15.4111	valid_0's l1: 21.0941
# ('sum_diff_partner_num_child_mean_commute', 2285522935.2713623)
# ('diff_partner_mean_commute', 1266732957.6325073)
# ('point2', 1201064831.3963623)
# ('point1', 1189252527.87854)
# ('diff_num_child_mean_commute', 1034228844.3967285)
# ('ratio_partner_max_commute', 887127147.3186646)
# ('age', 720407713.2071228)
# ('ratio_partner_mean_commute', 711953771.642273)
# ('point3', 689364476.7374268)
# ('diff_num_child_max_commute', 597556020.1459961)
# ('diff_num_child_min_commute', 552296533.6506958)
# ('position', 436591886.0922241)
# ('age_mean_commute', 392443974.9954834)
# ('position_max_age', 363278768.364563)
# ('diff_position_num_child_partner_mean_commute', 323185705.4182129)
# ('ratio_position_num_child_partner_max_commute', 285968756.5090332)
# ('diff_position_area_num_child_partner_min_commute', 276414503.0689697)
# ('diff_position_area_num_child_partner_mean_commute', 271334260.0678711)
# ('age_min_commute', 264753703.8826294)
# ('position_mean_commute', 223616099.28253174)
# ('position_max_commute', 203464357.88098145)
# ('position_mean_education', 196131830.3482666)
# ('diff_position_sex_num_child_partner_mean_commute', 171874607.03363037)
# ('ratio_partner_min_commute', 168545648.07104492)
# ('age_std_commute', 154436602.4607849)
# ('diff_position_partner_mean_commute', 153243496.3723755)
# ('ratio_position_partner_max_commute', 150678271.71038818)
# ('position_mean_age', 150429461.23693848)
# ('education_mean_commute', 129006675.21298218)
# ('ratio_num_child_mean_commute', 124211170.85205078)
# ('age_bin', 113663415.96594238)
# ('ratio_position_num_child_partner_mean_commute', 113098782.34399414)
# ('education_std_commute', 102526768.75061035)
# ('ratio_position_sex_num_child_partner_max_commute', 101493072.4644165)
# ('diff_position_mean_education', 99714991.64660645)
# ('diff_partner_min_commute', 98926505.23815918)
# ('ratio_position_education_min_commute', 93988590.09136963)
# ('diff_partner_max_commute', 87808056.97991943)
# ('education', 85691715.56826782)
# ('overtime', 85649558.36260986)
# ('ratio_sex_min_commute', 81908040.81726074)
# ('diff_position_age_num_child_partner_mean_commute', 80919345.1826477)
# ('position_sex_mean_commute', 77171960.93859863)
# ('diff_position_area_num_child_partner_max_commute', 75247460.12728882)
# ('position_min_commute', 67072919.63555908)
# ('diff_position_age_num_child_partner_min_commute', 65692943.28234863)
# ('position_sex_num_child_partner_mean_commute', 62972295.200531006)
# ('position_min_age', 62583457.2800293)
# ('diff_area_max_commute', 62178950.80938721)
# ('position_std_commute', 57062867.97540283)
# ('ratio_area_max_commute', 54989979.38296509)
# ('diff_sex_mean_commute', 54943268.79174805)
# ('diff_position_num_child_partner_min_commute', 54566357.459228516)
# ('ratio_position_mean_education', 54076331.59283447)
# ('position_std_age', 51638983.68261719)
# ('service_length', 48647699.373291016)
# ('num_child', 48162921.85449219)
# ('position_sex_min_commute', 46890390.07922363)
# ('diff_area_mean_commute', 46694167.29968262)
# ('diff_position_sex_num_child_partner_min_commute', 44821277.793273926)
# ('ratio_position_age_min_commute', 41694696.524017334)
# ('position_education_num_child_partner_min_commute', 35848998.20666504)
# ('position_nunique_age', 35627299.73736572)
# ('ratio_num_child_max_commute', 34883261.76373291)
# ('position_education_num_child_partner_mean_commute', 34796465.99395752)
# ('position_sex_num_child_partner_max_commute', 33618922.43701172)
# ('overtime_commute_month_ratio', 33177887.3939209)
# ('ratio_position_sex_num_child_partner_mean_commute', 31776728.19290161)
# ('ratio_area_mean_commute', 30196993.90447998)
# ('ratio_position_age_num_child_partner_mean_commute', 29475049.060577393)
# ('ratio_position_area_max_commute', 28578146.659973145)
# ('diff_position_min_age', 27602652.442871094)
# ('position_sex_num_child_partner_min_commute', 27337175.567626953)
# ('diff_position_num_child_mean_commute', 26733035.459503174)
# ('ratio_position_age_num_child_partner_max_commute', 24916474.05227661)
# ('ratio_position_partner_mean_commute', 24226817.70223999)
# ('num_child_min_commute', 23252171.295837402)
# ('diff_position_max_age', 22911593.417999268)
# ('education_max_commute', 22507369.025146484)
# ('ratio_age_min_commute', 21818627.655181885)
# ('ratio_sex_mean_commute', 21692498.83544922)
# ('diff_position_partner_min_commute', 21027776.65032959)
# ('ratio_position_area_mean_commute', 20333944.898773193)
# ('diff_education_mean_commute', 20141086.07321167)
# ('diff_position_education_num_child_partner_min_commute', 20129958.88220215)
# ('diff_position_education_num_child_partner_mean_commute', 19696377.07611084)
# ('num_child_mean_commute', 19586443.44744873)
# ('diff_position_area_max_commute', 19155968.129241943)
# ('ratio_position_sex_max_commute', 18524795.58532715)
# ('ratio_position_num_child_partner_min_commute', 18028625.405151367)
# ('ratio_position_sex_min_commute', 17210949.522583008)
# ('area_std_commute', 16738195.958435059)
# ('ratio_area_min_commute', 16181070.116577148)
# ('diff_position_num_child_max_commute', 15212861.87310791)
# ('ratio_position_partner_min_commute', 15058511.221801758)
# ('ratio_position_education_mean_commute', 14678161.1852417)
# ('ratio_position_age_num_child_partner_min_commute', 14434757.78314209)
# ('ratio_position_num_child_mean_commute', 14176131.086608887)
# ('diff_position_area_mean_commute', 13715896.885498047)
# ('ratio_position_age_mean_commute', 13671285.566253662)
# ('area_mean_commute', 13473424.82220459)
# ('diff_position_age_mean_commute', 13403041.533111572)
# ('commute_overtime_day_ratio', 12940621.60760498)
# ('ratio_position_max_age', 12844067.188537598)
# ('ratio_position_education_max_commute', 12698854.01965332)
# ('education_min_commute', 11063599.793640137)
# ('diff_position_education_mean_commute', 10631365.816101074)
# ('ratio_position_num_child_min_commute', 10498588.592163086)
# ('ratio_position_max_commute', 10482243.098693848)
# ('ratio_position_min_commute', 10460702.975952148)
# ('ratio_position_mean_commute', 10240663.539550781)
# ('ratio_num_child_min_commute', 9969444.765563965)
# ('ratio_position_num_child_max_commute', 9594297.001708984)
# ('ratio_education_max_commute', 8974539.191101074)
# ('ratio_education_min_commute', 8904347.217712402)
# ('ratio_age_mean_commute', 8444394.346862793)
# ('diff_position_mean_age', 8001610.798736572)
# ('diff_position_education_num_child_partner_max_commute', 7994827.405395508)
# ('diff_position_max_commute', 7933694.321563721)
# ('ratio_service_length_max_commute', 7844074.8005981445)
# ('diff_position_num_child_partner_max_commute', 7830623.22253418)
# ('ratio_education_mean_commute', 7825578.375)
# ('commute', 7349247.448974609)
# ('diff_position_sex_max_commute', 7320685.643249512)
# ('ratio_position_sex_num_child_partner_min_commute', 7229734.786254883)
# ('sex', 7145918.825256348)
# ('ratio_position_mean_age', 6742820.605377197)
# ('diff_position_age_min_commute', 6706769.556762695)
# ('diff_position_num_child_min_commute', 6603918.249328613)
# ('ratio_position_age_max_commute', 6530567.976501465)
# ('diff_position_partner_max_commute', 6347787.818572998)
# ('diff_position_sex_num_child_partner_max_commute', 5874051.55859375)
# ('ratio_service_length_min_commute', 5638952.558166504)
# ('ratio_position_area_min_commute', 5496351.675933838)
# ('area_max_commute', 5448802.626342773)
# ('ratio_position_sex_mean_commute', 5354544.554931641)
# ('diff_position_education_max_commute', 5017579.451263428)
# ('diff_position_sex_min_commute', 4934806.243041992)
# ('ratio_age_max_commute', 4842724.391937256)
# ('diff_position_area_min_commute', 4504734.670837402)
# ('diff_position_education_min_commute', 4433444.601837158)
# ('diff_position_age_num_child_partner_max_commute', 4055622.353515625)
# ('num_child_max_commute', 4036709.523498535)
# ('position_education_num_child_partner_max_commute', 4002160.4892578125)
# ('diff_education_min_commute', 3905636.4263916016)
# ('diff_position_mean_commute', 3143268.5462646484)
# ('diff_age_min_commute', 3019718.883911133)
# ('diff_service_length_min_commute', 2933225.024169922)
# ('age_max_commute', 2810943.4650268555)
# ('diff_area_min_commute', 2025231.5240478516)
# ('diff_position_min_commute', 1146747.1806640625)
# ('partner', 463717.1806640625)
# [20.42383684524302, 21.094076624308418]
# FOLD:2
# train_x shape: (16851, 152)
# valid_x shape: (4149, 152)
# Training until validation scores don't improve for 500 rounds.
# [500]	training's l1: 22.5588	valid_0's l1: 22.9139
# [1000]	training's l1: 19.8461	valid_0's l1: 21.1538
# [1500]	training's l1: 18.7414	valid_0's l1: 20.6703
# [2000]	training's l1: 18.0352	valid_0's l1: 20.4766
# [2500]	training's l1: 17.4719	valid_0's l1: 20.3865
# [3000]	training's l1: 16.9763	valid_0's l1: 20.3462
# [3500]	training's l1: 16.5421	valid_0's l1: 20.3289
# [4000]	training's l1: 16.1328	valid_0's l1: 20.3199
# [4500]	training's l1: 15.7525	valid_0's l1: 20.3132
# Early stopping, best iteration is:
# [4370]	training's l1: 15.8469	valid_0's l1: 20.307
# ('sum_diff_partner_num_child_mean_commute', 2509887606.2070923)
# ('diff_partner_mean_commute', 1469922424.1629028)
# ('ratio_partner_max_commute', 1420708584.2687988)
# ('point1', 1322310212.249878)
# ('diff_num_child_mean_commute', 928581517.395813)
# ('point2', 907630376.4846802)
# ('diff_num_child_min_commute', 831890771.9555054)
# ('age', 825646850.9529114)
# ('ratio_partner_mean_commute', 793295833.2441406)
# ('point3', 676048327.0838623)
# ('diff_num_child_max_commute', 630200897.6078491)
# ('position', 596807214.1358032)
# ('position_max_age', 409143262.0930176)
# ('ratio_position_partner_max_commute', 350143552.0461731)
# ('diff_position_area_num_child_partner_mean_commute', 329214058.7969971)
# ('diff_position_num_child_partner_mean_commute', 313252013.5474243)
# ('diff_position_area_num_child_partner_min_commute', 297800925.64819336)
# ('age_mean_commute', 286000677.88812256)
# ('education_mean_commute', 267223330.27770996)
# ('age_min_commute', 250898947.67266846)
# ('diff_position_partner_mean_commute', 243718122.20007324)
# ('position_max_commute', 242862555.8178711)
# ('ratio_position_num_child_partner_max_commute', 241143255.50952148)
# ('position_mean_commute', 239114274.98931885)
# ('diff_position_sex_num_child_partner_mean_commute', 218410246.36816406)
# ('position_mean_education', 215494338.88031006)
# ('position_mean_age', 187857649.85211182)
# ('ratio_partner_min_commute', 176642356.3484497)
# ('age_std_commute', 167581288.43518066)
# ('diff_position_age_num_child_partner_min_commute', 160521702.41497803)
# ('education_std_commute', 146614395.34039307)
# ('education', 142052591.79190063)
# ('diff_position_mean_education', 139302741.2074585)
# ('diff_position_area_num_child_partner_max_commute', 135806453.35217285)
# ('age_bin', 131514528.24682617)
# ('ratio_num_child_mean_commute', 129813957.1159668)
# ('position_sex_min_commute', 121027599.97125244)
# ('diff_position_num_child_partner_min_commute', 117496701.26885986)
# ('diff_partner_min_commute', 98278298.99267578)
# ('position_sex_mean_commute', 96322899.94384766)
# ('diff_position_age_num_child_partner_mean_commute', 94158170.92224121)
# ('overtime', 86486260.16522217)
# ('ratio_position_education_min_commute', 83884177.6986084)
# ('ratio_position_mean_education', 83854634.73052979)
# ('diff_partner_max_commute', 79402470.18005371)
# ('position_min_commute', 79259882.58526611)
# ('diff_position_sex_num_child_partner_min_commute', 73189869.90472412)
# ('ratio_position_sex_num_child_partner_max_commute', 72352030.6315918)
# ('diff_area_max_commute', 67063811.9765625)
# ('position_min_age', 66353793.66027832)
# ('position_std_commute', 62737675.867004395)
# ('position_sex_num_child_partner_mean_commute', 60633381.54071045)
# ('service_length', 60128475.7437439)
# ('diff_sex_mean_commute', 57056821.59240723)
# ('ratio_position_num_child_partner_mean_commute', 52750894.66070557)
# ('diff_area_mean_commute', 51294424.65716553)
# ('num_child', 48539194.47564697)
# ('ratio_area_max_commute', 48065895.73345947)
# ('position_education_num_child_partner_mean_commute', 47703432.50915527)
# ('position_nunique_age', 47547719.019348145)
# ('ratio_position_age_min_commute', 46174084.58319092)
# ('diff_position_num_child_mean_commute', 46026117.922180176)
# ('education_max_commute', 44179421.26385498)
# ('ratio_position_partner_mean_commute', 41602738.32495117)
# ('position_std_age', 41500444.12097168)
# ('ratio_area_mean_commute', 40847077.66555786)
# ('position_sex_num_child_partner_min_commute', 37524744.26873779)
# ('ratio_position_num_child_mean_commute', 37521084.40496826)
# ('diff_position_min_age', 35718172.593811035)
# ('position_education_num_child_partner_min_commute', 35493024.664489746)
# ('overtime_commute_month_ratio', 34270048.39337158)
# ('ratio_sex_min_commute', 28016002.31970215)
# ('position_sex_num_child_partner_max_commute', 26863702.75)
# ('ratio_position_age_num_child_partner_max_commute', 25361714.172058105)
# ('diff_position_area_max_commute', 24868031.313354492)
# ('ratio_position_age_num_child_partner_mean_commute', 24840395.763305664)
# ('num_child_min_commute', 23139451.615600586)
# ('ratio_position_area_mean_commute', 23123277.06829834)
# ('diff_position_max_age', 22081482.355163574)
# ('num_child_mean_commute', 21924705.433532715)
# ('ratio_position_sex_num_child_partner_mean_commute', 21154772.566589355)
# ('diff_position_num_child_max_commute', 20317094.726531982)
# ('ratio_num_child_max_commute', 19799328.408569336)
# ('education_min_commute', 19778110.684936523)
# ('ratio_sex_mean_commute', 19395723.421813965)
# ('ratio_position_area_max_commute', 19018588.199890137)
# ('ratio_position_max_commute', 18263233.03503418)
# ('diff_position_partner_min_commute', 17418929.479553223)
# ('ratio_area_min_commute', 16893237.26397705)
# ('ratio_position_education_mean_commute', 16839208.7545166)
# ('ratio_position_age_mean_commute', 16778813.557250977)
# ('diff_position_area_mean_commute', 16496472.304901123)
# ('diff_position_education_num_child_partner_mean_commute', 16244090.689086914)
# ('ratio_position_education_max_commute', 15979306.1875)
# ('ratio_position_max_age', 15530897.235839844)
# ('area_std_commute', 15496532.850708008)
# ('ratio_position_sex_max_commute', 15378930.092041016)
# ('area_mean_commute', 14217176.591308594)
# ('diff_position_partner_max_commute', 14124431.092041016)
# ('diff_position_age_mean_commute', 13926160.1038208)
# ('ratio_age_min_commute', 13710175.23034668)
# ('ratio_position_partner_min_commute', 13700962.911254883)
# ('commute_overtime_day_ratio', 13671592.640686035)
# ('diff_position_education_num_child_partner_min_commute', 13175850.923675537)
# ('ratio_position_age_num_child_partner_min_commute', 12912507.632385254)
# ('ratio_position_num_child_max_commute', 12800622.738708496)
# ('ratio_age_mean_commute', 12474814.011138916)
# ('ratio_position_num_child_partner_min_commute', 12370510.361816406)
# ('ratio_education_mean_commute', 12211542.371398926)
# ('ratio_education_min_commute', 12054286.103759766)
# ('ratio_position_num_child_min_commute', 11189454.095214844)
# ('ratio_position_sex_min_commute', 10929464.90649414)
# ('diff_position_max_commute', 10344775.51727295)
# ('ratio_position_age_max_commute', 9556045.591369629)
# ('ratio_position_mean_commute', 8413460.015319824)
# ('diff_position_num_child_partner_max_commute', 8274497.22668457)
# ('diff_position_mean_age', 8110848.798400879)
# ('diff_position_education_num_child_partner_max_commute', 7984908.474182129)
# ('ratio_service_length_max_commute', 7537345.560180664)
# ('diff_position_education_mean_commute', 7465595.571533203)
# ('diff_position_num_child_min_commute', 7455328.1369018555)
# ('ratio_position_mean_age', 6439930.236907959)
# ('diff_education_mean_commute', 6400392.214782715)
# ('sex', 6178319.700378418)
# ('diff_position_sex_num_child_partner_max_commute', 6132599.98046875)
# ('ratio_education_max_commute', 5662636.262634277)
# ('ratio_position_sex_num_child_partner_min_commute', 5658463.450439453)
# ('ratio_position_sex_mean_commute', 5626887.1795043945)
# ('area_max_commute', 5582339.707336426)
# ('diff_position_education_max_commute', 5492155.186706543)
# ('diff_position_sex_max_commute', 5344958.5712890625)
# ('diff_age_min_commute', 5277920.201477051)
# ('ratio_position_area_min_commute', 5245803.969512939)
# ('ratio_position_min_commute', 5077761.057739258)
# ('ratio_age_max_commute', 5060412.115356445)
# ('diff_education_min_commute', 5057114.047119141)
# ('ratio_service_length_min_commute', 4718255.7890625)
# ('diff_position_area_min_commute', 4533414.081298828)
# ('diff_position_mean_commute', 4325873.060302734)
# ('num_child_max_commute', 4304704.2734375)
# ('ratio_num_child_min_commute', 4278505.362731934)
# ('diff_position_min_commute', 3932637.5397338867)
# ('diff_position_age_num_child_partner_max_commute', 3676356.7318725586)
# ('diff_position_age_min_commute', 3178675.769592285)
# ('position_education_num_child_partner_max_commute', 3150011.503540039)
# ('commute', 3074130.2883911133)
# ('diff_area_min_commute', 2817670.8298950195)
# ('diff_service_length_min_commute', 2808357.5571899414)
# ('diff_position_education_min_commute', 2765373.014465332)
# ('diff_position_sex_min_commute', 2515669.9842834473)
# ('age_max_commute', 2348816.2271118164)
# ('partner', 731443.0148925781)
# [20.42383684524302, 21.094076624308418, 20.306955773696615]
# FOLD:3
# train_x shape: (16963, 152)
# valid_x shape: (4037, 152)
# Training until validation scores don't improve for 500 rounds.
# [500]	training's l1: 22.592	valid_0's l1: 23.0417
# [1000]	training's l1: 19.8864	valid_0's l1: 21.17
# [1500]	training's l1: 18.76	valid_0's l1: 20.6437
# [2000]	training's l1: 18.0425	valid_0's l1: 20.4455
# [2500]	training's l1: 17.4635	valid_0's l1: 20.3453
# [3000]	training's l1: 16.9655	valid_0's l1: 20.2781
# [3500]	training's l1: 16.5211	valid_0's l1: 20.2418
# [4000]	training's l1: 16.1202	valid_0's l1: 20.2264
# [4500]	training's l1: 15.7488	valid_0's l1: 20.2096
# [5000]	training's l1: 15.4016	valid_0's l1: 20.205
# Early stopping, best iteration is:
# [4962]	training's l1: 15.4276	valid_0's l1: 20.2035
# ('sum_diff_partner_num_child_mean_commute', 2507506809.1026917)
# ('ratio_partner_max_commute', 1487382733.201416)
# ('diff_partner_mean_commute', 1439217186.5576172)
# ('point1', 1358139954.2311707)
# ('point2', 950742745.2185059)
# ('diff_num_child_mean_commute', 923151899.1472168)
# ('diff_num_child_min_commute', 833573775.8995361)
# ('ratio_partner_mean_commute', 721969161.3197632)
# ('diff_num_child_max_commute', 709793255.2835083)
# ('point3', 698696909.6829224)
# ('age', 606047321.2786255)
# ('position', 555204207.9943848)
# ('position_max_age', 530208976.35491943)
# ('ratio_position_partner_max_commute', 350092250.0980835)
# ('diff_position_area_num_child_partner_mean_commute', 332728535.6314392)
# ('diff_position_num_child_partner_mean_commute', 328911111.5489197)
# ('age_min_commute', 298894486.14520264)
# ('position_mean_commute', 257001444.47564697)
# ('position_max_commute', 241690916.3215332)
# ('ratio_position_num_child_partner_max_commute', 227140730.12634277)
# ('diff_position_area_num_child_partner_min_commute', 218371644.97729492)
# ('position_mean_education', 217698620.0152588)
# ('education_mean_commute', 216961623.97705078)
# ('diff_position_partner_mean_commute', 214831237.35003662)
# ('age_mean_commute', 213554452.09106445)
# ('position_sex_min_commute', 212663031.16418457)
# ('diff_position_sex_num_child_partner_mean_commute', 193483554.24319458)
# ('position_mean_age', 184462971.78570557)
# ('ratio_partner_min_commute', 174898496.91479492)
# ('age_std_commute', 167214126.01428223)
# ('ratio_num_child_mean_commute', 147154263.42138672)
# ('education_std_commute', 143999571.92144775)
# ('diff_position_sex_num_child_partner_min_commute', 143761801.63879395)
# ('diff_position_area_num_child_partner_max_commute', 141386284.83483887)
# ('diff_position_mean_education', 133531008.6451416)
# ('ratio_position_num_child_partner_mean_commute', 123839575.56463623)
# ('age_bin', 118054573.41949463)
# ('education', 117533731.93078613)
# ('diff_position_num_child_partner_min_commute', 111847689.31066895)
# ('diff_position_age_num_child_partner_min_commute', 107415744.19329834)
# ('diff_partner_min_commute', 106384548.57775879)
# ('overtime', 87070753.7822876)
# ('ratio_position_education_min_commute', 86331082.65795898)
# ('position_min_commute', 81908175.01849365)
# ('position_sex_mean_commute', 80039203.21466064)
# ('ratio_position_mean_education', 78470610.65304565)
# ('ratio_position_sex_num_child_partner_max_commute', 76882745.67538452)
# ('diff_partner_max_commute', 75941882.67102051)
# ('position_min_age', 72651645.64874268)
# ('diff_position_age_num_child_partner_mean_commute', 71052860.62667847)
# ('position_std_commute', 69843538.92669678)
# ('diff_area_max_commute', 68425211.55023193)
# ('position_std_age', 61765889.95257568)
# ('diff_sex_mean_commute', 60572329.48815918)
# ('service_length', 59989071.43408203)
# ('position_sex_num_child_partner_mean_commute', 59532156.88256836)
# ('ratio_area_max_commute', 57593459.27572632)
# ('num_child', 50751016.49258423)
# ('ratio_position_age_min_commute', 49307711.37963867)
# ('diff_area_mean_commute', 45842415.20477295)
# ('ratio_area_mean_commute', 39558667.501586914)
# ('diff_position_num_child_min_commute', 38862481.964141846)
# ('position_nunique_age', 37691160.49475098)
# ('overtime_commute_month_ratio', 35217939.521118164)
# ('ratio_position_sex_num_child_partner_mean_commute', 35079973.69732666)
# ('diff_position_num_child_mean_commute', 33643713.81121826)
# ('education_max_commute', 32329745.390930176)
# ('diff_position_max_age', 31326381.336730957)
# ('ratio_sex_min_commute', 31252554.278320312)
# ('position_sex_num_child_partner_max_commute', 29577871.581726074)
# ('ratio_position_partner_mean_commute', 28203664.88623047)
# ('diff_position_min_age', 28180397.4821167)
# ('ratio_position_area_max_commute', 27725233.624664307)
# ('position_education_num_child_partner_min_commute', 27705778.963378906)
# ('position_sex_num_child_partner_min_commute', 27321084.819091797)
# ('ratio_area_min_commute', 24853002.78677368)
# ('ratio_num_child_max_commute', 23672242.780670166)
# ('ratio_position_age_num_child_partner_mean_commute', 23572314.804016113)
# ('ratio_position_area_mean_commute', 22020635.092071533)
# ('diff_position_area_max_commute', 21742766.39718628)
# ('num_child_mean_commute', 21532026.387512207)
# ('num_child_min_commute', 21149689.090637207)
# ('ratio_position_education_max_commute', 19778623.10913086)
# ('education_min_commute', 19436746.561340332)
# ('ratio_sex_mean_commute', 19104751.4352417)
# ('ratio_age_min_commute', 19040469.20413208)
# ('diff_position_num_child_max_commute', 18211195.773620605)
# ('ratio_position_max_commute', 18075274.00341797)
# ('ratio_position_sex_max_commute', 18012897.046813965)
# ('ratio_position_education_mean_commute', 17672385.67993164)
# ('diff_position_area_mean_commute', 17531600.409118652)
# ('diff_position_age_mean_commute', 17349286.015960693)
# ('diff_position_education_num_child_partner_mean_commute', 16743455.297729492)
# ('area_std_commute', 16581424.923980713)
# ('diff_position_partner_min_commute', 16290196.924560547)
# ('position_education_num_child_partner_mean_commute', 15998534.45437622)
# ('ratio_position_age_num_child_partner_min_commute', 15368382.168823242)
# ('ratio_position_age_mean_commute', 15347967.654296875)
# ('ratio_position_max_age', 15166215.159423828)
# ('ratio_age_mean_commute', 14720989.00326538)
# ('diff_position_education_num_child_partner_min_commute', 14715438.654724121)
# ('ratio_position_num_child_mean_commute', 14528496.64465332)
# ('ratio_position_partner_min_commute', 14234689.454742432)
# ('ratio_position_num_child_min_commute', 14058818.943725586)
# ('commute', 13429789.212463379)
# ('ratio_position_min_commute', 13281384.735443115)
# ('area_mean_commute', 13123475.572418213)
# ('commute_overtime_day_ratio', 12848243.058258057)
# ('ratio_position_sex_min_commute', 12232823.22241211)
# ('diff_position_partner_max_commute', 12197682.626098633)
# ('ratio_position_age_num_child_partner_max_commute', 11561140.098175049)
# ('ratio_position_num_child_partner_min_commute', 11379726.658538818)
# ('diff_education_mean_commute', 11360443.198272705)
# ('ratio_education_mean_commute', 10698739.600891113)
# ('diff_position_education_mean_commute', 8877895.078338623)
# ('diff_position_max_commute', 8579991.170166016)
# ('ratio_service_length_min_commute', 8283331.591705322)
# ('ratio_service_length_max_commute', 8227918.342956543)
# ('diff_position_mean_age', 8210149.514373779)
# ('ratio_position_age_max_commute', 7975275.980163574)
# ('ratio_position_mean_commute', 7576032.733764648)
# ('ratio_education_max_commute', 7512411.159484863)
# ('ratio_position_num_child_max_commute', 7369453.85534668)
# ('diff_position_sex_num_child_partner_max_commute', 7361645.850463867)
# ('ratio_position_sex_num_child_partner_min_commute', 7292210.400512695)
# ('diff_position_education_num_child_partner_max_commute', 7191723.229675293)
# ('diff_position_num_child_partner_max_commute', 7142282.717681885)
# ('ratio_position_mean_age', 7075424.091003418)
# ('sex', 6996167.974914551)
# ('area_max_commute', 6490833.436798096)
# ('ratio_education_min_commute', 6441237.60559082)
# ('ratio_position_sex_mean_commute', 6418042.0935668945)
# ('diff_position_age_min_commute', 5793434.767089844)
# ('diff_age_min_commute', 5597684.27923584)
# ('ratio_position_area_min_commute', 5332571.628387451)
# ('diff_position_education_max_commute', 5176823.658752441)
# ('diff_position_age_num_child_partner_max_commute', 4829112.043792725)
# ('ratio_age_max_commute', 4542829.198364258)
# ('diff_position_sex_max_commute', 4494363.048095703)
# ('diff_position_education_min_commute', 4297340.6513671875)
# ('diff_position_area_min_commute', 4045482.383666992)
# ('diff_education_min_commute', 3863320.7814331055)
# ('position_education_num_child_partner_max_commute', 3686274.6802368164)
# ('ratio_num_child_min_commute', 3502540.6240844727)
# ('diff_position_mean_commute', 3467656.2623901367)
# ('num_child_max_commute', 3249622.498840332)
# ('diff_service_length_min_commute', 3197190.362548828)
# ('age_max_commute', 2810262.4123535156)
# ('diff_area_min_commute', 2046310.9389038086)
# ('diff_position_min_commute', 1500273.5744018555)
# ('diff_position_sex_min_commute', 1338797.9660644531)
# ('partner', 101783.82080078125)
# [20.42383684524302, 21.094076624308418, 20.306955773696615, 20.20352157142471]
# FOLD:4
# train_x shape: (17020, 152)
# valid_x shape: (3980, 152)
# Training until validation scores don't improve for 500 rounds.
# [500]	training's l1: 22.5014	valid_0's l1: 23.6623
# [1000]	training's l1: 19.8383	valid_0's l1: 21.6056
# [1500]	training's l1: 18.7247	valid_0's l1: 21.0379
# [2000]	training's l1: 18.0099	valid_0's l1: 20.8248
# [2500]	training's l1: 17.4385	valid_0's l1: 20.6911
# [3000]	training's l1: 16.9503	valid_0's l1: 20.6156
# [3500]	training's l1: 16.5155	valid_0's l1: 20.5793
# [4000]	training's l1: 16.1135	valid_0's l1: 20.5533
# [4500]	training's l1: 15.7412	valid_0's l1: 20.5347
# [5000]	training's l1: 15.3886	valid_0's l1: 20.5259
# [5500]	training's l1: 15.0616	valid_0's l1: 20.5266
# Early stopping, best iteration is:
# [5018]	training's l1: 15.375	valid_0's l1: 20.5244
# ('sum_diff_partner_num_child_mean_commute', 2532216743.2454224)
# ('diff_partner_mean_commute', 1402552598.3638306)
# ('point1', 1326732882.0269775)
# ('ratio_partner_max_commute', 1227039802.4482422)
# ('diff_num_child_mean_commute', 930552809.5450134)
# ('diff_num_child_min_commute', 929482685.5739136)
# ('point2', 917530548.7918091)
# ('age', 830138736.4073792)
# ('ratio_partner_mean_commute', 782925208.5245361)
# ('point3', 693363382.9048462)
# ('diff_num_child_max_commute', 689757799.8187866)
# ('position', 552913259.8707886)
# ('position_max_age', 406678617.7081909)
# ('diff_position_num_child_partner_mean_commute', 372775903.53619385)
# ('ratio_position_partner_max_commute', 328362855.9191284)
# ('age_mean_commute', 307512253.0258789)
# ('diff_position_area_num_child_partner_mean_commute', 274884997.4651184)
# ('position_mean_commute', 260945146.15625)
# ('ratio_position_num_child_partner_max_commute', 255162207.08422852)
# ('age_min_commute', 233491017.9831543)
# ('position_mean_education', 232777221.71203613)
# ('diff_position_partner_mean_commute', 229494694.8781128)
# ('diff_position_area_num_child_partner_min_commute', 217840788.1262207)
# ('diff_position_sex_num_child_partner_mean_commute', 186005961.47827148)
# ('ratio_partner_min_commute', 180378134.39190674)
# ('education_mean_commute', 179643874.9790039)
# ('position_max_commute', 177479260.9154663)
# ('age_bin', 172169492.7269287)
# ('age_std_commute', 168347956.16741943)
# ('position_mean_age', 166290965.303833)
# ('diff_position_sex_num_child_partner_min_commute', 141653818.6913452)
# ('diff_position_age_num_child_partner_min_commute', 136536778.44140625)
# ('ratio_num_child_mean_commute', 136386763.57818604)
# ('diff_position_num_child_partner_min_commute', 134322999.90100098)
# ('diff_position_area_num_child_partner_max_commute', 126709590.81811523)
# ('diff_position_mean_education', 119803306.46911621)
# ('education_std_commute', 113532765.24377441)
# ('education', 105499005.68444824)
# ('diff_partner_min_commute', 98087640.75048828)
# ('position_sex_mean_commute', 97727725.09710693)
# ('diff_position_age_num_child_partner_mean_commute', 93108963.66641235)
# ('diff_partner_max_commute', 87605741.66290283)
# ('position_min_commute', 87218487.16491699)
# ('overtime', 86433970.26385498)
# ('ratio_position_education_min_commute', 82806128.0357666)
# ('ratio_position_mean_education', 75672322.82299805)
# ('ratio_position_sex_num_child_partner_max_commute', 74312807.77328491)
# ('diff_area_max_commute', 67300983.17126465)
# ('position_sex_min_commute', 65254687.839416504)
# ('diff_sex_mean_commute', 64794908.25299072)
# ('position_min_age', 62347943.91040039)
# ('position_std_commute', 55951415.81549072)
# ('position_std_age', 54807841.277526855)
# ('position_sex_num_child_partner_mean_commute', 53950674.11694336)
# ('service_length', 51790228.80056763)
# ('ratio_position_num_child_partner_mean_commute', 51737334.38095093)
# ('num_child', 49731157.65512085)
# ('diff_area_mean_commute', 49117468.00390625)
# ('ratio_area_max_commute', 45069568.85324097)
# ('position_education_num_child_partner_mean_commute', 42662193.14758301)
# ('position_sex_num_child_partner_min_commute', 37059328.09777832)
# ('ratio_position_age_min_commute', 35228837.54638672)
# ('ratio_area_mean_commute', 33787057.64138794)
# ('position_education_num_child_partner_min_commute', 33758068.03515625)
# ('overtime_commute_month_ratio', 33496117.238128662)
# ('position_nunique_age', 32602743.622680664)
# ('ratio_sex_min_commute', 31407900.480407715)
# ('education_max_commute', 31404804.067260742)
# ('ratio_position_num_child_mean_commute', 30910352.315612793)
# ('diff_position_num_child_mean_commute', 30889579.92590332)
# ('position_sex_num_child_partner_max_commute', 30572667.406951904)
# ('ratio_position_partner_mean_commute', 30284403.426818848)
# ('ratio_position_sex_num_child_partner_mean_commute', 29671248.222839355)
# ('ratio_position_area_max_commute', 29661486.365478516)
# ('ratio_position_age_num_child_partner_max_commute', 26515222.689697266)
# ('ratio_position_age_num_child_partner_mean_commute', 25703863.09414673)
# ('ratio_num_child_max_commute', 25043962.3772583)
# ('num_child_min_commute', 24138712.200805664)
# ('area_max_commute', 22887908.669433594)
# ('education_min_commute', 22808161.337036133)
# ('ratio_position_education_max_commute', 22318457.1791687)
# ('ratio_age_min_commute', 22189119.374145508)
# ('diff_position_area_max_commute', 22150913.964782715)
# ('ratio_position_max_commute', 21362551.807617188)
# ('diff_position_max_age', 21138922.09527588)
# ('diff_position_min_age', 20957765.23602295)
# ('ratio_position_partner_min_commute', 20322636.441192627)
# ('num_child_mean_commute', 20109312.009399414)
# ('diff_position_num_child_max_commute', 18980660.792297363)
# ('ratio_position_sex_max_commute', 18955822.819335938)
# ('ratio_position_area_mean_commute', 18910806.805908203)
# ('ratio_sex_mean_commute', 18773780.798217773)
# ('ratio_area_min_commute', 18685287.81768799)
# ('area_mean_commute', 17918065.91656494)
# ('diff_education_mean_commute', 17526502.95678711)
# ('ratio_age_mean_commute', 17250290.018066406)
# ('ratio_position_education_mean_commute', 16843736.204284668)
# ('area_std_commute', 15453799.031860352)
# ('ratio_position_max_age', 15216726.117126465)
# ('ratio_position_num_child_partner_min_commute', 14888234.319030762)
# ('ratio_position_age_num_child_partner_min_commute', 14728324.693328857)
# ('diff_position_education_num_child_partner_mean_commute', 14694068.162139893)
# ('diff_position_area_mean_commute', 14538236.0105896)
# ('diff_position_education_num_child_partner_min_commute', 14328873.755889893)
# ('diff_position_partner_min_commute', 14267938.16772461)
# ('commute_overtime_day_ratio', 13494653.10345459)
# ('diff_position_age_mean_commute', 13194794.396057129)
# ('ratio_education_max_commute', 12813027.626525879)
# ('ratio_position_sex_min_commute', 12768259.770019531)
# ('diff_position_partner_max_commute', 12440939.92199707)
# ('ratio_position_mean_commute', 12070954.931518555)
# ('ratio_position_age_mean_commute', 11692193.087982178)
# ('ratio_position_num_child_min_commute', 11536621.008666992)
# ('ratio_service_length_max_commute', 10599528.363891602)
# ('ratio_education_mean_commute', 10508818.93649292)
# ('diff_position_max_commute', 10078001.28491211)
# ('ratio_age_max_commute', 9385952.740600586)
# ('ratio_position_num_child_max_commute', 8871108.636383057)
# ('diff_position_education_mean_commute', 8726105.078521729)
# ('commute', 8646369.936645508)
# ('diff_position_mean_age', 8573411.214172363)
# ('ratio_position_sex_num_child_partner_min_commute', 7443999.364318848)
# ('diff_position_education_num_child_partner_max_commute', 7442702.649139404)
# ('ratio_position_area_min_commute', 7401209.739227295)
# ('diff_position_num_child_min_commute', 7216458.242706299)
# ('ratio_position_mean_age', 6981475.700378418)
# ('ratio_position_age_max_commute', 6803153.11907959)
# ('diff_position_num_child_partner_max_commute', 6495912.402587891)
# ('diff_age_min_commute', 6356307.072784424)
# ('ratio_service_length_min_commute', 6214592.935333252)
# ('diff_position_sex_num_child_partner_max_commute', 6012025.058929443)
# ('diff_position_age_min_commute', 5859597.47543335)
# ('sex', 5759350.625)
# ('num_child_max_commute', 5119469.429748535)
# ('ratio_position_sex_mean_commute', 4937352.62890625)
# ('ratio_education_min_commute', 4863347.892150879)
# ('ratio_position_min_commute', 4662502.171295166)
# ('diff_position_mean_commute', 4661275.847015381)
# ('diff_position_age_num_child_partner_max_commute', 4575898.452423096)
# ('diff_education_min_commute', 4392067.4279174805)
# ('diff_position_education_max_commute', 4270361.524658203)
# ('diff_position_sex_max_commute', 4177084.4298706055)
# ('ratio_num_child_min_commute', 3871584.7412719727)
# ('diff_area_min_commute', 3490767.1685180664)
# ('position_education_num_child_partner_max_commute', 3364890.6329345703)
# ('age_max_commute', 2822704.4580688477)
# ('diff_service_length_min_commute', 2732148.803527832)
# ('diff_position_education_min_commute', 2670313.2955932617)
# ('diff_position_min_commute', 2248637.9044799805)
# ('diff_position_area_min_commute', 2109479.2428588867)
# ('diff_position_sex_min_commute', 2071574.3817138672)
# ('partner', 492066.7684326172)
# [20.42383684524302, 21.094076624308418, 20.306955773696615, 20.20352157142471, 20.5243595882893]
# Full OOF MAE 20.519406
# CPU times: user 11min 18s, sys: 0 ns, total: 11min 18s
# Wall time: 57.9 s
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_lgb['salary_residual'] = train_lgb['salary'] - train_lgb['lgb_y']
train_lgb['salary_residual_abs'] = np.abs(train_lgb['salary'] - train_lgb['lgb_y'])
print (train_lgb.shape)
print (train_lgb.shape)
# Out:
# (21000, 211)
# (21000, 211)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
import random
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Embedding, Concatenate, Flatten, BatchNormalization, Dropout, concatenate, Activation
from keras.utils.vis_utils import plot_model
from keras.optimizers import Adam,SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dropout, Embedding, Permute, Concatenate, Flatten, Reshape
from keras.layers import GlobalMaxPooling1D, GlobalAveragePooling1D, concatenate, SpatialDropout1D
from keras.layers.advanced_activations import LeakyReLU, PReLU,ELU
from keras.models import Model
from keras.layers import CuDNNGRU, CuDNNLSTM, Bidirectional, Lambda
from keras.callbacks import Callback,EarlyStopping,ModelCheckpoint,LearningRateScheduler
from keras.regularizers import l1, l2, l1_l2

def preprocess(train_df,test_df,feats):
    train_df = train_df.replace([np.inf, -np.inf], np.nan)
    train_df = train_df.fillna(0) 

    test_df = test_df.replace([np.inf, -np.inf], np.nan)
    test_df = test_df.fillna(0)
    
    scaler = StandardScaler()
    train_df[feats] = scaler.fit_transform(train_df[feats])
    test_df[feats] = scaler.transform(test_df[feats])
    
    return train_df[feats], test_df[feats]


def ffnn(input_shape):
    model = Sequential()
    model.add(Dense(2 ** 11, input_dim = input_shape, init='he_normal', activation='relu'))
    model.add(Dense(2 ** 10, init='he_normal', activation='relu'))
    model.add(Dense(2 ** 4, init='he_normal', activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam') 
    return model

def nn_kfold(train_df,test_df,features,target,cat_features,folds,params,sampling=False):
    oof_preds = np.zeros((train_df.shape[0],1))
    sub_preds = np.zeros((test_df.shape[0],1))

    cv_list = []
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[features], train_df['salary_round'])):
        print ('FOLD:' + str(n_fold))
        train_x, train_y = train_df[features].iloc[train_idx], train_df[target].iloc[train_idx]
        valid_x, valid_y = train_df[features].iloc[valid_idx], train_df[target].iloc[valid_idx] 
        
        # Downsampling
        if sampling is True:
            valid_x, valid_y = train_df[features].iloc[valid_idx], train_df[target].iloc[valid_idx] 
            train_df_new = train_df.iloc[train_idx]
            train_df_new = train_df_new[train_df_new['salary_residual_abs']<120]
            train_x, train_y = train_df_new[features], train_df_new[target]
        
        print ('train_x shape:',train_x.shape)
        print ('valid_x shape:',valid_x.shape)

        
        model = params(train_x.shape[1])
        filepath = str(n_fold) + "_nn_best_model.hdf5" 
        es = EarlyStopping(patience=10, mode='min', verbose=1) 
        checkpoint = ModelCheckpoint(filepath=filepath, save_best_only=True,mode='auto') 
        reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, epsilon=1e-4, mode='min')

        hist = model.fit([train_x], train_y, batch_size=24, epochs=100, validation_data=(valid_x, valid_y), callbacks=[es, checkpoint, reduce_lr_loss], verbose=2)

        model.load_weights(filepath)
        _oof_preds = model.predict(valid_x, batch_size=64,verbose=1)

        oof_preds[valid_idx] = _oof_preds.reshape((-1,1))

        oof_cv = mean_absolute_error(valid_y,  oof_preds[valid_idx])
        cv_list.append(oof_cv)
        print (cv_list)
        sub_preds += model.predict(test_df[features] , batch_size=64).reshape((-1,1)) / folds.n_splits 
        
 
    cv = mean_absolute_error(train_df[target],  oof_preds)
    print('Full OOF MAE %.6f' % cv)  

    train_df['nn_y'] = oof_preds
    test_df['nn_y'] = sub_preds
    
    return train_df,test_df

train_df = df[df['salary'].notnull()] 
test_df = df[df['salary'].isnull()] 

params = ffnn
target = 'salary'
train_lgb[features], test_lgb[features] = preprocess(train_lgb,test_lgb,features)
train_nn,test_nn = nn_kfold(train_lgb,test_lgb,features,target,cat_features,folds,params,sampling=True)
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# FOLD:0
# train_x shape: (16457, 152)
# valid_x shape: (4386, 152)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:46: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2048, input_dim=152, activation="relu", kernel_initializer="he_normal")`
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:47: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1024, activation="relu", kernel_initializer="he_normal")`
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:48: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(16, activation="relu", kernel_initializer="he_normal")`
# Train on 16457 samples, validate on 4386 samples
# Epoch 1/100
#  - 3s - loss: 36.2680 - val_loss: 24.1432
# Epoch 2/100
#  - 3s - loss: 25.4572 - val_loss: 29.3011
# Epoch 3/100
#  - 3s - loss: 23.5120 - val_loss: 25.2607
# Epoch 4/100
#  - 3s - loss: 22.0294 - val_loss: 23.2312
# Epoch 5/100
#  - 3s - loss: 22.2963 - val_loss: 22.2619
# Epoch 6/100
#  - 3s - loss: 21.8045 - val_loss: 22.9224
# Epoch 7/100
#  - 3s - loss: 21.7496 - val_loss: 21.6138
# Epoch 8/100
#  - 3s - loss: 21.2045 - val_loss: 21.6970
# Epoch 9/100
#  - 3s - loss: 20.6249 - val_loss: 21.7387
# Epoch 10/100
#  - 3s - loss: 20.9622 - val_loss: 22.6161
# Epoch 11/100
#  - 3s - loss: 20.3458 - val_loss: 22.0437
# Epoch 12/100
#  - 3s - loss: 20.3987 - val_loss: 21.9739
# Epoch 13/100
#  - 3s - loss: 20.2042 - val_loss: 20.8153
# Epoch 14/100
#  - 3s - loss: 20.0276 - val_loss: 23.9175
# Epoch 15/100
#  - 3s - loss: 20.1640 - val_loss: 21.7185
# Epoch 16/100
#  - 3s - loss: 20.3061 - val_loss: 20.4011
# Epoch 17/100
#  - 3s - loss: 20.0445 - val_loss: 20.8674
# Epoch 18/100
#  - 3s - loss: 19.6306 - val_loss: 20.3594
# Epoch 19/100
#  - 3s - loss: 19.8683 - val_loss: 22.2602
# Epoch 20/100
#  - 3s - loss: 19.5351 - val_loss: 22.3186
# Epoch 21/100
#  - 3s - loss: 19.5946 - val_loss: 21.9682
# Epoch 22/100
#  - 3s - loss: 19.4808 - val_loss: 20.9819
# Epoch 23/100
#  - 3s - loss: 19.5438 - val_loss: 21.1984
# Epoch 24/100
#  - 3s - loss: 19.3303 - val_loss: 21.8866
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 25/100
#  - 3s - loss: 17.7133 - val_loss: 19.9763
# Epoch 26/100
#  - 3s - loss: 17.5191 - val_loss: 20.0080
# Epoch 27/100
#  - 3s - loss: 17.5259 - val_loss: 19.8185
# Epoch 28/100
#  - 3s - loss: 17.4859 - val_loss: 19.9726
# Epoch 29/100
#  - 3s - loss: 17.4235 - val_loss: 20.3153
# Epoch 30/100
#  - 3s - loss: 17.4302 - val_loss: 20.2565
# Epoch 31/100
#  - 3s - loss: 17.3620 - val_loss: 20.0416
# Epoch 32/100
#  - 3s - loss: 17.3433 - val_loss: 19.8619
# Epoch 33/100
#  - 3s - loss: 17.3427 - val_loss: 20.0518
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 34/100
#  - 3s - loss: 17.1201 - val_loss: 19.8364
# Epoch 35/100
#  - 3s - loss: 17.0695 - val_loss: 19.9208
# Epoch 36/100
#  - 3s - loss: 17.0756 - val_loss: 19.8247
# Epoch 37/100
#  - 3s - loss: 17.0603 - val_loss: 19.8342
# Epoch 00037: early stopping
# 4386/4386 [==============================] - 0s 67us/step
# [19.81851886455413]
# FOLD:1
# train_x shape: (16403, 152)
# valid_x shape: (4448, 152)
# Train on 16403 samples, validate on 4448 samples
# Epoch 1/100
#  - 3s - loss: 38.2789 - val_loss: 34.1432
# Epoch 2/100
#  - 3s - loss: 25.4694 - val_loss: 24.8474
# Epoch 3/100
#  - 3s - loss: 23.6635 - val_loss: 34.0790
# Epoch 4/100
#  - 3s - loss: 22.3677 - val_loss: 29.4763
# Epoch 5/100
#  - 3s - loss: 21.5848 - val_loss: 23.3203
# Epoch 6/100
#  - 3s - loss: 21.0354 - val_loss: 21.9636
# Epoch 7/100
#  - 3s - loss: 21.2016 - val_loss: 22.8306
# Epoch 8/100
#  - 3s - loss: 20.9492 - val_loss: 22.2670
# Epoch 9/100
#  - 3s - loss: 20.4898 - val_loss: 22.9637
# Epoch 10/100
#  - 3s - loss: 20.3610 - val_loss: 22.4794
# Epoch 11/100
#  - 3s - loss: 20.1399 - val_loss: 24.4068
# Epoch 12/100
#  - 3s - loss: 20.1546 - val_loss: 21.2817
# Epoch 13/100
#  - 3s - loss: 19.8856 - val_loss: 21.4995
# Epoch 14/100
#  - 3s - loss: 19.9540 - val_loss: 21.2551
# Epoch 15/100
#  - 3s - loss: 19.7753 - val_loss: 24.1869
# Epoch 16/100
#  - 3s - loss: 19.5352 - val_loss: 21.0848
# Epoch 17/100
#  - 3s - loss: 19.5813 - val_loss: 24.6685
# Epoch 18/100
#  - 3s - loss: 19.6547 - val_loss: 22.3308
# Epoch 19/100
#  - 3s - loss: 19.5301 - val_loss: 24.8744
# Epoch 20/100
#  - 3s - loss: 19.4106 - val_loss: 21.4919
# Epoch 21/100
#  - 3s - loss: 19.3622 - val_loss: 22.0595
# Epoch 22/100
#  - 3s - loss: 19.4256 - val_loss: 22.3743
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/100
#  - 3s - loss: 17.6647 - val_loss: 20.1079
# Epoch 24/100
#  - 3s - loss: 17.4752 - val_loss: 20.2154
# Epoch 25/100
#  - 3s - loss: 17.4553 - val_loss: 20.1012
# Epoch 26/100
#  - 3s - loss: 17.4271 - val_loss: 20.4941
# Epoch 27/100
#  - 3s - loss: 17.3888 - val_loss: 20.0808
# Epoch 28/100
#  - 3s - loss: 17.3837 - val_loss: 20.0848
# Epoch 29/100
#  - 3s - loss: 17.3507 - val_loss: 20.0484
# Epoch 30/100
#  - 3s - loss: 17.3420 - val_loss: 20.0552
# Epoch 31/100
#  - 3s - loss: 17.3011 - val_loss: 20.6211
# Epoch 32/100
#  - 3s - loss: 17.2875 - val_loss: 20.0167
# Epoch 33/100
#  - 3s - loss: 17.3136 - val_loss: 20.1714
# Epoch 34/100
#  - 3s - loss: 17.2940 - val_loss: 19.9687
# Epoch 35/100
#  - 3s - loss: 17.2552 - val_loss: 20.2559
# Epoch 36/100
#  - 3s - loss: 17.2449 - val_loss: 20.1434
# Epoch 37/100
#  - 3s - loss: 17.2430 - val_loss: 20.3140
# Epoch 38/100
#  - 3s - loss: 17.2417 - val_loss: 20.0911
# Epoch 39/100
#  - 3s - loss: 17.2057 - val_loss: 20.2566
# Epoch 40/100
#  - 3s - loss: 17.1708 - val_loss: 20.4096
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 41/100
#  - 3s - loss: 16.9562 - val_loss: 20.0165
# Epoch 42/100
#  - 3s - loss: 16.9332 - val_loss: 20.1136
# Epoch 43/100
#  - 3s - loss: 16.9215 - val_loss: 20.0793
# Epoch 44/100
#  - 3s - loss: 16.9199 - val_loss: 20.0700
# Epoch 00044: early stopping
# 4448/4448 [==============================] - 0s 69us/step
# [19.81851886455413, 19.968712685454133]
# FOLD:2
# train_x shape: (16692, 152)
# valid_x shape: (4149, 152)
# Train on 16692 samples, validate on 4149 samples
# Epoch 1/100
#  - 3s - loss: 35.9866 - val_loss: 27.7089
# Epoch 2/100
#  - 3s - loss: 25.8373 - val_loss: 24.4301
# Epoch 3/100
#  - 3s - loss: 23.5602 - val_loss: 26.2978
# Epoch 4/100
#  - 3s - loss: 22.5373 - val_loss: 21.2650
# Epoch 5/100
#  - 3s - loss: 21.8934 - val_loss: 22.5880
# Epoch 6/100
#  - 3s - loss: 21.6020 - val_loss: 24.8859
# Epoch 7/100
#  - 3s - loss: 21.3436 - val_loss: 20.6685
# Epoch 8/100
#  - 3s - loss: 20.9097 - val_loss: 21.8134
# Epoch 9/100
#  - 3s - loss: 20.8078 - val_loss: 21.4733
# Epoch 10/100
#  - 3s - loss: 20.6801 - val_loss: 21.4543
# Epoch 11/100
#  - 3s - loss: 20.8457 - val_loss: 20.9061
# Epoch 12/100
#  - 3s - loss: 20.2885 - val_loss: 23.5168
# Epoch 13/100
#  - 3s - loss: 20.2810 - val_loss: 20.7776
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/100
#  - 3s - loss: 18.1431 - val_loss: 19.9682
# Epoch 15/100
#  - 3s - loss: 17.9514 - val_loss: 19.8291
# Epoch 16/100
#  - 3s - loss: 17.8613 - val_loss: 19.9748
# Epoch 17/100
#  - 3s - loss: 17.8123 - val_loss: 19.9226
# Epoch 18/100
#  - 3s - loss: 17.7808 - val_loss: 19.7358
# Epoch 19/100
#  - 3s - loss: 17.7924 - val_loss: 19.6986
# Epoch 20/100
#  - 3s - loss: 17.7527 - val_loss: 19.9044
# Epoch 21/100
#  - 3s - loss: 17.7321 - val_loss: 19.8275
# Epoch 22/100
#  - 3s - loss: 17.7001 - val_loss: 20.0435
# Epoch 23/100
#  - 3s - loss: 17.6231 - val_loss: 20.0223
# Epoch 24/100
#  - 3s - loss: 17.6324 - val_loss: 19.9089
# Epoch 25/100
#  - 3s - loss: 17.6544 - val_loss: 19.6740
# Epoch 26/100
#  - 3s - loss: 17.5877 - val_loss: 19.9022
# Epoch 27/100
#  - 3s - loss: 17.5513 - val_loss: 19.7757
# Epoch 28/100
#  - 3s - loss: 17.5290 - val_loss: 19.8806
# Epoch 29/100
#  - 3s - loss: 17.5243 - val_loss: 19.7822
# Epoch 30/100
#  - 3s - loss: 17.4946 - val_loss: 19.9101
# Epoch 31/100
#  - 3s - loss: 17.4692 - val_loss: 19.9299
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 32/100
#  - 3s - loss: 17.1797 - val_loss: 19.6890
# Epoch 33/100
#  - 3s - loss: 17.1292 - val_loss: 19.6908
# Epoch 34/100
#  - 3s - loss: 17.1236 - val_loss: 19.6938
# Epoch 35/100
#  - 3s - loss: 17.1122 - val_loss: 19.7077
# Epoch 00035: early stopping
# 4149/4149 [==============================] - 0s 79us/step
# [19.81851886455413, 19.968712685454133, 19.67399391995535]
# FOLD:3
# train_x shape: (16799, 152)
# valid_x shape: (4037, 152)
# Train on 16799 samples, validate on 4037 samples
# Epoch 1/100
#  - 3s - loss: 37.2062 - val_loss: 24.3750
# Epoch 2/100
#  - 3s - loss: 25.2685 - val_loss: 27.5833
# Epoch 3/100
#  - 3s - loss: 22.9254 - val_loss: 24.1702
# Epoch 4/100
#  - 3s - loss: 21.8560 - val_loss: 21.4322
# Epoch 5/100
#  - 3s - loss: 21.9617 - val_loss: 22.8453
# Epoch 6/100
#  - 3s - loss: 21.0072 - val_loss: 24.2407
# Epoch 7/100
#  - 3s - loss: 21.0851 - val_loss: 21.2999
# Epoch 8/100
#  - 3s - loss: 21.0896 - val_loss: 21.8059
# Epoch 9/100
#  - 3s - loss: 20.6455 - val_loss: 22.0294
# Epoch 10/100
#  - 3s - loss: 20.3594 - val_loss: 24.2942
# Epoch 11/100
#  - 3s - loss: 20.4545 - val_loss: 22.1996
# Epoch 12/100
#  - 3s - loss: 20.3802 - val_loss: 20.4324
# Epoch 13/100
#  - 3s - loss: 19.9657 - val_loss: 20.8865
# Epoch 14/100
#  - 3s - loss: 19.9546 - val_loss: 23.4094
# Epoch 15/100
#  - 3s - loss: 20.0013 - val_loss: 20.7915
# Epoch 16/100
#  - 3s - loss: 19.7939 - val_loss: 22.8517
# Epoch 17/100
#  - 3s - loss: 19.7842 - val_loss: 20.5662
# Epoch 18/100
#  - 3s - loss: 19.8301 - val_loss: 23.2306
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 19/100
#  - 3s - loss: 17.9042 - val_loss: 19.7623
# Epoch 20/100
#  - 3s - loss: 17.6509 - val_loss: 19.7509
# Epoch 21/100
#  - 3s - loss: 17.5945 - val_loss: 19.7183
# Epoch 22/100
#  - 3s - loss: 17.5964 - val_loss: 19.7336
# Epoch 23/100
#  - 3s - loss: 17.5638 - val_loss: 19.6984
# Epoch 24/100
#  - 3s - loss: 17.5392 - val_loss: 19.6718
# Epoch 25/100
#  - 3s - loss: 17.4986 - val_loss: 19.9900
# Epoch 26/100
#  - 3s - loss: 17.4661 - val_loss: 19.6900
# Epoch 27/100
#  - 3s - loss: 17.4781 - val_loss: 19.6986
# Epoch 28/100
#  - 3s - loss: 17.4308 - val_loss: 19.7167
# Epoch 29/100
#  - 3s - loss: 17.4103 - val_loss: 19.6438
# Epoch 30/100
#  - 3s - loss: 17.3784 - val_loss: 19.6430
# Epoch 31/100
#  - 3s - loss: 17.3844 - val_loss: 19.7548
# Epoch 32/100
#  - 3s - loss: 17.3754 - val_loss: 19.8169
# Epoch 33/100
#  - 3s - loss: 17.3419 - val_loss: 19.6373
# Epoch 34/100
#  - 3s - loss: 17.2788 - val_loss: 19.7452
# Epoch 35/100
#  - 3s - loss: 17.2750 - val_loss: 19.6823
# Epoch 36/100
#  - 3s - loss: 17.2953 - val_loss: 19.7755
# Epoch 37/100
#  - 3s - loss: 17.2270 - val_loss: 19.6745
# Epoch 38/100
#  - 3s - loss: 17.2454 - val_loss: 19.8037
# Epoch 39/100
#  - 3s - loss: 17.2131 - val_loss: 19.8166
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 40/100
#  - 3s - loss: 16.9719 - val_loss: 19.5876
# Epoch 41/100
#  - 3s - loss: 16.9254 - val_loss: 19.6038
# Epoch 42/100
#  - 3s - loss: 16.9185 - val_loss: 19.6035
# Epoch 43/100
#  - 3s - loss: 16.9115 - val_loss: 19.5892
# Epoch 44/100
#  - 3s - loss: 16.9065 - val_loss: 19.6023
# Epoch 45/100
#  - 3s - loss: 16.8979 - val_loss: 19.6098
# Epoch 46/100
#  - 3s - loss: 16.8866 - val_loss: 19.6186
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 47/100
#  - 3s - loss: 16.8650 - val_loss: 19.6038
# Epoch 48/100
#  - 3s - loss: 16.8591 - val_loss: 19.6015
# Epoch 49/100
#  - 3s - loss: 16.8569 - val_loss: 19.6051
# Epoch 50/100
#  - 3s - loss: 16.8564 - val_loss: 19.6052
# Epoch 00050: early stopping
# 4037/4037 [==============================] - 0s 84us/step
# [19.81851886455413, 19.968712685454133, 19.67399391995535, 19.587568424251923]
# FOLD:4
# train_x shape: (16865, 152)
# valid_x shape: (3980, 152)
# Train on 16865 samples, validate on 3980 samples
# Epoch 1/100
#  - 4s - loss: 37.2236 - val_loss: 26.4102
# Epoch 2/100
#  - 3s - loss: 26.3783 - val_loss: 25.2827
# Epoch 3/100
#  - 3s - loss: 23.9224 - val_loss: 22.4564
# Epoch 4/100
#  - 3s - loss: 22.7327 - val_loss: 24.3339
# Epoch 5/100
#  - 3s - loss: 21.7695 - val_loss: 23.2043
# Epoch 6/100
#  - 3s - loss: 21.6280 - val_loss: 22.0381
# Epoch 7/100
#  - 3s - loss: 20.7725 - val_loss: 22.0149
# Epoch 8/100
#  - 3s - loss: 21.3729 - val_loss: 21.7155
# Epoch 9/100
#  - 3s - loss: 20.9465 - val_loss: 20.9466
# Epoch 10/100
#  - 3s - loss: 20.4337 - val_loss: 22.0602
# Epoch 11/100
#  - 3s - loss: 20.7424 - val_loss: 20.9227
# Epoch 12/100
#  - 3s - loss: 20.1422 - val_loss: 21.0329
# Epoch 13/100
#  - 3s - loss: 20.1864 - val_loss: 22.6311
# Epoch 14/100
#  - 3s - loss: 19.9587 - val_loss: 21.1539
# Epoch 15/100
#  - 3s - loss: 19.9686 - val_loss: 21.0720
# Epoch 16/100
#  - 3s - loss: 19.8238 - val_loss: 24.9149
# Epoch 17/100
#  - 3s - loss: 19.8791 - val_loss: 22.6492
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/100
#  - 3s - loss: 17.8981 - val_loss: 20.2155
# Epoch 19/100
#  - 3s - loss: 17.7252 - val_loss: 20.0932
# Epoch 20/100
#  - 3s - loss: 17.6922 - val_loss: 20.1299
# Epoch 21/100
#  - 3s - loss: 17.6126 - val_loss: 20.2913
# Epoch 22/100
#  - 3s - loss: 17.6130 - val_loss: 20.2856
# Epoch 23/100
#  - 3s - loss: 17.6028 - val_loss: 20.1373
# Epoch 24/100
#  - 3s - loss: 17.5394 - val_loss: 20.2588
# Epoch 25/100
#  - 3s - loss: 17.5051 - val_loss: 20.2257
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 26/100
#  - 3s - loss: 17.2725 - val_loss: 20.0583
# Epoch 27/100
#  - 3s - loss: 17.2426 - val_loss: 20.0469
# Epoch 28/100
#  - 3s - loss: 17.2305 - val_loss: 20.0602
# Epoch 29/100
#  - 3s - loss: 17.2134 - val_loss: 20.0364
# Epoch 30/100
#  - 3s - loss: 17.2169 - val_loss: 20.0335
# Epoch 31/100
#  - 3s - loss: 17.2104 - val_loss: 20.0320
# Epoch 32/100
#  - 3s - loss: 17.2051 - val_loss: 20.0643
# Epoch 33/100
#  - 3s - loss: 17.2113 - val_loss: 20.0337
# Epoch 34/100
#  - 3s - loss: 17.2007 - val_loss: 20.0714
# Epoch 35/100
#  - 3s - loss: 17.1994 - val_loss: 20.0370
# Epoch 36/100
#  - 3s - loss: 17.1940 - val_loss: 20.0417
# Epoch 37/100
#  - 3s - loss: 17.1838 - val_loss: 20.0436
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 38/100
#  - 3s - loss: 17.1645 - val_loss: 20.0441
# Epoch 39/100
#  - 3s - loss: 17.1583 - val_loss: 20.0400
# Epoch 40/100
#  - 3s - loss: 17.1562 - val_loss: 20.0395
# Epoch 41/100
#  - 3s - loss: 17.1553 - val_loss: 20.0376
# Epoch 00041: early stopping
# 3980/3980 [==============================] - 0s 85us/step
# [19.81851886455413, 19.968712685454133, 19.67399391995535, 19.587568424251923, 20.032001991342934]
# Full OOF MAE 19.817840
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_nn[['nn_y','id']].to_csv('ensemble/train_nn1_oof_down_stratified_1981.csv',index=False)
test_nn[['nn_y','id']].to_csv('ensemble/test_nn1_oof_down_stratified_1981.csv',index=False)

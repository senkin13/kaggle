# %%
# %%time
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_datetime64_any_dtype
from pandas.io.json import json_normalize
import json
import random
import os
import glob
import gc
import datetime
import numpy as np
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold

import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import BatchNormalization,Activation,Dropout,Dense,Input,Embedding,concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Flatten,Multiply,Add, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,GRU,LSTM, Bidirectional
from tensorflow.keras.layers import GlobalMaxPool1D,GlobalAveragePooling1D, GlobalMaxPooling1D,SpatialDropout1D
from tensorflow.compat.v1.keras.layers import CuDNNGRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Attention,LeakyReLU,PReLU,ELU
from tensorflow.keras import backend as K
from tensorflow.keras import initializers,optimizers
from tensorflow.keras import constraints
from tensorflow.keras import regularizers
from tensorflow.keras.layers import InputSpec, Layer
from tensorflow.keras.optimizers import *
from tensorflow.keras.metrics import AUC
from sklearn.metrics import average_precision_score
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from scipy import sparse
from scipy.sparse import hstack, csr_matrix
from sklearn.decomposition import NMF,LatentDirichletAllocation,TruncatedSVD
from gensim.models import Word2Vec,FastText
from gensim import corpora
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib_venn import venn2
# %matplotlib inline

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
pd.set_option("display.precision", 8)

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

def preprocess(train_df,test_df,feats):
    train_df = train_df.replace([np.inf, -np.inf], np.nan)
    train_df = train_df.fillna(0) 

    test_df = test_df.replace([np.inf, -np.inf], np.nan)
    test_df = test_df.fillna(0)
    
    scaler = StandardScaler()
    train_df[feats] = scaler.fit_transform(train_df[feats])
    test_df[feats] = scaler.transform(test_df[feats])
    
    return train_df[feats], test_df[feats]
    
# seed
seed = 817
seed_everything(seed)

# load csv
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
fitting = pd.read_csv('fitting__fixed.csv')
spec_df = pd.read_pickle('spec_df.pkl')
# Out:
# Wall time: 720 ms

# %%
# import pathlib
# p_temp = pathlib.Path('spectrum_raw')

# spec = []
# for file in p_temp.iterdir():
#     spec_df = pd.read_csv(file, sep='\t', header=None)[:511]
#     spec_df.columns = ['wavelength', 'intensity']
#     spec_df['spectrum_filename'] = file.stem + '.dat'
#     spec.append(spec_df)

# spec_df = pd.concat(spec, axis=0)
# display(spec_df.shape)
# display(spec_df.head())
# spec_df.to_pickle('spec_df.pkl')

# %%
from tqdm import tqdm
def load_dat(spectrum_file):

    ## Datファイルの読み込み
    dat_df = pd.read_csv(spectrum_dir + spectrum_file,
                         header=None,
                         sep="\t")

    ## カラム名変更
    dat_df.columns = ["WaveLength", "SignalPower"]

    ## 波長データは使わず、光強度のみを使います
    spectrum = dat_df["SignalPower"][:511].values

    return spectrum

def min_max_scale(spectrum):

    ## 波形そのものが重要そうですので、0~1に正規化します
    spectrum = (spectrum - np.min(spectrum)) / (np.max(spectrum) - np.min(spectrum))

    return spectrum

spectrum_dir = "spectrum_raw/"
X_train = np.empty((len(train), 511), dtype="float")
X_train_filelist = train["spectrum_filename"].tolist()
y_train = train["target"].values

for i, spectrum_file in tqdm(enumerate(X_train_filelist)):

    ## datから光強度のみ読み込み
    specrum = load_dat(spectrum_file)

    ## 正規化
    specrum = min_max_scale(specrum)

    X_train[i,:] = specrum

print(X_train.shape, y_train.shape)

X_test = np.empty((len(test), 511), dtype="float")
X_test_filelist = test["spectrum_filename"].tolist()

for i, spectrum_file in tqdm(enumerate(X_test_filelist)):

    ## datから光強度のみ読み込み
    specrum = load_dat(spectrum_file)

    ## 正規化
    specrum = min_max_scale(specrum)

    X_test[i,:] = specrum

print(X_test.shape)

X_train = X_train.reshape(-1, 511, 1)
X_test = X_test.reshape(-1, 511, 1)
y_train = y_train.reshape(-1, 1)

print(X_train.shape, X_test.shape, y_train.shape)
# Out:
# 7436it [00:59, 124.20it/s]
# 12it [00:00, 117.72it/s]
# (7436, 511) (7436,)
# 6952it [00:55, 125.74it/s]
# (6952, 511)
# (7436, 511, 1) (6952, 511, 1) (7436, 1)

# %%
import tensorflow.keras.backend as K
def average_precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
    
def wave_block(x, filters, kernel_size, n):
    dilation_rates = [2**i for i in range(n)]
    x = Conv1D(filters = filters,
                kernel_size = 1,
                padding = 'same')(x)
    res_x = x
    for dilation_rate in dilation_rates:
        tanh_out = Conv1D(filters = filters,
                            kernel_size = kernel_size,
                            padding = 'same', 
                            activation = 'tanh', 
                            dilation_rate = dilation_rate)(x)
        sigm_out = Conv1D(filters = filters,
                            kernel_size = kernel_size,
                            padding = 'same',
                            activation = 'sigmoid', 
                            dilation_rate = dilation_rate)(x)
        x = Multiply()([tanh_out, sigm_out])
        x = Conv1D(filters = filters,
                    kernel_size = 1,
                    padding = 'same')(x)
        res_x = Add()([res_x, x])
        return res_x

def create_model(num_cols,input_len):
    # numerical feature
    input_num = Input(shape=(len(num_cols),),name='numerical')
    n = input_num
    
    # wavenet
    intensity_inp = Input(shape=(input_len, 1))
    x = wave_block(intensity_inp, 16, 12, 12)
    x1 = BatchNormalization()(x)
    x2 = wave_block(x1, 32, 12, 8)
    x2 = BatchNormalization()(x2)
    x3 = wave_block(x2, 64, 12, 4)
    x3 = BatchNormalization()(x3)
    x4 = wave_block(x3, 128, 12, 1)    
    x4 = BatchNormalization()(x4)
    
    avg_pool_1 = GlobalAveragePooling1D()(x1)
    max_pool_1 = GlobalMaxPooling1D()(x1)
    avg_pool_2 = GlobalAveragePooling1D()(x2)
    max_pool_2 = GlobalMaxPooling1D()(x2)
    avg_pool_3 = GlobalAveragePooling1D()(x3)
    max_pool_3 = GlobalMaxPooling1D()(x3)
    avg_pool_4 = GlobalAveragePooling1D()(x4)
    max_pool_4 = GlobalMaxPooling1D()(x4)
    
    x = concatenate([n,avg_pool_3,max_pool_3,avg_pool_4,max_pool_4])
    x = Dense(256,kernel_initializer='he_normal',)(x)
    x = ELU()(x)
    x = Dropout(0.1)(x)
    x = Dense(128,kernel_initializer='he_normal',)(x)
    x = ELU()(x)
    x = Dropout(0.1)(x)    
    x = Dense(16,kernel_initializer='he_normal',)(x)
    x = ELU()(x)
    x = Dropout(0.1)(x)    
    output = Dense(1,activation='sigmoid')(x)
    
    # model
    model = Model([input_num]+[intensity_inp], output) 
    #model.summary()
    model.compile(loss="binary_crossentropy",optimizer='adam', 
                  metrics=[AUC(curve='PR', num_thresholds=1000)])
    return model

# %%
from sklearn.metrics import roc_auc_score,log_loss
from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold,RepeatedStratifiedKFold
def nn_kfold(numerical_cols,
             train_df_num,test_df_num,
             train_df,test_df,
             train_df_y,target,folds):  
    tf.keras.backend.clear_session()
    oof_preds = np.zeros((train_df.shape[0],1))
    oof_preds1 = np.zeros((train_df.shape[0],1))
    oof_preds2 = np.zeros((train_df.shape[0],1))
    oof_preds3 = np.zeros((train_df.shape[0],1))
    oof_preds4 = np.zeros((train_df.shape[0],1))
    oof_preds5 = np.zeros((train_df.shape[0],1))      
    sub_preds = np.zeros((test_df.shape[0],1))
    
    cv_list = []
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df, train_df_y)):        
        print ('FOLD:' + str(n_fold))
        train_num_x = train_df_num.iloc[train_idx].values
        valid_num_x = train_df_num.iloc[valid_idx].values
        test_num_x = test_df_num.values
        
        train_x, train_y = train_df[train_idx], train_df_y[train_idx]
        valid_x, valid_y = train_df[valid_idx], train_df_y[valid_idx]
        test_x = test_df

        
        print ('train_y shape:',train_y.shape,train_y.mean())
        print ('valid_y shape:',valid_y.shape,valid_y.mean())
        
        input_len = 511
        model = create_model(numerical_cols,input_len)
        if n_fold < 1:
            model.summary()
        filepath = str(n_fold) + "_best_model.hdf5" 
            
        es = EarlyStopping(patience=8, mode='min', verbose=1) 
        checkpoint = ModelCheckpoint(monitor='val_loss', filepath=filepath, save_best_only=True,mode='auto') 
        reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, verbose=1)

        hist = model.fit([train_num_x]
                         +[train_x]
                         , train_y, batch_size=64, epochs=100, 
                         validation_data=([valid_num_x]
                                          +[valid_x]
                                          , valid_y), callbacks=[es, checkpoint, reduce_lr_loss,
                                                                ], verbose=1)

        model.load_weights(filepath)
        
        if n_fold < 5:
            _oof_preds = model.predict([valid_num_x]+[valid_x], batch_size=128,verbose=1)
            oof_preds1[valid_idx] = _oof_preds.reshape((-1,1))
        if n_fold >= 5 and n_fold < 10:
            _oof_preds = model.predict([valid_num_x]+[valid_x], batch_size=128,verbose=1)
            oof_preds2[valid_idx] = _oof_preds.reshape((-1,1))
        if n_fold >= 10 and n_fold < 15:
            _oof_preds = model.predict([valid_num_x]+[valid_x], batch_size=128,verbose=1)
            oof_preds3[valid_idx] = _oof_preds.reshape((-1,1))
        if n_fold >= 15 and n_fold < 20:
            _oof_preds = model.predict([valid_num_x]+[valid_x], batch_size=128,verbose=1)
            oof_preds4[valid_idx] = _oof_preds.reshape((-1,1))
        if n_fold >= 20 and n_fold < 25:
            _oof_preds = model.predict([valid_num_x]+[valid_x], batch_size=128,verbose=1)
            oof_preds5[valid_idx] = _oof_preds.reshape((-1,1))
            
        sub_preds += model.predict([test_num_x]
                                   +[test_x]
                                   , batch_size=128).reshape((-1,1)) / folds.get_n_splits()   
    oof_preds = (oof_preds1 + oof_preds2 + oof_preds3 + oof_preds4 + oof_preds5
                )/5   
    cv = log_loss(train_df_y, oof_preds)
    print('Full log_loss %.6f' % cv)      
    cv = average_precision_score(train_df_y, oof_preds)
    print('Full AP %.6f' % cv)  

    return oof_preds,sub_preds,cv 

train_df = pd.read_pickle('train_num.pkl')
test_df = pd.read_pickle('test_num.pkl')

target = 'target'

# numerical_cols
numerical_cols = [    
'exc_wl', 'layout_a', 'layout_x', 'layout_y', 'pos_x', 'params0', 'params1', 'params3', 'params4', 'params5', 'params6',
    'rms', 'beta', 'intensity_min', 'intensity_max', 'intensity_mean', 'intensity_std', 'intensity_minmax', 'intensity_q1',
    'intensity_q5', 'intensity_q95', 'intensity_q99', 'diff_params1_params4', 'diff_params2_params5', 'diff_params3_params6',
    'ratio_params1_params4', 'ratio_params1_params3', 'ratio_params3_params6', 'ratio_params4_params6', 'exc_wl_count_target', 
    'layout_a_count_target', 'layout_x_count_target', 'layout_y_count_target', 'pos_x_count_target', 'layout_a_mean_ratio_intensity_minmax'
                     ]

train_x_num, test_x_num = preprocess(train_df,test_df,numerical_cols)

for c in ['exc_wl']:
    lbl = LabelEncoder()
    train_df[c] = lbl.fit_transform(train_df[c])
    test_df[c] = lbl.transform(test_df[c])
    print (train_df[c].nunique()+1)

n_splits= 5
n_repeats = 5
# folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
folds = RepeatedStratifiedKFold(n_splits=n_splits,  n_repeats=n_repeats,  random_state=seed)
train_df,test_df,cv = nn_kfold(numerical_cols,
                               train_x_num,test_x_num,
                               X_train,X_test,
                               y_train,target,folds)
# Out:
# 3
# FOLD:0
# train_y shape: (5948, 1) 0.03160726294552791
# valid_y shape: (1488, 1) 0.03225806451612903
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 511, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 511, 16)      32          input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 511, 16)      3088        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 511, 16)      3088        conv1d[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 511, 16)      0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 511, 16)      272         multiply[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 511, 16)      0           conv1d[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 511, 16)      64          add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 511, 32)      544         batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 511, 32)      12320       conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 511, 32)      12320       conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 511, 32)      0           conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 511, 32)      1056        multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 511, 32)      0           conv1d_4[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 511, 32)      128         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 511, 64)      2112        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 511, 64)      49216       conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 511, 64)      49216       conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 511, 64)      0           conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 511, 64)      4160        multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 511, 64)      0           conv1d_8[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 511, 64)      256         add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 511, 128)     8320        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 511, 128)     196736      conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 511, 128)     196736      conv1d_12[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 511, 128)     0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 511, 128)     16512       multiply_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 511, 128)     0           conv1d_12[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 511, 128)     512         add_3[0][0]
# __________________________________________________________________________________________________
# numerical (InputLayer)          [(None, 35)]         0
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 419)          0           numerical[0][0]
#                                                                  global_average_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_2[0][0]
#                                                                  global_average_pooling1d_3[0][0]
#                                                                  global_max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          107520      concatenate[0][0]
# __________________________________________________________________________________________________
# elu (ELU)                       (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           elu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dropout[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 128)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           elu_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           2064        dropout_1[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 16)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           elu_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            17          dropout_2[0][0]
# ==================================================================================================
# Total params: 699,185
# Trainable params: 698,705
# Non-trainable params: 480
# __________________________________________________________________________________________________
# Train on 5948 samples, validate on 1488 samples
# Epoch 1/100
# 5948/5948 [==============================] - 7s 1ms/sample - loss: 0.1536 - auc: 0.2514 - val_loss: 0.1367 - val_auc: 0.1967
# Epoch 2/100
# 5948/5948 [==============================] - 5s 797us/sample - loss: 0.0572 - auc: 0.7479 - val_loss: 0.1004 - val_auc: 0.2807
# Epoch 3/100
# 5948/5948 [==============================] - 5s 803us/sample - loss: 0.0482 - auc: 0.7614 - val_loss: 0.0898 - val_auc: 0.4859
# Epoch 4/100
# 5948/5948 [==============================] - 5s 799us/sample - loss: 0.0484 - auc: 0.7653 - val_loss: 0.0548 - val_auc: 0.7652
# Epoch 5/100
# 5948/5948 [==============================] - 5s 807us/sample - loss: 0.0469 - auc: 0.7596 - val_loss: 0.0388 - val_auc: 0.8806
# Epoch 6/100
# 5948/5948 [==============================] - 5s 803us/sample - loss: 0.0405 - auc: 0.8309 - val_loss: 0.0359 - val_auc: 0.9158
# Epoch 7/100
# 5948/5948 [==============================] - 5s 804us/sample - loss: 0.0387 - auc: 0.8374 - val_loss: 0.0275 - val_auc: 0.9172
# Epoch 8/100
# 5948/5948 [==============================] - 5s 806us/sample - loss: 0.0332 - auc: 0.8782 - val_loss: 0.0233 - val_auc: 0.9344
# Epoch 9/100
# 5948/5948 [==============================] - 5s 787us/sample - loss: 0.0360 - auc: 0.8547 - val_loss: 0.0304 - val_auc: 0.9022
# Epoch 10/100
# 5948/5948 [==============================] - 5s 782us/sample - loss: 0.0369 - auc: 0.8681 - val_loss: 0.0298 - val_auc: 0.9227
# Epoch 11/100
# 5948/5948 [==============================] - 5s 783us/sample - loss: 0.0320 - auc: 0.8910 - val_loss: 0.0314 - val_auc: 0.8976
# Epoch 12/100
# 5824/5948 [============================>.] - ETA: 0s - loss: 0.0321 - auc: 0.8863
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0323 - auc: 0.8847 - val_loss: 0.0292 - val_auc: 0.9239
# Epoch 13/100
# 5948/5948 [==============================] - 5s 805us/sample - loss: 0.0269 - auc: 0.9193 - val_loss: 0.0225 - val_auc: 0.9359
# Epoch 14/100
# 5948/5948 [==============================] - 5s 785us/sample - loss: 0.0197 - auc: 0.9479 - val_loss: 0.0226 - val_auc: 0.9363
# Epoch 15/100
# 5948/5948 [==============================] - 5s 791us/sample - loss: 0.0201 - auc: 0.9476 - val_loss: 0.0244 - val_auc: 0.9350
# Epoch 16/100
# 5948/5948 [==============================] - 5s 782us/sample - loss: 0.0207 - auc: 0.9408 - val_loss: 0.0239 - val_auc: 0.9324
# Epoch 17/100
# 5824/5948 [============================>.] - ETA: 0s - loss: 0.0193 - auc: 0.9530
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5948/5948 [==============================] - 5s 780us/sample - loss: 0.0190 - auc: 0.9545 - val_loss: 0.0228 - val_auc: 0.9349
# Epoch 18/100
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0170 - auc: 0.9631 - val_loss: 0.0228 - val_auc: 0.9355
# Epoch 19/100
# 5948/5948 [==============================] - 5s 791us/sample - loss: 0.0172 - auc: 0.9613 - val_loss: 0.0228 - val_auc: 0.9356
# Epoch 20/100
# 5948/5948 [==============================] - 5s 782us/sample - loss: 0.0154 - auc: 0.9697 - val_loss: 0.0229 - val_auc: 0.9357
# Epoch 21/100
# 5824/5948 [============================>.] - ETA: 0s - loss: 0.0162 - auc: 0.9668
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5948/5948 [==============================] - 5s 781us/sample - loss: 0.0162 - auc: 0.9662 - val_loss: 0.0231 - val_auc: 0.9359
# Epoch 00021: early stopping
# 1488/1488 [==============================] - 0s 307us/sample
# FOLD:1
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1054 - auc: 0.4266 - val_loss: 0.1610 - val_auc: 0.1791
# Epoch 2/100
# 5949/5949 [==============================] - 5s 816us/sample - loss: 0.0517 - auc: 0.7370 - val_loss: 0.1319 - val_auc: 0.4622
# Epoch 3/100
# 5949/5949 [==============================] - 5s 828us/sample - loss: 0.0461 - auc: 0.7986 - val_loss: 0.0932 - val_auc: 0.7811
# Epoch 4/100
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0389 - auc: 0.8478 - val_loss: 0.0559 - val_auc: 0.8386
# Epoch 5/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0378 - auc: 0.8401 - val_loss: 0.0448 - val_auc: 0.8598
# Epoch 6/100
# 5949/5949 [==============================] - 5s 816us/sample - loss: 0.0324 - auc: 0.8810 - val_loss: 0.0420 - val_auc: 0.8781
# Epoch 7/100
# 5949/5949 [==============================] - 5s 786us/sample - loss: 0.0340 - auc: 0.8472 - val_loss: 0.0468 - val_auc: 0.8664
# Epoch 8/100
# 5949/5949 [==============================] - 5s 817us/sample - loss: 0.0369 - auc: 0.8333 - val_loss: 0.0492 - val_auc: 0.8678
# Epoch 9/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0325 - auc: 0.8870 - val_loss: 0.0453 - val_auc: 0.8468
# Epoch 10/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0309 - auc: 0.8695
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0319 - auc: 0.8659 - val_loss: 0.0462 - val_auc: 0.8744
# Epoch 11/100
# 5949/5949 [==============================] - 5s 804us/sample - loss: 0.0227 - auc: 0.9284 - val_loss: 0.0452 - val_auc: 0.8709
# Epoch 12/100
# 5949/5949 [==============================] - 5s 807us/sample - loss: 0.0192 - auc: 0.9546 - val_loss: 0.0457 - val_auc: 0.8752
# Epoch 13/100
# 5949/5949 [==============================] - 5s 810us/sample - loss: 0.0201 - auc: 0.9441 - val_loss: 0.0485 - val_auc: 0.8642
# Epoch 14/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0188 - auc: 0.9526
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0185 - auc: 0.9543 - val_loss: 0.0456 - val_auc: 0.8782
# Epoch 00014: early stopping
# 1487/1487 [==============================] - 0s 317us/sample
# FOLD:2
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1320 - auc: 0.2951 - val_loss: 0.1011 - val_auc: 0.6194
# Epoch 2/100
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0540 - auc: 0.7420 - val_loss: 0.0736 - val_auc: 0.7846
# Epoch 3/100
# 5949/5949 [==============================] - 5s 801us/sample - loss: 0.0396 - auc: 0.8140 - val_loss: 0.0839 - val_auc: 0.8412
# Epoch 4/100
# 5949/5949 [==============================] - 5s 818us/sample - loss: 0.0511 - auc: 0.7657 - val_loss: 0.0416 - val_auc: 0.8962
# Epoch 5/100
# 5949/5949 [==============================] - 5s 820us/sample - loss: 0.0400 - auc: 0.8194 - val_loss: 0.0363 - val_auc: 0.8915
# Epoch 6/100
# 5949/5949 [==============================] - 5s 818us/sample - loss: 0.0364 - auc: 0.8434 - val_loss: 0.0322 - val_auc: 0.9070
# Epoch 7/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0328 - auc: 0.8715 - val_loss: 0.0377 - val_auc: 0.9173
# Epoch 8/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0327 - auc: 0.8520 - val_loss: 0.0323 - val_auc: 0.9175
# Epoch 9/100
# 5949/5949 [==============================] - 5s 814us/sample - loss: 0.0305 - auc: 0.8652 - val_loss: 0.0302 - val_auc: 0.9261
# Epoch 10/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0304 - auc: 0.8863 - val_loss: 0.0461 - val_auc: 0.9132
# Epoch 11/100
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0264 - auc: 0.9130 - val_loss: 0.0458 - val_auc: 0.9205
# Epoch 12/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0289 - auc: 0.8978 - val_loss: 0.0357 - val_auc: 0.9109
# Epoch 13/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0312 - auc: 0.8789
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0310 - auc: 0.8789 - val_loss: 0.0443 - val_auc: 0.9135
# Epoch 14/100
# 5949/5949 [==============================] - 5s 799us/sample - loss: 0.0209 - auc: 0.9384 - val_loss: 0.0328 - val_auc: 0.9245
# Epoch 15/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0177 - auc: 0.9583 - val_loss: 0.0320 - val_auc: 0.9326
# Epoch 16/100
# 5949/5949 [==============================] - 5s 806us/sample - loss: 0.0163 - auc: 0.9619 - val_loss: 0.0321 - val_auc: 0.9271
# Epoch 17/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0142 - auc: 0.972 - ETA: 0s - loss: 0.0144 - auc: 0.9687
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0147 - auc: 0.9682 - val_loss: 0.0337 - val_auc: 0.9264
# Epoch 00017: early stopping
# 1487/1487 [==============================] - 0s 308us/sample
# FOLD:3
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1106 - auc: 0.4225 - val_loss: 0.1613 - val_auc: 0.1938
# Epoch 2/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0490 - auc: 0.7710 - val_loss: 0.1252 - val_auc: 0.3496
# Epoch 3/100
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0468 - auc: 0.7660 - val_loss: 0.1951 - val_auc: 0.4527
# Epoch 4/100
# 5949/5949 [==============================] - 5s 822us/sample - loss: 0.0434 - auc: 0.8129 - val_loss: 0.1229 - val_auc: 0.7007
# Epoch 5/100
# 5949/5949 [==============================] - 5s 825us/sample - loss: 0.0357 - auc: 0.8734 - val_loss: 0.0722 - val_auc: 0.7812
# Epoch 6/100
# 5949/5949 [==============================] - 5s 818us/sample - loss: 0.0378 - auc: 0.8677 - val_loss: 0.0487 - val_auc: 0.8318
# Epoch 7/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0336 - auc: 0.8663 - val_loss: 0.0472 - val_auc: 0.8337
# Epoch 8/100
# 5949/5949 [==============================] - 5s 824us/sample - loss: 0.0346 - auc: 0.8751 - val_loss: 0.0380 - val_auc: 0.8396
# Epoch 9/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0289 - auc: 0.9003 - val_loss: 0.0373 - val_auc: 0.8495
# Epoch 10/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0304 - auc: 0.9041 - val_loss: 0.0456 - val_auc: 0.8429
# Epoch 11/100
# 5949/5949 [==============================] - 5s 814us/sample - loss: 0.0315 - auc: 0.9011 - val_loss: 0.0372 - val_auc: 0.8481
# Epoch 12/100
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0298 - auc: 0.8956 - val_loss: 0.0509 - val_auc: 0.8325
# Epoch 13/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0318 - auc: 0.9003 - val_loss: 0.0487 - val_auc: 0.8066
# Epoch 14/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0307 - auc: 0.8953 - val_loss: 0.0459 - val_auc: 0.8157
# Epoch 15/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0299 - auc: 0.8928
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 801us/sample - loss: 0.0298 - auc: 0.8954 - val_loss: 0.0432 - val_auc: 0.8490
# Epoch 16/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0202 - auc: 0.9532 - val_loss: 0.0364 - val_auc: 0.8598
# Epoch 17/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0162 - auc: 0.9694 - val_loss: 0.0395 - val_auc: 0.8581
# Epoch 18/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0146 - auc: 0.9723 - val_loss: 0.0416 - val_auc: 0.8541
# Epoch 19/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0141 - auc: 0.9721 - val_loss: 0.0423 - val_auc: 0.8567
# Epoch 20/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0130 - auc: 0.9742
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 790us/sample - loss: 0.0128 - auc: 0.9744 - val_loss: 0.0421 - val_auc: 0.8615
# Epoch 21/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0125 - auc: 0.9769 - val_loss: 0.0428 - val_auc: 0.8592
# Epoch 22/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0117 - auc: 0.9796 - val_loss: 0.0435 - val_auc: 0.8574
# Epoch 23/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0110 - auc: 0.9829 - val_loss: 0.0444 - val_auc: 0.8588
# Epoch 24/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0122 - auc: 0.9786
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0125 - auc: 0.9772 - val_loss: 0.0444 - val_auc: 0.8586
# Epoch 00024: early stopping
# 1487/1487 [==============================] - 0s 309us/sample
# FOLD:4
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1144 - auc: 0.3506 - val_loss: 0.1169 - val_auc: 0.2033
# Epoch 2/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0525 - auc: 0.7363 - val_loss: 0.1403 - val_auc: 0.5205
# Epoch 3/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0465 - auc: 0.7779 - val_loss: 0.0602 - val_auc: 0.7435
# Epoch 4/100
# 5949/5949 [==============================] - 5s 819us/sample - loss: 0.0441 - auc: 0.7865 - val_loss: 0.0571 - val_auc: 0.9102
# Epoch 5/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0407 - auc: 0.8469 - val_loss: 0.0331 - val_auc: 0.9162
# Epoch 6/100
# 5949/5949 [==============================] - 5s 816us/sample - loss: 0.0418 - auc: 0.8202 - val_loss: 0.0234 - val_auc: 0.9341
# Epoch 7/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0379 - auc: 0.8474 - val_loss: 0.0451 - val_auc: 0.9161
# Epoch 8/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0391 - auc: 0.8328 - val_loss: 0.0363 - val_auc: 0.9272
# Epoch 9/100
# 5949/5949 [==============================] - 5s 800us/sample - loss: 0.0417 - auc: 0.8215 - val_loss: 0.0245 - val_auc: 0.9313
# Epoch 10/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0318 - auc: 0.8872
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0328 - auc: 0.8816 - val_loss: 0.0261 - val_auc: 0.9213
# Epoch 11/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0256 - auc: 0.9113 - val_loss: 0.0197 - val_auc: 0.9430
# Epoch 12/100
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0232 - auc: 0.9192 - val_loss: 0.0194 - val_auc: 0.9413
# Epoch 13/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0237 - auc: 0.9310 - val_loss: 0.0188 - val_auc: 0.9449
# Epoch 14/100
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0210 - auc: 0.9415 - val_loss: 0.0177 - val_auc: 0.9462
# Epoch 15/100
# 5949/5949 [==============================] - 5s 797us/sample - loss: 0.0217 - auc: 0.9335 - val_loss: 0.0204 - val_auc: 0.9397
# Epoch 16/100
# 5949/5949 [==============================] - 5s 816us/sample - loss: 0.0191 - auc: 0.9482 - val_loss: 0.0173 - val_auc: 0.9595
# Epoch 17/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0174 - auc: 0.9609 - val_loss: 0.0203 - val_auc: 0.9383
# Epoch 18/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0164 - auc: 0.9629 - val_loss: 0.0174 - val_auc: 0.9543
# Epoch 19/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0164 - auc: 0.9600 - val_loss: 0.0175 - val_auc: 0.9460
# Epoch 20/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0171 - auc: 0.9587
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0169 - auc: 0.9588 - val_loss: 0.0187 - val_auc: 0.9523
# Epoch 21/100
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0145 - auc: 0.9700 - val_loss: 0.0168 - val_auc: 0.9517
# Epoch 22/100
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0133 - auc: 0.9727 - val_loss: 0.0165 - val_auc: 0.9528
# Epoch 23/100
# 5949/5949 [==============================] - 5s 807us/sample - loss: 0.0141 - auc: 0.9718 - val_loss: 0.0163 - val_auc: 0.9534
# Epoch 24/100
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0141 - auc: 0.9708 - val_loss: 0.0162 - val_auc: 0.9555
# Epoch 25/100
# 5949/5949 [==============================] - 5s 820us/sample - loss: 0.0127 - auc: 0.9757 - val_loss: 0.0162 - val_auc: 0.9547
# Epoch 26/100
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0129 - auc: 0.9744 - val_loss: 0.0158 - val_auc: 0.9566
# Epoch 27/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0128 - auc: 0.9748 - val_loss: 0.0160 - val_auc: 0.9562
# Epoch 28/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0128 - auc: 0.9733 - val_loss: 0.0160 - val_auc: 0.9553
# Epoch 29/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0132 - auc: 0.9756 - val_loss: 0.0160 - val_auc: 0.9557
# Epoch 30/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0102 - auc: 0.9823
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0113 - auc: 0.9778 - val_loss: 0.0162 - val_auc: 0.9566
# Epoch 31/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0125 - auc: 0.9760 - val_loss: 0.0162 - val_auc: 0.9566
# Epoch 32/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0126 - auc: 0.9736 - val_loss: 0.0162 - val_auc: 0.9566
# Epoch 33/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0124 - auc: 0.9756 - val_loss: 0.0162 - val_auc: 0.9566
# Epoch 34/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0112 - auc: 0.9794
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0111 - auc: 0.9795 - val_loss: 0.0163 - val_auc: 0.9566
# Epoch 00034: early stopping
# 1487/1487 [==============================] - 0s 307us/sample
# FOLD:5
# train_y shape: (5948, 1) 0.03160726294552791
# valid_y shape: (1488, 1) 0.03225806451612903
# Train on 5948 samples, validate on 1488 samples
# Epoch 1/100
# 5948/5948 [==============================] - 7s 1ms/sample - loss: 0.2177 - auc: 0.1735 - val_loss: 0.1096 - val_auc: 0.3799
# Epoch 2/100
# 5948/5948 [==============================] - 5s 809us/sample - loss: 0.0602 - auc: 0.6999 - val_loss: 0.0865 - val_auc: 0.5968
# Epoch 3/100
# 5948/5948 [==============================] - 5s 813us/sample - loss: 0.0582 - auc: 0.7061 - val_loss: 0.0620 - val_auc: 0.7687
# Epoch 4/100
# 5948/5948 [==============================] - 5s 809us/sample - loss: 0.0453 - auc: 0.8022 - val_loss: 0.0441 - val_auc: 0.8528
# Epoch 5/100
# 5948/5948 [==============================] - 5s 788us/sample - loss: 0.0402 - auc: 0.8386 - val_loss: 0.0477 - val_auc: 0.8864
# Epoch 6/100
# 5948/5948 [==============================] - 5s 807us/sample - loss: 0.0399 - auc: 0.8348 - val_loss: 0.0296 - val_auc: 0.9214
# Epoch 7/100
# 5948/5948 [==============================] - 5s 789us/sample - loss: 0.0396 - auc: 0.8398 - val_loss: 0.0495 - val_auc: 0.9369
# Epoch 8/100
# 5948/5948 [==============================] - 5s 804us/sample - loss: 0.0404 - auc: 0.8288 - val_loss: 0.0218 - val_auc: 0.9486
# Epoch 9/100
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0375 - auc: 0.8456 - val_loss: 0.0276 - val_auc: 0.9351
# Epoch 10/100
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0320 - auc: 0.8906 - val_loss: 0.0297 - val_auc: 0.9369
# Epoch 11/100
# 5948/5948 [==============================] - 5s 789us/sample - loss: 0.0334 - auc: 0.8827 - val_loss: 0.0257 - val_auc: 0.9413
# Epoch 12/100
# 5888/5948 [============================>.] - ETA: 0s - loss: 0.0302 - auc: 0.8977
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0299 - auc: 0.8976 - val_loss: 0.0226 - val_auc: 0.9448
# Epoch 13/100
# 5948/5948 [==============================] - 5s 786us/sample - loss: 0.0226 - auc: 0.9366 - val_loss: 0.0219 - val_auc: 0.9517
# Epoch 14/100
# 5948/5948 [==============================] - 5s 795us/sample - loss: 0.0213 - auc: 0.9394 - val_loss: 0.0227 - val_auc: 0.9494
# Epoch 15/100
# 5948/5948 [==============================] - 5s 800us/sample - loss: 0.0204 - auc: 0.9452 - val_loss: 0.0237 - val_auc: 0.9499
# Epoch 16/100
# 5888/5948 [============================>.] - ETA: 0s - loss: 0.0196 - auc: 0.9439
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5948/5948 [==============================] - 5s 810us/sample - loss: 0.0200 - auc: 0.9427 - val_loss: 0.0239 - val_auc: 0.9468
# Epoch 00016: early stopping
# 1488/1488 [==============================] - 0s 315us/sample
# FOLD:6
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1509 - auc: 0.3000 - val_loss: 0.1476 - val_auc: 0.1954
# Epoch 2/100
# 5949/5949 [==============================] - 5s 832us/sample - loss: 0.0501 - auc: 0.7620 - val_loss: 0.1357 - val_auc: 0.6273
# Epoch 3/100
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0484 - auc: 0.7798 - val_loss: 0.0909 - val_auc: 0.7542
# Epoch 4/100
# 5949/5949 [==============================] - 5s 806us/sample - loss: 0.0389 - auc: 0.8499 - val_loss: 0.0665 - val_auc: 0.8222
# Epoch 5/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0382 - auc: 0.8588 - val_loss: 0.0303 - val_auc: 0.9047
# Epoch 6/100
# 5949/5949 [==============================] - 5s 787us/sample - loss: 0.0408 - auc: 0.8522 - val_loss: 0.0482 - val_auc: 0.8327
# Epoch 7/100
# 5949/5949 [==============================] - 5s 803us/sample - loss: 0.0388 - auc: 0.8379 - val_loss: 0.0310 - val_auc: 0.8875
# Epoch 8/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0359 - auc: 0.8523 - val_loss: 0.0738 - val_auc: 0.8268
# Epoch 9/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0323 - auc: 0.8897
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0324 - auc: 0.8874 - val_loss: 0.0397 - val_auc: 0.8534
# Epoch 10/100
# 5949/5949 [==============================] - 5s 800us/sample - loss: 0.0262 - auc: 0.9155 - val_loss: 0.0311 - val_auc: 0.8884
# Epoch 11/100
# 5949/5949 [==============================] - 5s 819us/sample - loss: 0.0236 - auc: 0.9274 - val_loss: 0.0296 - val_auc: 0.8980
# Epoch 12/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0209 - auc: 0.9397 - val_loss: 0.0266 - val_auc: 0.9032
# Epoch 13/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0189 - auc: 0.9437 - val_loss: 0.0256 - val_auc: 0.9080
# Epoch 14/100
# 5949/5949 [==============================] - 5s 799us/sample - loss: 0.0171 - auc: 0.9609 - val_loss: 0.0275 - val_auc: 0.9123
# Epoch 15/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0174 - auc: 0.9591 - val_loss: 0.0266 - val_auc: 0.9119
# Epoch 16/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0162 - auc: 0.9652 - val_loss: 0.0291 - val_auc: 0.9075
# Epoch 17/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0153 - auc: 0.9664
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0152 - auc: 0.9675 - val_loss: 0.0269 - val_auc: 0.9082
# Epoch 18/100
# 5949/5949 [==============================] - 5s 788us/sample - loss: 0.0135 - auc: 0.9730 - val_loss: 0.0267 - val_auc: 0.9132
# Epoch 19/100
# 5949/5949 [==============================] - 5s 787us/sample - loss: 0.0128 - auc: 0.9757 - val_loss: 0.0269 - val_auc: 0.9130
# Epoch 20/100
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0124 - auc: 0.9776 - val_loss: 0.0270 - val_auc: 0.9141
# Epoch 21/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0125 - auc: 0.9801
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0124 - auc: 0.9801 - val_loss: 0.0270 - val_auc: 0.9151
# Epoch 00021: early stopping
# 1487/1487 [==============================] - 0s 310us/sample
# FOLD:7
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1012 - auc: 0.4488 - val_loss: 0.1486 - val_auc: 0.4897
# Epoch 2/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0585 - auc: 0.7174 - val_loss: 0.1396 - val_auc: 0.5561
# Epoch 3/100
# 5949/5949 [==============================] - 5s 786us/sample - loss: 0.0493 - auc: 0.7896 - val_loss: 0.1524 - val_auc: 0.7028
# Epoch 4/100
# 5949/5949 [==============================] - 5s 806us/sample - loss: 0.0426 - auc: 0.8162 - val_loss: 0.0488 - val_auc: 0.8890
# Epoch 5/100
# 5949/5949 [==============================] - 5s 825us/sample - loss: 0.0411 - auc: 0.8295 - val_loss: 0.0420 - val_auc: 0.8757
# Epoch 6/100
# 5949/5949 [==============================] - 5s 819us/sample - loss: 0.0478 - auc: 0.7660 - val_loss: 0.0386 - val_auc: 0.8805
# Epoch 7/100
# 5949/5949 [==============================] - 5s 826us/sample - loss: 0.0400 - auc: 0.8204 - val_loss: 0.0256 - val_auc: 0.9074
# Epoch 8/100
# 5949/5949 [==============================] - 5s 810us/sample - loss: 0.0369 - auc: 0.8656 - val_loss: 0.0393 - val_auc: 0.8957
# Epoch 9/100
# 5949/5949 [==============================] - 5s 804us/sample - loss: 0.0329 - auc: 0.8875 - val_loss: 0.0333 - val_auc: 0.8508
# Epoch 10/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0345 - auc: 0.8677 - val_loss: 0.0260 - val_auc: 0.8981
# Epoch 11/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0364 - auc: 0.8645
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 801us/sample - loss: 0.0361 - auc: 0.8661 - val_loss: 0.0424 - val_auc: 0.8664
# Epoch 12/100
# 5949/5949 [==============================] - 5s 818us/sample - loss: 0.0256 - auc: 0.9240 - val_loss: 0.0287 - val_auc: 0.8895
# Epoch 13/100
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0235 - auc: 0.9355 - val_loss: 0.0282 - val_auc: 0.8984
# Epoch 14/100
# 5949/5949 [==============================] - 5s 799us/sample - loss: 0.0220 - auc: 0.9432 - val_loss: 0.0279 - val_auc: 0.8991
# Epoch 15/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0181 - auc: 0.9566
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0181 - auc: 0.9554 - val_loss: 0.0276 - val_auc: 0.9025
# Epoch 00015: early stopping
# 1487/1487 [==============================] - 0s 311us/sample
# FOLD:8
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1003 - auc: 0.4132 - val_loss: 0.0973 - val_auc: 0.2797
# Epoch 2/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0511 - auc: 0.7540 - val_loss: 0.0958 - val_auc: 0.5255
# Epoch 3/100
# 5949/5949 [==============================] - 5s 812us/sample - loss: 0.0492 - auc: 0.7781 - val_loss: 0.0873 - val_auc: 0.8223
# Epoch 4/100
# 5949/5949 [==============================] - 5s 807us/sample - loss: 0.0383 - auc: 0.8407 - val_loss: 0.0444 - val_auc: 0.8985
# Epoch 5/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0517 - auc: 0.7833 - val_loss: 0.0982 - val_auc: 0.8996
# Epoch 6/100
# 5949/5949 [==============================] - 5s 824us/sample - loss: 0.0422 - auc: 0.8156 - val_loss: 0.0303 - val_auc: 0.9171
# Epoch 7/100
# 5949/5949 [==============================] - 5s 790us/sample - loss: 0.0350 - auc: 0.8818 - val_loss: 0.0372 - val_auc: 0.9068
# Epoch 8/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0352 - auc: 0.8632 - val_loss: 0.0391 - val_auc: 0.9127
# Epoch 9/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0340 - auc: 0.8678 - val_loss: 0.0309 - val_auc: 0.9215
# Epoch 10/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0332 - auc: 0.8500
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0336 - auc: 0.8525 - val_loss: 0.0332 - val_auc: 0.9254
# Epoch 11/100
# 5949/5949 [==============================] - 5s 814us/sample - loss: 0.0248 - auc: 0.9139 - val_loss: 0.0299 - val_auc: 0.9336
# Epoch 12/100
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0216 - auc: 0.9227 - val_loss: 0.0301 - val_auc: 0.9356
# Epoch 13/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0208 - auc: 0.9299 - val_loss: 0.0301 - val_auc: 0.9379
# Epoch 14/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0207 - auc: 0.9322 - val_loss: 0.0320 - val_auc: 0.9366
# Epoch 15/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0192 - auc: 0.9458
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0189 - auc: 0.9477 - val_loss: 0.0310 - val_auc: 0.9375
# Epoch 16/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0160 - auc: 0.9604 - val_loss: 0.0310 - val_auc: 0.9382
# Epoch 17/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0173 - auc: 0.9518 - val_loss: 0.0313 - val_auc: 0.9376
# Epoch 18/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0164 - auc: 0.9572 - val_loss: 0.0314 - val_auc: 0.9373
# Epoch 19/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0160 - auc: 0.9530
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0163 - auc: 0.9517 - val_loss: 0.0315 - val_auc: 0.9374
# Epoch 00019: early stopping
# 1487/1487 [==============================] - 0s 310us/sample
# FOLD:9
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1164 - auc: 0.3942 - val_loss: 0.1719 - val_auc: 0.1513
# Epoch 2/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0513 - auc: 0.7879 - val_loss: 0.1845 - val_auc: 0.3134
# Epoch 3/100
# 5949/5949 [==============================] - 5s 810us/sample - loss: 0.0444 - auc: 0.8123 - val_loss: 0.0784 - val_auc: 0.5891
# Epoch 4/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0427 - auc: 0.8290 - val_loss: 0.0545 - val_auc: 0.7497
# Epoch 5/100
# 5949/5949 [==============================] - 5s 788us/sample - loss: 0.0362 - auc: 0.8437 - val_loss: 0.0749 - val_auc: 0.7228
# Epoch 6/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0344 - auc: 0.8643 - val_loss: 0.0685 - val_auc: 0.7327
# Epoch 7/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0318 - auc: 0.8846 - val_loss: 0.0794 - val_auc: 0.7560
# Epoch 8/100
# 5949/5949 [==============================] - 5s 817us/sample - loss: 0.0375 - auc: 0.8495 - val_loss: 0.0532 - val_auc: 0.8038
# Epoch 9/100
# 5949/5949 [==============================] - 5s 804us/sample - loss: 0.0330 - auc: 0.8669 - val_loss: 0.0547 - val_auc: 0.7961
# Epoch 10/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0277 - auc: 0.9010 - val_loss: 0.0548 - val_auc: 0.7931
# Epoch 11/100
# 5949/5949 [==============================] - 5s 821us/sample - loss: 0.0269 - auc: 0.9188 - val_loss: 0.0503 - val_auc: 0.7811
# Epoch 12/100
# 5949/5949 [==============================] - 5s 835us/sample - loss: 0.0279 - auc: 0.8943 - val_loss: 0.0441 - val_auc: 0.8001
# Epoch 13/100
# 5949/5949 [==============================] - 5s 799us/sample - loss: 0.0246 - auc: 0.9304 - val_loss: 0.0567 - val_auc: 0.7840
# Epoch 14/100
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0267 - auc: 0.9079 - val_loss: 0.0602 - val_auc: 0.7837
# Epoch 15/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0265 - auc: 0.9148 - val_loss: 0.0468 - val_auc: 0.7992
# Epoch 16/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0205 - auc: 0.9454
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0208 - auc: 0.9433 - val_loss: 0.0631 - val_auc: 0.7900
# Epoch 17/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0172 - auc: 0.9612 - val_loss: 0.0571 - val_auc: 0.8030
# Epoch 18/100
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0144 - auc: 0.9706 - val_loss: 0.0543 - val_auc: 0.8076
# Epoch 19/100
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0111 - auc: 0.9764 - val_loss: 0.0556 - val_auc: 0.8069
# Epoch 20/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0101 - auc: 0.9857
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0101 - auc: 0.9857 - val_loss: 0.0551 - val_auc: 0.8133
# Epoch 00020: early stopping
# 1487/1487 [==============================] - 0s 310us/sample
# FOLD:10
# train_y shape: (5948, 1) 0.03160726294552791
# valid_y shape: (1488, 1) 0.03225806451612903
# Train on 5948 samples, validate on 1488 samples
# Epoch 1/100
# 5948/5948 [==============================] - 7s 1ms/sample - loss: 0.1411 - auc: 0.2345 - val_loss: 0.1455 - val_auc: 0.2306
# Epoch 2/100
# 5948/5948 [==============================] - 5s 820us/sample - loss: 0.0543 - auc: 0.7483 - val_loss: 0.0924 - val_auc: 0.4723
# Epoch 3/100
# 5948/5948 [==============================] - 5s 813us/sample - loss: 0.0509 - auc: 0.7656 - val_loss: 0.0771 - val_auc: 0.7312
# Epoch 4/100
# 5948/5948 [==============================] - 5s 811us/sample - loss: 0.0424 - auc: 0.8090 - val_loss: 0.0504 - val_auc: 0.8480
# Epoch 5/100
# 5948/5948 [==============================] - 5s 809us/sample - loss: 0.0477 - auc: 0.7949 - val_loss: 0.0483 - val_auc: 0.8858
# Epoch 6/100
# 5948/5948 [==============================] - 5s 811us/sample - loss: 0.0398 - auc: 0.8319 - val_loss: 0.0379 - val_auc: 0.9253
# Epoch 7/100
# 5948/5948 [==============================] - 5s 812us/sample - loss: 0.0409 - auc: 0.8249 - val_loss: 0.0224 - val_auc: 0.9387
# Epoch 8/100
# 5948/5948 [==============================] - 5s 793us/sample - loss: 0.0372 - auc: 0.8545 - val_loss: 0.0250 - val_auc: 0.9433
# Epoch 9/100
# 5948/5948 [==============================] - 5s 791us/sample - loss: 0.0345 - auc: 0.8702 - val_loss: 0.0246 - val_auc: 0.9514
# Epoch 10/100
# 5948/5948 [==============================] - 5s 785us/sample - loss: 0.0311 - auc: 0.8967 - val_loss: 0.0250 - val_auc: 0.9362
# Epoch 11/100
# 5888/5948 [============================>.] - ETA: 0s - loss: 0.0323 - auc: 0.8729
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5948/5948 [==============================] - 5s 789us/sample - loss: 0.0344 - auc: 0.8673 - val_loss: 0.0264 - val_auc: 0.9422
# Epoch 12/100
# 5948/5948 [==============================] - 5s 808us/sample - loss: 0.0258 - auc: 0.9229 - val_loss: 0.0185 - val_auc: 0.9692
# Epoch 13/100
# 5948/5948 [==============================] - 5s 794us/sample - loss: 0.0255 - auc: 0.9209 - val_loss: 0.0210 - val_auc: 0.9655
# Epoch 14/100
# 5948/5948 [==============================] - 5s 811us/sample - loss: 0.0226 - auc: 0.9381 - val_loss: 0.0184 - val_auc: 0.9667
# Epoch 15/100
# 5948/5948 [==============================] - 5s 807us/sample - loss: 0.0195 - auc: 0.9477 - val_loss: 0.0220 - val_auc: 0.9661
# Epoch 16/100
# 5824/5948 [============================>.] - ETA: 0s - loss: 0.0197 - auc: 0.9515
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5948/5948 [==============================] - 5s 797us/sample - loss: 0.0195 - auc: 0.9526 - val_loss: 0.0195 - val_auc: 0.9680
# Epoch 17/100
# ...
# 5948/5948 [==============================] - 5s 795us/sample - loss: 0.0154 - auc: 0.9656 - val_loss: 0.0361 - val_auc: 0.8939
# Epoch 19/100
# 5948/5948 [==============================] - 5s 781us/sample - loss: 0.0144 - auc: 0.9717 - val_loss: 0.0362 - val_auc: 0.8943
# Epoch 20/100
# 5888/5948 [============================>.] - ETA: 0s - loss: 0.0142 - auc: 0.9751
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5948/5948 [==============================] - 5s 785us/sample - loss: 0.0141 - auc: 0.9755 - val_loss: 0.0363 - val_auc: 0.8949
# Epoch 00020: early stopping
# 1488/1488 [==============================] - 0s 313us/sample
# FOLD:21
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1084 - auc: 0.4776 - val_loss: 0.0936 - val_auc: 0.3771
# Epoch 2/100
# 5949/5949 [==============================] - 5s 778us/sample - loss: 0.0665 - auc: 0.6924 - val_loss: 0.2456 - val_auc: 0.5802
# Epoch 3/100
# 5949/5949 [==============================] - 5s 801us/sample - loss: 0.0551 - auc: 0.7556 - val_loss: 0.0859 - val_auc: 0.7752
# Epoch 4/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0507 - auc: 0.7675 - val_loss: 0.0378 - val_auc: 0.8548
# Epoch 5/100
# 5949/5949 [==============================] - 5s 781us/sample - loss: 0.0406 - auc: 0.8302 - val_loss: 0.1144 - val_auc: 0.9223
# Epoch 6/100
# 5949/5949 [==============================] - 5s 810us/sample - loss: 0.0464 - auc: 0.8103 - val_loss: 0.0275 - val_auc: 0.9157
# Epoch 7/100
# 5949/5949 [==============================] - 5s 783us/sample - loss: 0.0398 - auc: 0.8327 - val_loss: 0.0311 - val_auc: 0.9362
# Epoch 8/100
# 5949/5949 [==============================] - 5s 786us/sample - loss: 0.0373 - auc: 0.8607 - val_loss: 0.0420 - val_auc: 0.8844
# Epoch 9/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0346 - auc: 0.8784 - val_loss: 0.0251 - val_auc: 0.9360
# Epoch 10/100
# 5949/5949 [==============================] - 5s 782us/sample - loss: 0.0413 - auc: 0.8390 - val_loss: 0.0263 - val_auc: 0.9224
# Epoch 11/100
# 5949/5949 [==============================] - 5s 780us/sample - loss: 0.0302 - auc: 0.8940 - val_loss: 0.0399 - val_auc: 0.9097
# Epoch 12/100
# 5949/5949 [==============================] - 5s 815us/sample - loss: 0.0304 - auc: 0.8957 - val_loss: 0.0215 - val_auc: 0.9389
# Epoch 13/100
# 5949/5949 [==============================] - 5s 790us/sample - loss: 0.0360 - auc: 0.8481 - val_loss: 0.0273 - val_auc: 0.9334
# Epoch 14/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0317 - auc: 0.8850 - val_loss: 0.0262 - val_auc: 0.9326
# Epoch 15/100
# 5949/5949 [==============================] - 5s 790us/sample - loss: 0.0321 - auc: 0.8870 - val_loss: 0.0230 - val_auc: 0.9311
# Epoch 16/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0341 - auc: 0.8696
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 795us/sample - loss: 0.0337 - auc: 0.8701 - val_loss: 0.0220 - val_auc: 0.9355
# Epoch 17/100
# 5949/5949 [==============================] - 5s 824us/sample - loss: 0.0234 - auc: 0.9357 - val_loss: 0.0209 - val_auc: 0.9383
# Epoch 18/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0204 - auc: 0.9471 - val_loss: 0.0219 - val_auc: 0.9398
# Epoch 19/100
# 5949/5949 [==============================] - 5s 797us/sample - loss: 0.0201 - auc: 0.9474 - val_loss: 0.0213 - val_auc: 0.9418
# Epoch 20/100
# 5949/5949 [==============================] - 5s 803us/sample - loss: 0.0184 - auc: 0.9568 - val_loss: 0.0221 - val_auc: 0.9463
# Epoch 21/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0167 - auc: 0.9649
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0166 - auc: 0.9644 - val_loss: 0.0248 - val_auc: 0.9315
# Epoch 22/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0183 - auc: 0.9658 - val_loss: 0.0224 - val_auc: 0.9420
# Epoch 23/100
# 5949/5949 [==============================] - 5s 781us/sample - loss: 0.0154 - auc: 0.9689 - val_loss: 0.0223 - val_auc: 0.9449
# Epoch 24/100
# 5949/5949 [==============================] - 5s 778us/sample - loss: 0.0142 - auc: 0.9745 - val_loss: 0.0224 - val_auc: 0.9436
# Epoch 25/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0139 - auc: 0.9766
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 781us/sample - loss: 0.0137 - auc: 0.9772 - val_loss: 0.0225 - val_auc: 0.9438
# Epoch 00025: early stopping
# 1487/1487 [==============================] - 0s 319us/sample
# FOLD:22
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1723 - auc: 0.1549 - val_loss: 0.1147 - val_auc: 0.2129
# Epoch 2/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0582 - auc: 0.7325 - val_loss: 0.1073 - val_auc: 0.3099
# Epoch 3/100
# 5949/5949 [==============================] - 5s 775us/sample - loss: 0.0476 - auc: 0.7686 - val_loss: 0.2019 - val_auc: 0.3369
# Epoch 4/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0472 - auc: 0.7893 - val_loss: 0.0606 - val_auc: 0.8080
# Epoch 5/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0398 - auc: 0.8433 - val_loss: 0.0449 - val_auc: 0.8685
# Epoch 6/100
# 5949/5949 [==============================] - 5s 833us/sample - loss: 0.0368 - auc: 0.8645 - val_loss: 0.0396 - val_auc: 0.8596
# Epoch 7/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0356 - auc: 0.8649 - val_loss: 0.0307 - val_auc: 0.8943
# Epoch 8/100
# 5949/5949 [==============================] - 5s 779us/sample - loss: 0.0343 - auc: 0.8685 - val_loss: 0.0328 - val_auc: 0.9099
# Epoch 9/100
# 5949/5949 [==============================] - 5s 779us/sample - loss: 0.0399 - auc: 0.8455 - val_loss: 0.0460 - val_auc: 0.9064
# Epoch 10/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0298 - auc: 0.8987 - val_loss: 0.0271 - val_auc: 0.8984
# Epoch 11/100
# 5949/5949 [==============================] - 5s 777us/sample - loss: 0.0354 - auc: 0.8628 - val_loss: 0.0309 - val_auc: 0.8872
# Epoch 12/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0338 - auc: 0.8757 - val_loss: 0.0320 - val_auc: 0.9077
# Epoch 13/100
# 5949/5949 [==============================] - 5s 827us/sample - loss: 0.0265 - auc: 0.9177 - val_loss: 0.0246 - val_auc: 0.9280
# Epoch 14/100
# 5949/5949 [==============================] - 5s 809us/sample - loss: 0.0301 - auc: 0.8962 - val_loss: 0.0391 - val_auc: 0.9118
# Epoch 15/100
# 5949/5949 [==============================] - 5s 847us/sample - loss: 0.0295 - auc: 0.8965 - val_loss: 0.0276 - val_auc: 0.9003
# Epoch 16/100
# 5949/5949 [==============================] - 5s 863us/sample - loss: 0.0286 - auc: 0.9141 - val_loss: 0.0256 - val_auc: 0.9189
# Epoch 17/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0251 - auc: 0.9242
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 819us/sample - loss: 0.0249 - auc: 0.9242 - val_loss: 0.0386 - val_auc: 0.8666
# Epoch 18/100
# 5949/5949 [==============================] - 5s 816us/sample - loss: 0.0204 - auc: 0.9530 - val_loss: 0.0248 - val_auc: 0.9190
# Epoch 19/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0185 - auc: 0.9560 - val_loss: 0.0237 - val_auc: 0.9200
# Epoch 20/100
# 5949/5949 [==============================] - 5s 784us/sample - loss: 0.0146 - auc: 0.9715 - val_loss: 0.0239 - val_auc: 0.9241
# Epoch 21/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0150 - auc: 0.9727 - val_loss: 0.0237 - val_auc: 0.9261
# Epoch 22/100
# 5949/5949 [==============================] - 5s 792us/sample - loss: 0.0130 - auc: 0.9782 - val_loss: 0.0261 - val_auc: 0.9262
# Epoch 23/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0113 - auc: 0.9819
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 830us/sample - loss: 0.0114 - auc: 0.9818 - val_loss: 0.0285 - val_auc: 0.9204
# Epoch 24/100
# 5949/5949 [==============================] - 5s 824us/sample - loss: 0.0109 - auc: 0.9823 - val_loss: 0.0279 - val_auc: 0.9204
# Epoch 25/100
# 5949/5949 [==============================] - 5s 805us/sample - loss: 0.0106 - auc: 0.9833 - val_loss: 0.0277 - val_auc: 0.9220
# Epoch 26/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0098 - auc: 0.9853 - val_loss: 0.0277 - val_auc: 0.9237
# Epoch 27/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0107 - auc: 0.9820
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 798us/sample - loss: 0.0106 - auc: 0.9823 - val_loss: 0.0277 - val_auc: 0.9247
# Epoch 28/100
# 5949/5949 [==============================] - 5s 797us/sample - loss: 0.0096 - auc: 0.9828 - val_loss: 0.0278 - val_auc: 0.9251
# Epoch 29/100
# 5949/5949 [==============================] - 5s 810us/sample - loss: 0.0104 - auc: 0.9819 - val_loss: 0.0280 - val_auc: 0.9258
# Epoch 00029: early stopping
# 1487/1487 [==============================] - 0s 318us/sample
# FOLD:23
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.0853 - auc: 0.5696 - val_loss: 0.1420 - val_auc: 0.2362
# Epoch 2/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0493 - auc: 0.7766 - val_loss: 0.0920 - val_auc: 0.5848
# Epoch 3/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0455 - auc: 0.7799 - val_loss: 0.0988 - val_auc: 0.6660
# Epoch 4/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0518 - auc: 0.7235 - val_loss: 0.0632 - val_auc: 0.7567
# Epoch 5/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0431 - auc: 0.8219 - val_loss: 0.0556 - val_auc: 0.8164
# Epoch 6/100
# 5949/5949 [==============================] - 5s 804us/sample - loss: 0.0382 - auc: 0.8301 - val_loss: 0.0490 - val_auc: 0.8769
# Epoch 7/100
# 5949/5949 [==============================] - 5s 791us/sample - loss: 0.0294 - auc: 0.8861 - val_loss: 0.0499 - val_auc: 0.8894
# Epoch 8/100
# 5949/5949 [==============================] - 5s 804us/sample - loss: 0.0324 - auc: 0.8887 - val_loss: 0.0388 - val_auc: 0.8873
# Epoch 9/100
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0307 - auc: 0.8817 - val_loss: 0.0417 - val_auc: 0.8853
# Epoch 10/100
# 5949/5949 [==============================] - 5s 782us/sample - loss: 0.0283 - auc: 0.8964 - val_loss: 0.0451 - val_auc: 0.8667
# Epoch 11/100
# 5949/5949 [==============================] - 5s 784us/sample - loss: 0.0284 - auc: 0.8953 - val_loss: 0.0407 - val_auc: 0.9046
# Epoch 12/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0260 - auc: 0.9032
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 784us/sample - loss: 0.0259 - auc: 0.9068 - val_loss: 0.0469 - val_auc: 0.8781
# Epoch 13/100
# 5949/5949 [==============================] - 5s 783us/sample - loss: 0.0211 - auc: 0.9369 - val_loss: 0.0402 - val_auc: 0.8800
# Epoch 14/100
# 5949/5949 [==============================] - 5s 790us/sample - loss: 0.0175 - auc: 0.9496 - val_loss: 0.0422 - val_auc: 0.8809
# Epoch 15/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0147 - auc: 0.9596 - val_loss: 0.0452 - val_auc: 0.8920
# Epoch 16/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0144 - auc: 0.9653
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 789us/sample - loss: 0.0147 - auc: 0.9649 - val_loss: 0.0405 - val_auc: 0.8922
# Epoch 00016: early stopping
# 1487/1487 [==============================] - 0s 309us/sample
# FOLD:24
# train_y shape: (5949, 1) 0.03177004538577912
# valid_y shape: (1487, 1) 0.03160726294552791
# Train on 5949 samples, validate on 1487 samples
# Epoch 1/100
# 5949/5949 [==============================] - 7s 1ms/sample - loss: 0.1338 - auc: 0.3938 - val_loss: 0.1952 - val_auc: 0.3355
# Epoch 2/100
# 5949/5949 [==============================] - 5s 803us/sample - loss: 0.0586 - auc: 0.7344 - val_loss: 0.1507 - val_auc: 0.4607
# Epoch 3/100
# 5949/5949 [==============================] - 5s 843us/sample - loss: 0.0499 - auc: 0.7831 - val_loss: 0.0941 - val_auc: 0.7075
# Epoch 4/100
# 5949/5949 [==============================] - 5s 806us/sample - loss: 0.0372 - auc: 0.8646 - val_loss: 0.0546 - val_auc: 0.7960
# Epoch 5/100
# 5949/5949 [==============================] - 5s 811us/sample - loss: 0.0413 - auc: 0.8099 - val_loss: 0.0375 - val_auc: 0.8638
# Epoch 6/100
# 5949/5949 [==============================] - 5s 800us/sample - loss: 0.0333 - auc: 0.8523 - val_loss: 0.0340 - val_auc: 0.8819
# Epoch 7/100
# 5949/5949 [==============================] - 5s 787us/sample - loss: 0.0386 - auc: 0.8332 - val_loss: 0.0352 - val_auc: 0.8715
# Epoch 8/100
# 5949/5949 [==============================] - 5s 786us/sample - loss: 0.0335 - auc: 0.8885 - val_loss: 0.0353 - val_auc: 0.8881
# Epoch 9/100
# 5949/5949 [==============================] - 5s 784us/sample - loss: 0.0328 - auc: 0.8930 - val_loss: 0.0368 - val_auc: 0.8986
# Epoch 10/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0299 - auc: 0.9000
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5949/5949 [==============================] - 5s 785us/sample - loss: 0.0298 - auc: 0.9015 - val_loss: 0.0465 - val_auc: 0.8462
# Epoch 11/100
# 5949/5949 [==============================] - 5s 787us/sample - loss: 0.0268 - auc: 0.9116 - val_loss: 0.0352 - val_auc: 0.8851
# Epoch 12/100
# 5949/5949 [==============================] - 5s 801us/sample - loss: 0.0209 - auc: 0.9433 - val_loss: 0.0338 - val_auc: 0.8950
# Epoch 13/100
# 5949/5949 [==============================] - 5s 785us/sample - loss: 0.0188 - auc: 0.9555 - val_loss: 0.0360 - val_auc: 0.8887
# Epoch 14/100
# 5949/5949 [==============================] - 5s 806us/sample - loss: 0.0153 - auc: 0.9687 - val_loss: 0.0348 - val_auc: 0.8978
# Epoch 15/100
# 5949/5949 [==============================] - 5s 794us/sample - loss: 0.0164 - auc: 0.9638 - val_loss: 0.0356 - val_auc: 0.8942
# Epoch 16/100
# 5888/5949 [============================>.] - ETA: 0s - loss: 0.0153 - auc: 0.9713
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 5949/5949 [==============================] - 5s 793us/sample - loss: 0.0151 - auc: 0.9718 - val_loss: 0.0368 - val_auc: 0.8955
# Epoch 17/100
# 5949/5949 [==============================] - 5s 802us/sample - loss: 0.0131 - auc: 0.9751 - val_loss: 0.0358 - val_auc: 0.8979
# Epoch 18/100
# 5949/5949 [==============================] - 5s 808us/sample - loss: 0.0119 - auc: 0.9770 - val_loss: 0.0358 - val_auc: 0.8966
# Epoch 19/100
# 5949/5949 [==============================] - 5s 796us/sample - loss: 0.0110 - auc: 0.9822 - val_loss: 0.0360 - val_auc: 0.8975
# Epoch 20/100
# 5824/5949 [============================>.] - ETA: 0s - loss: 0.0124 - auc: 0.9779
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 5949/5949 [==============================] - 5s 813us/sample - loss: 0.0121 - auc: 0.9788 - val_loss: 0.0361 - val_auc: 0.9000
# Epoch 00020: early stopping
# 1487/1487 [==============================] - 0s 317us/sample
# Full log_loss 0.027431
# Full AP 0.916668

# %%
test['target'] = test_df
test['target'].to_csv('atmacup5_submission2.csv',index=False)
